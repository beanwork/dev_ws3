# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
kkma.sentences("한국어 분석을 시작합니다 재미있어요~")
# Out:
# ['한국어 분석을 시작합니다', '재미있어요~']

# %% [markdown]
# ## 육아휴직 관련 법안 분석
# - konlpy는 자바로 되어있는 자연어 분석 엔진을 python유저들이 사용하기 쉽게 바꾸어주는 것

# %%
import nltk

# %%
from konlpy.corpus import kobill

files_ko = kobill.fileids()
doc_ko = kobill.open('1809890.txt').read()
doc_ko
# Out:
# '지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이사철․여상규․안규백\n\n황영철․박영아․김정훈\n\n김학송 의원(10인)\n\n제안이유 및 주요내용\n\n  초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요\n\n한 나이이나, 현재 공무원이 자녀를 양육하기 위하여 육아휴직을 할 \n\n수 있는 자녀의 나이는 만 6세 이하로 되어 있어 초등학교 저학년인 \n\n자녀를 돌보기 위해서는 해당 부모님은 일자리를 그만 두어야 하고 \n\n이는 곧 출산의욕을 저하시키는 문제로 이어질 수 있을 것임.\n\n  따라서 육아휴직이 가능한 자녀의 연령을 만 8세 이하로 개정하려\n\n는 것임(안 제63조제2항제4호).\n\n- 1 -\n\n\x0c법률  제        호\n\n지방공무원법 일부개정법률안\n\n지방공무원법 일부를 다음과 같이 개정한다.\n\n제63조제2항제4호 중 “만 6세 이하의 초등학교 취학 전 자녀를”을 “만 \n\n8세 이하(취학 중인 경우에는 초등학교 2학년 이하를 말한다)의 자녀를”\n\n로 한다.\n\n부      칙\n\n이 법은 공포한 날부터 시행한다.\n\n- 3 -\n\n\x0c신 ·구조문대비표\n\n현      행\n\n개   정   안\n\n제63조(휴직) ① (생  략)\n\n제63조(휴직) ① (현행과 같음)\n\n  ② 공무원이 다음 각 호의 어\n\n  ② -------------------------\n\n느 하나에 해당하는 사유로 휴\n\n----------------------------\n\n직을 원하면 임용권자는 휴직\n\n----------------------------\n\n을 명할 수 있다. 다만, 제4호\n\n-------------.---------------\n\n의 경우에는 대통령령으로 정\n\n-------------------------
# ...

# %% [markdown]
# ### 문서에서 명사들만 추출

# %%
from konlpy.tag import Okt
t = Okt()
tokens_ko = t.nouns(doc_ko)  ## nouns는 명사
tokens_ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '의',
#  '안',
#  '번',
#  '호',
#  '발의',
#  '연월일',
#  '발',
#  '의',
#  '자',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '위',
#  '육아휴직',
#  '수',
#  '자녀',
#  '나이',
#  '만',
#  '세',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '위',
#  '해당',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '수',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '만',
#  '세',
#  '이하',
#  '개정',
#  '것임',
#  '안',
#  '제',
#  '항제',
#  '호',
#  '법률',
#  '제',
#  '호',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '제',
#  '항제',
#  '호',
#  '중',
#  '만',
#  '세',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '만',
#  '세',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
# ...

# %% [markdown]
# ### 사용 빈도 확인

# %%
ko = nltk.Text(tokens_ko, name='대한민국 국회 의안 제 1809890호')
print(len(ko.tokens))  ## return number of tokens
print(len(set(ko.tokens)))  ## returns number of unique tokens

ko.vocab()
# Out:
# 735
# 250
# FreqDist({'육아휴직': 38, '발생': 19, '만': 18, '이하': 18, '비용': 17, '액': 17, '경우': 16, '세': 16, '자녀': 14, '고용': 14, ...})

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
# %matplotlib inline

# %%
plt.figure(figsize=(12,6))
ko.plot(50)
plt.show()

# %% [markdown]
# ### stopwords 별도 설정

# %%
stop_words = ['.', '(', ')', ',', "'", '%', '-', 'X', ').', 'x', '의', '자',
              '에', '안', '번', '호', '을', '이', '다', '만', '로', '가', '를']
re_ko = []
for each_word in ko:
    if each_word not in stop_words:
        re_ko.append(each_word)

re_ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '발의',
#  '연월일',
#  '발',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '위',
#  '육아휴직',
#  '수',
#  '자녀',
#  '나이',
#  '세',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '위',
#  '해당',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '수',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '세',
#  '이하',
#  '개정',
#  '것임',
#  '제',
#  '항제',
#  '법률',
#  '제',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '제',
#  '항제',
#  '중',
#  '세',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '세',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
#  '학년',
#  '이하',
#  '말',
#  '자녀',
#  '부',
#  '칙',
#  '법',
#  '공포',
#  '날',
#  '시행',
#  '신',
#  '구조',
#  '문대비',
#  '표',
#  '현',
# ...

# %% [markdown]
# ### 빈도 다시 그리기

# %%
ko = nltk.Text(ko, name='대한민국 국회 의안 제 1890890호')

plt.figure(figsize=(12,6))
ko.plot(50)
plt.show()

# %% [markdown]
# ### 특정단어가 발생한 빈도

# %%
ko.count('초등학교')
# Out:
# 6

# %% [markdown]
# ### 문서내의 특정 단어의 위치

# %%
plt.figure(figsize=(12,6))
ko.dispersion_plot(['육아휴직', '초등학교', '공무원'])

# %% [markdown]
# ### 특정 단어 주변에 나열된 단어

# %%
ko.concordance('육아휴직')
# Out:
# Displaying 25 of 38 matches:
# 학교 저학년 경우 부모 사랑 필요 나이 현재 공무원 자녀 양육 위 육아휴직 수 자녀 나이 만 세 이하 초등학교 저학년 자녀 위 해당 부모님
#  위 해당 부모님 일자리 곧 출산 의욕 저하 문제 수 것임 따라서 육아휴직 자녀 연령 만 세 이하 개정 것임 안 제 항제 호 법률 제 호 지
# 만 세 이하 만 세 이하 방공 무 법 제 항제 호 중 지방 공무원 육아휴직 가능 자녀 연 령 만 세 이하 만 세 이하 교육 공무원 법 제 항
#  세 이하 만 세 이하 교육 공무원 법 제 항 제 중 교육 공무원 육아휴직 가능 자녀 연령 만 세 이하 만 세 이하 남녀 고용 평등 일 가정
# 하 남녀 고용 평등 일 가정 양립 지원 관 법률 제 항 중 근로자 육아휴직 가능 자녀 연령 만 세 이하 만 세 이하 조정 함 추가 재정 요가
# 경우 해당 함 첨부 사유 개정안 국가 지방 교육 공무원 및 근로자 육아휴직 신청 수 자녀 연령 만 세 이하 만 세 이하 상향 조정 함 추가
#  요가 예상 법률 개정안 시행 고 가정 경우 현재 자녀 연령 세이 육아휴직 신청 국가 지방 교육 공무원 및 근로자 대상 대상 연령 확대 육아
# 휴직 신청 국가 지방 교육 공무원 및 근로자 대상 대상 연령 확대 육아휴직 신청 수가 정도 것 예상 이 경우 발생 비용 현행법 월 이나 현재
# 이 경우 발생 비용 현행법 월 이나 현재 관련 법령 개정 추진 이 육아휴직 지급 월급 액 비례 육아휴직 여가 지급 기 때문 법령 개정 가정
#  이나 현재 관련 법령 개정 추진 이 육아휴직 지급 월급 액 비례 육아휴직 여가 지급 기 때문 법령 개정 가정 추계 경우 육아휴직 급여 액
#  액 비례 육아휴직 여가 지급 기 때문 법령 개정 가정 추계 경우 육아휴직 급여 액 육아휴직 지급 월급 여의 해당 육아휴직 발생 경우 발생
#  여가 지급 기 때문 법령 개정 가정 추계 경우 육아휴직 급여 액 육아휴직 지급 월급 여의 해당 육아휴직 발생 경우 발생 비용 체인 고용 인
# ...

# %% [markdown]
# ### font_path 설정

# %%
from matplotlib import font_manager as fm
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumGothic',
#   '/home/soomin/venv/nltk/lib/python3.10/site-packages/koreanize_matplotlib/fonts/NanumGothicExtraBold.ttf'),
#  ('NanumGothic',
#   '/home/soomin/venv/nltk/lib/python3.10/site-packages/koreanize_matplotlib/fonts/NanumGothic.ttf'),
#  ('NanumGothic',
#   '/home/soomin/venv/nltk/lib/python3.10/site-packages/koreanize_matplotlib/fonts/NanumGothicBold.ttf'),
#  ('NanumGothic',
#   '/home/soomin/venv/nltk/lib/python3.10/site-packages/koreanize_matplotlib/fonts/NanumGothicLight.ttf')]

# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt

data = ko.vocab().most_common(200)

f_path =  '/home/soomin/venv/nltk/lib/python3.10/site-packages/koreanize_matplotlib/fonts/NanumGothicExtraBold.ttf'
wordcloud = WordCloud(font_path=f_path,
                      relative_scaling=0.2,
                      background_color='white'
                    ).generate_from_frequencies(dict(data))

plt.figure(figsize=(12,6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### 나이브 베이즈 분류

# %%
from nltk.tokenize import word_tokenize
import nltk

# %%
train = [('i like you', 'pos'),
         ('i hate you', 'neg'),
         ('you like me', 'neg'),
         ('i like her', 'pos')]

# %% [markdown]
# ### 전체 말뭉치

# %%
all_words = []

for sentence in train:
    for word in word_tokenize(sentence[0]):
        all_words.append(word.lower())

set(all_words)
# Out:
# {'hate', 'her', 'i', 'like', 'me', 'you'}

# %% [markdown]
# ### 훈련용 데이터에 마킹

# %% [markdown]
# ### 원라인 코드 풀어서

# %%
t = []

for x in train:
    tmp = {}
    for word in all_words:
        tmp[word] = word in word_tokenize(x[0])
    tup = (tmp, x[1])
    t.append(tup)
t
# Out:
# [({'i': True,
#    'like': True,
#    'you': True,
#    'hate': False,
#    'me': False,
#    'her': False},
#   'pos'),
#  ({'i': True,
#    'like': False,
#    'you': True,
#    'hate': True,
#    'me': False,
#    'her': False},
#   'neg'),
#  ({'i': False,
#    'like': True,
#    'you': True,
#    'hate': False,
#    'me': True,
#    'her': False},
#   'neg'),
#  ({'i': True,
#    'like': True,
#    'you': False,
#    'hate': False,
#    'me': False,
#    'her': True},
#   'pos')]

# %% [markdown]
# ### naive bayes classifier

# %%
classifier = nltk.NaiveBayesClassifier.train(t)
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                     hate = False             pos : neg    =      1.7 : 1.0
#                      her = False             neg : pos    =      1.7 : 1.0
#                        i = True              pos : neg    =      1.7 : 1.0
#                     like = True              pos : neg    =      1.7 : 1.0
#                       me = False             pos : neg    =      1.7 : 1.0
#                      you = True              neg : pos    =      1.7 : 1.0

# %% [markdown]
# ### test 문장 입력

# %%
test_sentence = 'I like MeRui'
test_sentence_features = {}
for word in all_words:
    if word in word_tokenize(test_sentence.lower()):  ## 띄어쓰기를 기준으로 문장을 쪼갬
        test_sentence_features[word.lower()] = True
    else:
        test_sentence_features[word.lower()] = False
test_sentence_features
# Out:
# {'i': True,
#  'like': True,
#  'you': False,
#  'hate': False,
#  'me': False,
#  'her': False}

# %% [markdown]
# ### 분류 결과

# %%
classifier.classify(test_sentence_features)
# Out:
# 'pos'

# %% [markdown]
# ### 한글에서 나이브 베이즈 연습

# %%
from konlpy.tag import Okt
pos_tagger = Okt()

train = [('난 수업이 빨리 마치면 좋겠어', 'pos'),
         ('내일은 수업이 없어서 좋아', 'pos'),
         ('내일은 놀러가야지', 'pos'),
         ('오늘 수업은 정말 지루해', 'neg'),
         ('수업은 아직 시작도 안했어', 'neg'),
         ('나는 왜 이런걸 해야하는지 모르겠어', 'neg')]

# %% [markdown]
# ### 형태소 분석

# %%
pos_tagger.pos(train[0][0])
# Out:
# [('난', 'Noun'),
#  ('수업', 'Noun'),
#  ('이', 'Josa'),
#  ('빨리', 'Adverb'),
#  ('마치', 'Noun'),
#  ('면', 'Josa'),
#  ('좋겠어', 'Adjective')]

# %% [markdown]
# ### 훈련용 데이터 형태소 분석

# %%
train_docs = []
for sentence in train:
    train_docs.append((pos_tagger.morphs(sentence[0]), sentence[1]))

train_docs
# Out:
# [(['난', '수업', '이', '빨리', '마치', '면', '좋겠어'], 'pos'),
#  (['내일', '은', '수업', '이', '없어서', '좋아'], 'pos'),
#  (['내일', '은', '놀러', '가야', '지'], 'pos'),
#  (['오늘', '수업', '은', '정말', '지루해'], 'neg'),
#  (['수업', '은', '아직', '시작', '도', '안', '했어'], 'neg'),
#  (['나', '는', '왜', '이런', '걸', '해야하는지', '모르겠어'], 'neg')]

# %% [markdown]
# ### 말뭉치 만들기

# %%
all_words = []
for d in train_docs:
    for t in d[0]:
        all_words.append(t)
        
all_words = set(all_words)
all_words
# Out:
# {'가야',
#  '걸',
#  '나',
#  '난',
#  '내일',
#  '놀러',
#  '는',
#  '도',
#  '마치',
#  '면',
#  '모르겠어',
#  '빨리',
#  '수업',
#  '시작',
#  '아직',
#  '안',
#  '없어서',
#  '오늘',
#  '왜',
#  '은',
#  '이',
#  '이런',
#  '정말',
#  '좋겠어',
#  '좋아',
#  '지',
#  '지루해',
#  '해야하는지',
#  '했어'}

# %% [markdown]
# ### 있다 없다 놀이

# %%
def term_exists(doc):
    return {word : (word in set(doc)) for word in all_words}

train_xy = [(term_exists(d), c) for d,c in train_docs]
train_xy
# Out:
# [({'시작': False,
#    '했어': False,
#    '좋아': False,
#    '이': True,
#    '해야하는지': False,
#    '지': False,
#    '좋겠어': True,
#    '는': False,
#    '놀러': False,
#    '나': False,
#    '난': True,
#    '걸': False,
#    '지루해': False,
#    '오늘': False,
#    '가야': False,
#    '빨리': True,
#    '아직': False,
#    '마치': True,
#    '면': True,
#    '이런': False,
#    '은': False,
#    '왜': False,
#    '내일': False,
#    '도': False,
#    '모르겠어': False,
#    '수업': True,
#    '정말': False,
#    '안': False,
#    '없어서': False},
#   'pos'),
#  ({'시작': False,
#    '했어': False,
#    '좋아': True,
#    '이': True,
#    '해야하는지': False,
#    '지': False,
#    '좋겠어': False,
#    '는': False,
#    '놀러': False,
#    '나': False,
#    '난': False,
#    '걸': False,
#    '지루해': False,
#    '오늘': False,
#    '가야': False,
#    '빨리': False,
#    '아직': False,
#    '마치': False,
#    '면': False,
#    '이런': False,
#    '은': True,
#    '왜': False,
#    '내일': True,
#    '도': False,
#    '모르겠어': False,
#    '수업': True,
# ...

# %% [markdown]
# ### 나이브 베이즈 훈련

# %%
classifier = nltk.NaiveBayesClassifier.train(train_xy)
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                       내일 = False             neg : pos    =      2.3 : 1.0
#                        이 = False             neg : pos    =      2.3 : 1.0
#                       가야 = False             neg : pos    =      1.4 : 1.0
#                        걸 = False             pos : neg    =      1.4 : 1.0
#                        나 = False             pos : neg    =      1.4 : 1.0
#                        난 = False             neg : pos    =      1.4 : 1.0
#                       놀러 = False             neg : pos    =      1.4 : 1.0
#                        는 = False             pos : neg    =      1.4 : 1.0
#                        도 = False             pos : neg    =      1.4 : 1.0
#                       마치 = False             neg : pos    =      1.4 : 1.0

# %% [markdown]
# ### 테스트 문장

# %%
test_sentence = '수업 마치면 놀러가야지'

test_docs = pos_tagger.morphs(test_sentence)
test_docs
# Out:
# ['수업', '마치', '면', '놀러', '가야', '지']

# %%
test_xy = term_exists(test_docs)
test_xy
# Out:
# {'시작': False,
#  '했어': False,
#  '좋아': False,
#  '이': False,
#  '해야하는지': False,
#  '지': True,
#  '좋겠어': False,
#  '는': False,
#  '놀러': True,
#  '나': False,
#  '난': False,
#  '걸': False,
#  '지루해': False,
#  '오늘': False,
#  '가야': True,
#  '빨리': False,
#  '아직': False,
#  '마치': True,
#  '면': True,
#  '이런': False,
#  '은': False,
#  '왜': False,
#  '내일': False,
#  '도': False,
#  '모르겠어': False,
#  '수업': True,
#  '정말': False,
#  '안': False,
#  '없어서': False}

# %%
classifier.classify(train_xy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/soomin/dev_ws/nltk/01.hello_nltk.ipynb Cell 54 line 1
# ----> <a href='vscode-notebook-cell:/home/soomin/dev_ws/nltk/01.hello_nltk.ipynb#Y130sZmlsZQ%3D%3D?line=0'>1</a> classifier.classify(train_xy)
#
# File ~/venv/nltk/lib/python3.10/site-packages/nltk/classify/naivebayes.py:89, in NaiveBayesClassifier.classify(self, featureset)
#      88 def classify(self, featureset):
# ---> 89     return self.prob_classify(featureset).max()
#
# File ~/venv/nltk/lib/python3.10/site-packages/nltk/classify/naivebayes.py:96, in NaiveBayesClassifier.prob_classify(self, featureset)
#      91 def prob_classify(self, featureset):
#      92     # Discard any feature names that we've never seen before.
#      93     # Otherwise, we'll just assign a probability of 0 to
#      94     # everything.
#      95     featureset = featureset.copy()
# ...

# %% [markdown]
# ### 또 다른 테스트

# %%
test_sentence = '오늘은 언제 수업 마치려나'
classifier.classify(term_exists(pos_tagger.morphs(test_sentence)))
# Out:
# 'neg'

# %%
test_sentence = '오늘 수업 마치고 일어나면 내일이다'
classifier.classify(term_exists(pos_tagger.morphs(test_sentence)))
# Out:
# 'pos'
