# %%
import mysql.connector
## root 1
## admin dltnals123$

# %%
mydb = mysql.connector.connect(
        host = "localhost",
        user = 'root',
        password = '1'
)

# %%
mydb.close()

# %%
remote = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = 'armdb'
)

# %%
remote.close()

# %%
connect_local_db = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = 'root',
    password = '1',
    database = 'armbase'
)

# %%
connect_local_db.close()

# %%
connectremote_db = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

# %%
connectremote_db.close()

# %%
excute_query  = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

excute_query_cursor = excute_query.cursor()
excute_query_cursor.execute("create table sql_file (id int, filename varchar(16))")
excute_query.close()

# %%
del_table  = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = 'dltnals123$',
    database = "armbase"
)
del_table_cursor = del_table.cursor()
del_table_cursor.execute("drop table sql_file")

del_table.close()

# %%
excute_sqlfile = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

excute_sqlfile_cur = excute_sqlfile.cursor()
sql = open("test03.sql").read()
excute_sqlfile_cur.execute(sql)

excute_sqlfile.close()

# %%
multi_query = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

mp_cur = multi_query.cursor()
sql = open("test04.sql").read()
for result_iterator in mp_cur.execute(sql, multi=True):
    if result_iterator.with_rows:
        print(result_iterator.fetchall())
    else:
        print(result_iterator.statement)

multi_query.commit()
multi_query.close()
# Out:
# INSERT INTO sql_file VALUES (1, "test01.sql")
# INSERT INTO sql_file VALUES (2, "test02.sql")
# INSERT INTO sql_file VALUES (3, "test03.sql")
# INSERT INTO sql_file VALUES (4, "test04.sql")

# %%
fetch_example  = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

fe_cur = fetch_example.cursor(buffered=True)  # 여러 데이터를 가져올 때
fe_cur.execute("select * from sql_file")

result = fe_cur.fetchall()  # 쿼리의 모든 결과를 가져온다
for result_iterator in result:
    print(result_iterator)

fetch_example.close()
# Out:
# (1, 'test01.sql')
# (2, 'test02.sql')
# (3, 'test03.sql')
# (4, 'test04.sql')

# %%
import pandas as pd

df = pd.DataFrame(result)
df.head()
# Out:
#    0           1
# 0  1  test01.sql
# 1  2  test02.sql
# 2  3  test03.sql
# 3  4  test04.sql

# %%
police_df = pd.read_csv("../sql/data/police_station.csv")
police_df.head()
# Out:
#    서울특별시경찰청       서울시 종로구 사직로8길 31
# 0   서울중부경찰서        서울특별시 중구 수표로 27
# 1   서울종로경찰서       서울특별시 종로구 율곡로 46
# 2  서울남대문경찰서      서울특별시 중구 한강대로 410
# 3  서울서대문경찰서     서울특별시 서대문구 통일로 113
# 4   서울혜화경찰서  서울특별시 종로구 창경궁로 112-16

# %%
police = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

# %%
police_cur = police.cursor()
sql = "create table police_station (name varchar(32), address varchar(32))"
police_cur.execute(sql)

# %%
values = "insert into police_station values (%s, %s)"

# %%
for idx, row in police_df.iterrows():
    police_cur.execute(values, tuple(row))
    print(tuple(row))
    police.commit()
# Out:
# ('서울중부경찰서', '서울특별시 중구 수표로 27')
# ('서울종로경찰서', '서울특별시 종로구 율곡로 46')
# ('서울남대문경찰서', '서울특별시 중구 한강대로 410')
# ('서울서대문경찰서', '서울특별시 서대문구 통일로 113')
# ('서울혜화경찰서', '서울특별시 종로구 창경궁로 112-16')
# ('서울용산경찰서', '서울특별시 용산구 원효로89길 24')
# ('서울성북경찰서', '서울특별시 성북구 보문로 170')
# ('서울동대문경찰서', '서울특별시 동대문구 약령시로 21길 29')
# ('서울마포경찰서', '서울특별시 마포구 마포대로 183')
# ('서울영등포경찰서', '서울특별시 영등포구 국회대로 608')
# ('서울성동경찰서', '서울특별시 성동구 왕십리광장로 9')
# ('서울동작경찰서', '서울특별시 동작구 노량진로 148')
# ('서울광진경찰서', '서울특별시 광진구 광나루로 447 광진소방서 임시청사 (능동)')
# ('서울서부경찰서', '서울특별시 은평구 은평로9길 15')
# ('서울강북경찰서', '서울특별시 강북구 오패산로 406')
# ('서울금천경찰서', '서울특별시 관악구 남부순환로 1435')
# ('서울중랑경찰서', '서울특별시 중랑구 중랑역로 137')
# ('서울강남경찰서', '서울특별시 강남구 테헤란로 114길 11')
# ('서울관악경찰서', '서울특별시 관악구 관악로5길 33')
# ('서울강서경찰서', '서울특별시 양천구 화곡로 73')
# ('서울강동경찰서', '서울특별시 강동구 성내로 33')
# ('서울종암경찰서', '서울특별시 성북구 종암로 135')
# ('서울구로경찰서', '서울특별시 구로구 가마산로 235')
# ('서울서초경찰서', '서울특별시 서초구 반포대로 179')
# ('서울양천경찰서', '서울특별시 양천구 목동동로 99')
# ('서울송파경찰서', '서울특별시 송파구 중대로 221')
# ('서울노원경찰서', '서울특별시 노원구 노원로 283')
# ('서울방배경찰서', '서울특별시 서초구 방배천로 54')
# ('서울도봉경찰서', '서울특별시 도봉구 노해로 403')
# ('서울수서경찰서', '서울특별시 강남구 개포로 617')
# ('서울은평경찰서', '서울특별시 은평구 연서로 365')

# %%
police_cur.execute("select * from police_station")

result = police_cur.fetchall()
for row in result:

    print(police_cur.fetchall())
    print(row)
# Out:
# []
# ('서울중부경찰서', '서울특별시 중구 수표로 27')
# []
# ('서울종로경찰서', '서울특별시 종로구 율곡로 46')
# []
# ('서울남대문경찰서', '서울특별시 중구 한강대로 410')
# []
# ('서울서대문경찰서', '서울특별시 서대문구 통일로 113')
# []
# ('서울혜화경찰서', '서울특별시 종로구 창경궁로 112-16')
# []
# ('서울용산경찰서', '서울특별시 용산구 원효로89길 24')
# []
# ('서울성북경찰서', '서울특별시 성북구 보문로 170')
# []
# ('서울동대문경찰서', '서울특별시 동대문구 약령시로 21길 29')
# []
# ('서울마포경찰서', '서울특별시 마포구 마포대로 183')
# []
# ('서울영등포경찰서', '서울특별시 영등포구 국회대로 608')
# []
# ('서울성동경찰서', '서울특별시 성동구 왕십리광장로 9')
# []
# ('서울동작경찰서', '서울특별시 동작구 노량진로 148')
# []
# ('서울광진경찰서', '서울특별시 광진구 광나루로 447 광진소방서 임시청사 (능')
# []
# ('서울서부경찰서', '서울특별시 은평구 은평로9길 15')
# []
# ('서울강북경찰서', '서울특별시 강북구 오패산로 406')
# []
# ('서울금천경찰서', '서울특별시 관악구 남부순환로 1435')
# []
# ('서울중랑경찰서', '서울특별시 중랑구 중랑역로 137')
# []
# ('서울강남경찰서', '서울특별시 강남구 테헤란로 114길 11')
# []
# ('서울관악경찰서', '서울특별시 관악구 관악로5길 33')
# []
# ('서울강서경찰서', '서울특별시 양천구 화곡로 73')
# []
# ('서울강동경찰서', '서울특별시 강동구 성내로 33')
# []
# ('서울종암경찰서', '서울특별시 성북구 종암로 135')
# []
# ('서울구로경찰서', '서울특별시 구로구 가마산로 235')
# []
# ('서울서초경찰서', '서울특별시 서초구 반포대로 179')
# []
# ('서울양천경찰서', '서울특별시 양천구 목동동로 99')
# []
# ('서울송파경찰서', '서울특별시 송파구 중대로 221')
# []
# ('서울노원경찰서', '서울특별시 노원구 노원로 283')
# []
# ('서울방배경찰서', '서울특별시 서초구 방배천로 54')
# []
# ('서울도봉경찰서', '서울특별시 도봉구 노해로 403')
# []
# ('서울수서경찰서', '서울특별시 강남구 개포로 617')
# []
# ('서울은평경찰서', '서울특별시 은평구 연서로 365')

# %%
police_df2 = pd.DataFrame(result)
police_df2.head()
# Out:
#           0                      1
# 0   서울중부경찰서        서울특별시 중구 수표로 27
# 1   서울종로경찰서       서울특별시 종로구 율곡로 46
# 2  서울남대문경찰서      서울특별시 중구 한강대로 410
# 3  서울서대문경찰서     서울특별시 서대문구 통일로 113
# 4   서울혜화경찰서  서울특별시 종로구 창경궁로 112-16

# %%
police.close()

# %%
crime_df = pd.read_csv('../sql/data/2020_crime.csv', encoding='euc-kr')
crime_df.head()
# Out:
#    구분     죄종 발생검거   건수
# 0  중부     살인   발생    1
# 1  중부     살인   검거    1
# 2  중부     강도   발생    3
# 3  중부     강도   검거    4
# 4  중부  강간,추행   발생  113

# %%
crime_example = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

# %%
query = '''insert into crime_status values ("2020", %s, %s, %s, %s)'''
ce_cursor = crime_example.cursor(buffered=True)

# %%
for idx, row in crime_df.iterrows():
    ce_cursor.execute(query, tuple(row))
    print(tuple(row))
    crime_example.commit()
# Out:
# ('중부', '살인', '발생', 1)
# ('중부', '살인', '검거', 1)
# ('중부', '강도', '발생', 3)
# ('중부', '강도', '검거', 4)
# ('중부', '강간,추행', '발생', 113)
# ('중부', '강간,추행', '검거', 76)
# ('중부', '절도', '발생', 943)
# ('중부', '절도', '검거', 495)
# ('중부', '폭력', '발생', 997)
# ('중부', '폭력', '검거', 830)
# ('종로', '살인', '발생', 9)
# ('종로', '살인', '검거', 6)
# ('종로', '강도', '발생', 4)
# ('종로', '강도', '검거', 4)
# ('종로', '강간,추행', '발생', 115)
# ('종로', '강간,추행', '검거', 93)
# ('종로', '절도', '발생', 602)
# ('종로', '절도', '검거', 284)
# ('종로', '폭력', '발생', 964)
# ('종로', '폭력', '검거', 792)
# ('남대문', '살인', '발생', 1)
# ('남대문', '살인', '검거', 1)
# ('남대문', '강도', '발생', 2)
# ('남대문', '강도', '검거', 2)
# ('남대문', '강간,추행', '발생', 73)
# ('남대문', '강간,추행', '검거', 52)
# ('남대문', '절도', '발생', 699)
# ('남대문', '절도', '검거', 368)
# ('남대문', '폭력', '발생', 579)
# ('남대문', '폭력', '검거', 494)
# ('서대문', '살인', '발생', 3)
# ('방배', '살인', '발생', 1)
# ('방배', '살인', '검거', 1)
# ('방배', '강도', '발생', 1)
# ('방배', '강도', '검거', 1)
# ('방배', '강간', '발생', 63)
# ('방배', '강간', '검거', 50)
# ('방배', '절도', '발생', 348)
# ('방배', '절도', '검거', 159)
# ('방배', '폭력', '발생', 423)
# ('방배', '폭력', '검거', 365)
# ('은평', '살인', '발생', 1)
# ('은평', '살인', '검거', 1)
# ('은평', '강도', '발생', 1)
# ('은평', '강도', '검거', 1)
# ('은평', '강간,추행', '발생', 95)
# ('은평', '강간,추행', '검거', 74)
# ('은평', '절도', '발생', 839)
# ('은평', '절도', '검거', 434)
# ('은평', '폭력', '발생', 1092)
# ('은평', '폭력', '검거', 956)
# ('도봉', '살인', '발생', 0)
# ('도봉', '살인', '검거', 0)
# ('도봉', '강도', '발생', 2)
# ('도봉', '강도', '검거', 2)
# ('도봉', '강간', '발생', 82)
# ('도봉', '강간', '검거', 87)
# ('도봉', '절도', '발생', 861)
# ('도봉', '절도', '검거', 379)
# ('도봉', '폭력', '발생', 1234)
# ('도봉', '폭력', '검거', 1022)
# ('수서', '살인', '발생', 1)
# ('수서', '살인', '검거', 2)
# ('수서', '강도', '발생', 2)
# ('수서', '강도', '검거', 1)
# ('수서', '강간,추행', '발생', 195)
# ('수서', '강간,추행', '검거', 194)
# ('수서', '절도', '발생', 1010)
# ('수서', '절도', '검거', 475)
# ('수서', '폭력', '발생', 1394)
# ('수서', '폭력', '검거', 1200)

# %%
ce_cursor.execute("select * from crime_status")

result = ce_cursor.fetchall()
for row in result:
    print(row)
# Out:
# (2020, '중부', '살인', '발생', 1)
# (2020, '중부', '살인', '검거', 1)
# (2020, '중부', '강도', '발생', 3)
# (2020, '중부', '강도', '검거', 4)
# (2020, '중부', '강간,추행', '발생', 113)
# (2020, '중부', '강간,추행', '검거', 76)
# (2020, '중부', '절도', '발생', 943)
# (2020, '중부', '절도', '검거', 495)
# (2020, '중부', '폭력', '발생', 997)
# (2020, '중부', '폭력', '검거', 830)
# (2020, '종로', '살인', '발생', 9)
# (2020, '종로', '살인', '검거', 6)
# (2020, '종로', '강도', '발생', 4)
# (2020, '종로', '강도', '검거', 4)
# (2020, '종로', '강간,추행', '발생', 115)
# (2020, '종로', '강간,추행', '검거', 93)
# (2020, '종로', '절도', '발생', 602)
# (2020, '종로', '절도', '검거', 284)
# (2020, '종로', '폭력', '발생', 964)
# (2020, '종로', '폭력', '검거', 792)
# (2020, '남대문', '살인', '발생', 1)
# (2020, '남대문', '살인', '검거', 1)
# (2020, '남대문', '강도', '발생', 2)
# (2020, '남대문', '강도', '검거', 2)
# (2020, '남대문', '강간,추행', '발생', 73)
# (2020, '남대문', '강간,추행', '검거', 52)
# (2020, '남대문', '절도', '발생', 699)
# (2020, '남대문', '절도', '검거', 368)
# (2020, '남대문', '폭력', '발생', 579)
# (2020, '남대문', '폭력', '검거', 494)
# (2020, '서대문', '살인', '발생', 3)
# (2020, '서대문', '살인', '검거', 3)
# (2020, '서대문', '강도', '발생', 2)
# (2020, '서대문', '강도', '검거', 1)
# (2020, '서대문', '강간,추행', '발생', 159)
# (2020, '서대문', '강간,추행', '검거', 149)
# (2020, '서대문', '절도', '발생', 1077)
# (2020, '서대문', '절도', '검거', 524)
# (2020, '서대문', '폭력', '발생', 1292)
# (2020, '서대문', '폭력', '검거', 1029)
# (2020, '혜화', '살인', '발생', 0)
# (2020, '혜화', '살인', '검거', 0)
# (2020, '혜화', '강도', '발생', 3)
# (2020, '혜화', '강도', '검거', 3)
# (2020, '혜화', '강간,추행', '발생', 77)
# (2020, '혜화', '강간,추행', '검거', 53)
# (2020, '혜화', '절도', '발생', 581)
# (2020, '혜화', '절도', '검거', 310)
# (2020, '혜화', '폭력', '발생', 747)
# (2020, '혜화', '폭력', '검거', 628)
# (2020, '용산', '살인', '발생', 5)
# (2020, '용산', '살인', '검거', 3)
# (2020, '용산', '강도', '발생', 6)
# (2020, '용산', '강도', '검거', 6)
# (2020, '용산', '강간,추행', '발생', 230)
# (2020, '용산', '강간,추행', '검거', 186)
# (2020, '용산', '절도', '발생', 1111)
# (2020, '용산', '절도', '검거', 534)
# (2020, '용산', '폭력', '발생', 1617)
# (2020, '용산', '폭력', '검거', 1327)
# (2020, '성북', '살인', '발생', 0)
# (2020, '성북', '살인', '검거', 0)
# (2020, '성북', '강도', '발생', 2)
# (2020, '성북', '강도', '검거', 2)
# (2020, '성북', '강간', '발생', 95)
# (2020, '성북', '강간', '검거', 77)
# (2020, '성북', '절도', '발생', 439)
# (2020, '성북', '절도', '검거', 233)
# (2020, '성북', '폭력', '발생', 672)
# (2020, '성북', '폭력', '검거', 610)
# (2020, '동대문', '살인', '발생', 10)
# (2020, '동대문', '살인', '검거', 8)
# (2020, '동대문', '강도', '발생', 6)
# (2020, '동대문', '강도', '검거', 5)
# (2020, '동대문', '강간,추행', '발생', 161)
# (2020, '동대문', '강간,추행', '검거', 142)
# (2020, '동대문', '절도', '발생', 1440)
# (2020, '동대문', '절도', '검거', 713)
# (2020, '동대문', '폭력', '발생', 1784)
# (2020, '동대문', '폭력', '검거', 1597)
# (2020, '마포', '살인', '발생', 9)
# (2020, '마포', '살인', '검거', 8)
# (2020, '마포', '강도', '발생', 4)
# (2020, '마포', '강도', '검거', 3)
# (2020, '마포', '강간,추행', '발생', 348)
# (2020, '마포', '강간,추행', '검거', 287)
# (2020, '마포', '절도', '발생', 1483)
# (2020, '마포', '절도', '검거', 679)
# (2020, '마포', '폭력', '발생', 1844)
# (2020, '마포', '폭력', '검거', 1557)
# (2020, '영등포', '살인', '발생', 7)
# (2020, '영등포', '살인', '검거', 4)
# (2020, '영등포', '강도', '발생', 6)
# (2020, '영등포', '강도', '검거', 5)
# (2020, '영등포', '강간,추행', '발생', 315)
# (2020, '영등포', '강간,추행', '검거', 252)
# (2020, '영등포', '절도', '발생', 2188)
# (2020, '영등포', '절도', '검거', 953)
# (2020, '영등포', '폭력', '발생', 2701)
# (2020, '영등포', '폭력', '검거', 2157)
# (2020, '성동', '살인', '발생', 5)
# (2020, '성동', '살인', '검거', 5)
# (2020, '성동', '강도', '발생', 3)
# (2020, '성동', '강도', '검거', 3)
# (2020, '성동', '강간,추행', '발생', 115)
# (2020, '성동', '강간,추행', '검거', 98)
# (2020, '성동', '절도', '발생', 1016)
# (2020, '성동', '절도', '검거', 565)
# (2020, '성동', '폭력', '발생', 1223)
# (2020, '성동', '폭력', '검거', 1103)
# (2020, '동작', '살인', '발생', 1)
# (2020, '동작', '살인', '검거', 1)
# (2020, '동작', '강도', '발생', 1)
# (2020, '동작', '강도', '검거', 2)
# (2020, '동작', '강간,추행', '발생', 226)
# (2020, '동작', '강간,추행', '검거', 121)
# (2020, '동작', '절도', '발생', 1341)
# (2020, '동작', '절도', '검거', 592)
# (2020, '동작', '폭력', '발생', 1631)
# (2020, '동작', '폭력', '검거', 1370)
# (2020, '광진', '살인', '발생', 2)
# (2020, '광진', '살인', '검거', 2)
# (2020, '광진', '강도', '발생', 4)
# (2020, '광진', '강도', '검거', 4)
# (2020, '광진', '강간,추행', '발생', 255)
# (2020, '광진', '강간,추행', '검거', 224)
# (2020, '광진', '절도', '발생', 1664)
# (2020, '광진', '절도', '검거', 874)
# (2020, '광진', '폭력', '발생', 1676)
# (2020, '광진', '폭력', '검거', 1407)
# (2020, '서부', '살인', '발생', 3)
# (2020, '서부', '살인', '검거', 3)
# (2020, '서부', '강도', '발생', 3)
# (2020, '서부', '강도', '검거', 2)
# (2020, '서부', '강간,추행', '발생', 76)
# (2020, '서부', '강간,추행', '검거', 71)
# (2020, '서부', '절도', '발생', 532)
# (2020, '서부', '절도', '검거', 322)
# (2020, '서부', '폭력', '발생', 748)
# (2020, '서부', '폭력', '검거', 667)
# (2020, '강북', '살인', '발생', 9)
# (2020, '강북', '살인', '검거', 8)
# (2020, '강북', '강도', '발생', 5)
# (2020, '강북', '강도', '검거', 4)
# (2020, '강북', '강간,추행', '발생', 159)
# (2020, '강북', '강간,추행', '검거', 132)
# (2020, '강북', '절도', '발생', 780)
# (2020, '강북', '절도', '검거', 490)
# (2020, '강북', '폭력', '발생', 1817)
# (2020, '강북', '폭력', '검거', 1625)
# (2020, '금천', '살인', '발생', 4)
# (2020, '금천', '살인', '검거', 4)
# (2020, '금천', '강도', '발생', 7)
# (2020, '금천', '강도', '검거', 6)
# (2020, '금천', '강간,추행', '발생', 117)
# (2020, '금천', '강간,추행', '검거', 93)
# (2020, '금천', '절도', '발생', 999)
# (2020, '금천', '절도', '검거', 553)
# (2020, '금천', '폭력', '발생', 1471)
# (2020, '금천', '폭력', '검거', 1310)
# (2020, '중랑', '살인', '발생', 10)
# (2020, '중랑', '살인', '검거', 9)
# (2020, '중랑', '강도', '발생', 5)
# (2020, '중랑', '강도', '검거', 6)
# (2020, '중랑', '강간,추행', '발생', 183)
# (2020, '중랑', '강간,추행', '검거', 153)
# (2020, '중랑', '절도', '발생', 1506)
# (2020, '중랑', '절도', '검거', 889)
# (2020, '중랑', '폭력', '발생', 2022)
# (2020, '수서', '폭력', '발생', 1394)
# (2020, '수서', '폭력', '검거', 1200)

# %%
crime_df2 = pd.DataFrame(result)
crime_df2.head(10)
# Out:
#       0   1      2   3    4
# 0  2020  중부     살인  발생    1
# 1  2020  중부     살인  검거    1
# 2  2020  중부     강도  발생    3
# 3  2020  중부     강도  검거    4
# 4  2020  중부  강간,추행  발생  113
# 5  2020  중부  강간,추행  검거   76
# 6  2020  중부     절도  발생  943
# 7  2020  중부     절도  검거  495
# 8  2020  중부     폭력  발생  997
# 9  2020  중부     폭력  검거  830

# %%
crime_example.close()

# %%
cctv_con = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

# %%
cctv_df = pd.read_csv("../sql/data/Seoul_CCTV.csv")
cctv_df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
query = "create table cctv_table(name varchar(16), sum int, bf_2013 int, y_2014 int, y_2015 int, y_2016 int)"
cctv_cursor = cctv_con.cursor(buffered=True)

# %%
cctv_cursor.execute(query)

# %%
values = "insert into cctv_table values(%s, %s, %s, %s, %s, %s)"
cctv_cursor = cctv_con.cursor(buffered=True)

# %%
for idx, row in cctv_df.iterrows():
    cctv_cursor.execute(values, tuple(row))
    print(tuple(row))
    cctv_con.commit()
# Out:
# ('강남구', 3238, 1292, 430, 584, 932)
# ('강동구', 1010, 379, 99, 155, 377)
# ('강북구', 831, 369, 120, 138, 204)
# ('강서구', 911, 388, 258, 184, 81)
# ('관악구', 2109, 846, 260, 390, 613)
# ('광진구', 878, 573, 78, 53, 174)
# ('구로구', 1884, 1142, 173, 246, 323)
# ('금천구', 1348, 674, 51, 269, 354)
# ('노원구', 1566, 542, 57, 451, 516)
# ('도봉구', 825, 238, 159, 42, 386)
# ('동대문구', 1870, 1070, 23, 198, 579)
# ('동작구', 1302, 544, 341, 103, 314)
# ('마포구', 980, 314, 118, 169, 379)
# ('서대문구', 1254, 844, 50, 68, 292)
# ('서초구', 2297, 1406, 157, 336, 398)
# ('성동구', 1327, 730, 91, 241, 265)
# ('성북구', 1651, 1009, 78, 360, 204)
# ('송파구', 1081, 529, 21, 68, 463)
# ('양천구', 2482, 1843, 142, 30, 467)
# ('영등포구', 1277, 495, 214, 195, 373)
# ('용산구', 2096, 1368, 218, 112, 398)
# ('은평구', 2108, 1138, 224, 278, 468)
# ('종로구', 1619, 464, 314, 211, 630)
# ('중구', 1023, 413, 190, 72, 348)
# ('중랑구', 916, 509, 121, 177, 109)

# %%
cctv_cursor.execute("select * from cctv_table")

result = cctv_cursor.fetchall()

for row in result:
    print(row)
# Out:
# ('강남구', 3238, 1292, 430, 584, 932)
# ('강동구', 1010, 379, 99, 155, 377)
# ('강북구', 831, 369, 120, 138, 204)
# ('강서구', 911, 388, 258, 184, 81)
# ('관악구', 2109, 846, 260, 390, 613)
# ('광진구', 878, 573, 78, 53, 174)
# ('구로구', 1884, 1142, 173, 246, 323)
# ('금천구', 1348, 674, 51, 269, 354)
# ('노원구', 1566, 542, 57, 451, 516)
# ('도봉구', 825, 238, 159, 42, 386)
# ('동대문구', 1870, 1070, 23, 198, 579)
# ('동작구', 1302, 544, 341, 103, 314)
# ('마포구', 980, 314, 118, 169, 379)
# ('서대문구', 1254, 844, 50, 68, 292)
# ('서초구', 2297, 1406, 157, 336, 398)
# ('성동구', 1327, 730, 91, 241, 265)
# ('성북구', 1651, 1009, 78, 360, 204)
# ('송파구', 1081, 529, 21, 68, 463)
# ('양천구', 2482, 1843, 142, 30, 467)
# ('영등포구', 1277, 495, 214, 195, 373)
# ('용산구', 2096, 1368, 218, 112, 398)
# ('은평구', 2108, 1138, 224, 278, 468)
# ('종로구', 1619, 464, 314, 211, 630)
# ('중구', 1023, 413, 190, 72, 348)
# ('중랑구', 916, 509, 121, 177, 109)
# ('강남구', 3238, 1292, 430, 584, 932)
# ('강동구', 1010, 379, 99, 155, 377)
# ('강북구', 831, 369, 120, 138, 204)
# ('강서구', 911, 388, 258, 184, 81)
# ('관악구', 2109, 846, 260, 390, 613)
# ('광진구', 878, 573, 78, 53, 174)
# ('구로구', 1884, 1142, 173, 246, 323)
# ('금천구', 1348, 674, 51, 269, 354)
# ('노원구', 1566, 542, 57, 451, 516)
# ('도봉구', 825, 238, 159, 42, 386)
# ('동대문구', 1870, 1070, 23, 198, 579)
# ('동작구', 1302, 544, 341, 103, 314)
# ('마포구', 980, 314, 118, 169, 379)
# ('서대문구', 1254, 844, 50, 68, 292)
# ('서초구', 2297, 1406, 157, 336, 398)
# ('성동구', 1327, 730, 91, 241, 265)
# ('성북구', 1651, 1009, 78, 360, 204)
# ('송파구', 1081, 529, 21, 68, 463)
# ('양천구', 2482, 1843, 142, 30, 467)
# ('영등포구', 1277, 495, 214, 195, 373)
# ('용산구', 2096, 1368, 218, 112, 398)
# ('은평구', 2108, 1138, 224, 278, 468)
# ('종로구', 1619, 464, 314, 211, 630)
# ('중구', 1023, 413, 190, 72, 348)
# ('중랑구', 916, 509, 121, 177, 109)

# %%
cctv_df2 = pd.DataFrame(result)
cctv_df2.head(10)
# Out:
#      0     1     2    3    4    5
# 0  강남구  3238  1292  430  584  932
# 1  강동구  1010   379   99  155  377
# 2  강북구   831   369  120  138  204
# 3  강서구   911   388  258  184   81
# 4  관악구  2109   846  260  390  613
# 5  광진구   878   573   78   53  174
# 6  구로구  1884  1142  173  246  323
# 7  금천구  1348   674   51  269  354
# 8  노원구  1566   542   57  451  516
# 9  도봉구   825   238  159   42  386

# %%
cctv_con.close()

# %% [markdown]
# ## 시카고 맛집 데이터 & sql

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
from user_agent import generate_user_agent
from urllib.request import Request
from urllib.parse import urljoin
import pandas as pd
import mysql.connector
import re

url = "https://www.chicagomag.com/chicago-magazine/november-2012/best-sandwiches-chicago/"
req = Request(url=url,headers={'User-Agent':generate_user_agent()})
page = urlopen(req)

soup = BeautifulSoup(page, "html.parser")

## connect 준비 
sand_con = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin", 
    password = "dltnals123$",
    database = "armbase"
)
## 커서 선언
sand_con_cur = sand_con.cursor(buffered=True)
## 테이블 만드는 쿼리
query = '''create table sandwich(ranking int, cafe varchar(32), 
                                 menu varchar(64), price float, address varchar(32))'''
sand_con_cur.execute(query)

## insert value 쿼리
insert_values = "insert into sandwich values(%s, %s, %s, %s, %s)"

## 랭크, 링크, 메뉴, 카페이름 정보
for each in soup.find_all("div", class_ ="sammy"):
    
    str = each.find("div", class_ = "sammyListing").get_text()
    menu = str.split('\n')[0]
    cafe = str.split('\n')[1]
    rank = each.find("div", class_ = "sammyRank").string
    
    ## 링크 건너가서 주소랑 가격 값 가져오기
    sand_url = urljoin("https://www.chicagomag.com", each.find("a")["href"])
    req = Request(url=sand_url,headers={'User-Agent':generate_user_agent()})
    page = urlopen(req)
    price_add=BeautifulSoup(page, "html.parser")

    ## 가격과 주소가 있는 정보
    list = price_add.find_all("p", class_ = "addy")
    pr_ad_txt = list[0].find("em").get_text()

    ## 가격과 주소 정보 분리
    text = re.split('.,', pr_ad_txt)

    ## 가격
    price = re.search("\$\d+.(\d)?.", text[0]).group()
    price = price.split('$')[1]
    price = price[:-1]

    # 주소
    address = text[0][len(price) + 2 :]

    ## 쿼리 execute
    values = (rank, cafe, menu, price, address)
    sand_con_cur.execute(insert_values,values)
    sand_con.commit()

sand_con.close()

# %% [markdown]
# ## 퀴즈 1번

# %%
movie_df = pd.read_csv('../sql/data/movie.csv')
movie_df
# Out:
#             date             name  point
# 0     2017-12-01         뷰티풀 투모로우   9.36
# 1     2017-12-01         아이 캔 스피크   9.34
# 2     2017-12-01       다시 태어나도 우리   9.32
# 3     2017-12-01               록키   9.31
# 4     2017-12-01           저수지 게임   9.29
# ...          ...              ...    ...
# 4232  2018-03-10      나미야 잡화점의 기적   7.49
# 4233  2018-03-10               궁합   7.15
# 4234  2018-03-10  조선명탐정: 흡혈괴마의 비밀   6.82
# 4235  2018-03-10            골든슬럼버   5.53
# 4236  2018-03-10              게이트   4.83
#
# [4237 rows x 3 columns]

# %%
movie = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

# %%
movie_cur = movie.cursor(buffered=True)
create_table = "create table movie_table (date date, name varchar(16), point float)"
movie_cur.execute(create_table)

# %%
insert_value = "insert into movie_table values (%s, %s, %s)"
for idx, row in movie_df.iterrows():
    movie_cur.execute(insert_value, tuple(row))
    print(tuple(row))
    movie.commit()
# Out:
# ('2017-12-01', '뷰티풀 투모로우', 9.36)
# ('2017-12-01', '아이 캔 스피크', 9.34)
# ('2017-12-01', '다시 태어나도 우리', 9.32)
# ('2017-12-01', '록키', 9.31)
# ('2017-12-01', '저수지 게임', 9.29)
# ('2017-12-01', '땐뽀걸즈', 9.25)
# ('2017-12-01', '나, 다니엘 블레이크', 9.22)
# ('2017-12-01', '러빙 빈센트', 9.21)
# ('2017-12-01', '스쿨 오브 락', 9.21)
# ('2017-12-01', '킹 오브 프리즘 프라이드 더 히어로', 9.19)
# ('2017-12-01', '내 사랑', 9.18)
# ('2017-12-01', '범죄도시', 9.17)
# ('2017-12-01', '공범자들', 9.16)
# ('2017-12-01', '댄서', 9.13)
# ('2017-12-01', '히트', 9.11)
# ('2017-12-01', '이프 온리', 9.08)
# ('2017-12-01', '버킷리스트: 죽기 전에 꼭 하고 싶은 것들', 9.08)
# ('2017-12-01', '채비', 9.04)
# ('2017-12-01', '조제, 호랑이 그리고 물고기들', 9.01)
# ('2017-12-01', '원스', 8.99)
# ('2017-12-01', '빅풋 주니어', 8.92)
# ('2017-12-01', '매디슨 카운티의 다리', 8.91)
# ('2017-12-01', '행복을 찾아서', 8.9)
# ('2017-12-01', '10분', 8.89)
# ('2017-12-01', '여배우는 오늘도', 8.88)
# ('2017-12-01', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-01', '토르: 라그나로크', 8.87)
# ('2017-12-01', '넛잡 2', 8.83)
# ('2017-12-01', '순정', 8.77)
# ('2017-12-01', '김광석', 8.77)
# ('2017-12-01', '행복한 사전', 8.67)
# ('2017-12-01', '오리엔트 특급 살인', 8.66)
# ('2017-12-01', '배드 지니어스', 8.59)
# ('2017-12-01', '문영', 8.55)
# ('2017-12-01', '반드시 잡는다', 8.5)
# ('2017-12-01', '오두막', 8.49)
# ('2017-12-01', '기억의 밤', 8.49)
# ('2017-12-01', '해피 데스데이', 8.37)
# ('2017-12-01', '딥', 8.16)
# ('2017-12-01', '더 테이블', 8.07)
# ('2017-12-01', '블레이드 러너 2049', 8.02)
# ('2017-12-01', '잠깐만 회사 좀 관두고 올게', 8.02)
# ('2017-12-01', '너의 췌장을 먹고 싶어', 7.98)
# ('2017-12-01', '메소드', 7.98)
# ('2017-12-01', '저스티스 리그', 7.96)
# ('2017-12-01', '프랭크', 7.95)
# ('2017-12-01', '꾼', 7.92)
# ('2017-12-01', '최악의 하루', 7.88)
# ('2017-12-01', '침묵', 7.74)
# ('2017-12-01', '부라더', 7.51)
# ('2017-12-02', '뷰티풀 투모로우', 9.36)
# ('2017-12-02', '아이 캔 스피크', 9.34)
# ('2017-12-02', '다시 태어나도 우리', 9.32)
# ('2017-12-02', '록키', 9.31)
# ('2017-12-02', '저수지 게임', 9.29)
# ('2017-12-02', '땐뽀걸즈', 9.25)
# ('2017-12-02', '나, 다니엘 블레이크', 9.22)
# ('2017-12-02', '러빙 빈센트', 9.21)
# ('2017-12-02', '스쿨 오브 락', 9.21)
# ('2017-12-02', '킹 오브 프리즘 프라이드 더 히어로', 9.19)
# ('2017-12-02', '내 사랑', 9.18)
# ('2017-12-02', '범죄도시', 9.17)
# ('2017-12-02', '공범자들', 9.16)
# ('2017-12-02', '댄서', 9.13)
# ('2017-12-02', '히트', 9.11)
# ('2017-12-02', '이프 온리', 9.09)
# ('2017-12-02', '버킷리스트: 죽기 전에 꼭 하고 싶은 것들', 9.08)
# ('2017-12-02', '조제, 호랑이 그리고 물고기들', 9.01)
# ('2017-12-02', '채비', 8.99)
# ('2017-12-02', '원스', 8.99)
# ('2017-12-02', '빅풋 주니어', 8.92)
# ('2017-12-02', '매디슨 카운티의 다리', 8.91)
# ('2017-12-02', '행복을 찾아서', 8.9)
# ('2017-12-02', '10분', 8.89)
# ('2017-12-02', '여배우는 오늘도', 8.88)
# ('2017-12-02', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12
'잠깐만 회사 좀 관두고 올게', 8.02)
# ('2017-12-03', '너의 췌장을 먹고 싶어', 7.98)
# ('2017-12-03', '꾼', 7.97)
# ('2017-12-03', '저스티스 리그', 7.95)
# ('2017-12-03', '프랭크', 7.94)
# ('2017-12-03', '메소드', 7.94)
# ('2017-12-03', '최악의 하루', 7.88)
# ('2017-12-03', '침묵', 7.72)
# ('2017-12-03', '부라더', 7.5)
# ('2017-12-03', '7호실', 6.91)
# ('2017-12-03', '유리정원', 6.88)
# ('2017-12-03', '뜨거운 것이 좋아', 6.84)
# ('2017-12-04', '뷰티풀 투모로우', 9.37)
# ('2017-12-04', '아이 캔 스피크', 9.34)
# ('2017-12-04', '다시 태어나도 우리', 9.32)
# ('2017-12-04', '록키', 9.3)
# ('2017-12-04', '빌리 엘리어트', 9.28)
# ('2017-12-04', '땐뽀걸즈', 9.25)
# ('2017-12-04', '가위손', 9.25)
# ('2017-12-04', '나, 다니엘 블레이크', 9.22)
# ('2017-12-04', '스쿨 오브 락', 9.21)
# ('2017-12-04', '러빙 빈센트', 9.21)
# ('2017-12-04', '킹 오브 프리즘 프라이드 더 히어로', 9.19)
# ('2017-12-04', '내 사랑', 9.18)
# ('2017-12-04', '범죄도시', 9.16)
# ('2017-12-04', '댄서', 9.13)
# ('2017-12-04', '히트', 9.11)
# ('2017-12-04', '이프 온리', 9.09)
# ('2017-12-04', '버킷리스트: 죽기 전에 꼭 하고 싶은 것들', 9.07)
# ('2017-12-04', '조제, 호랑이 그리고 물고기들', 9.01)
# ('2017-12-04', '원스', 8.99)
# ('2017-12-04', '채비', 8.93)
# ('2017-12-04', '빅풋 주니어', 8.92)
# ('2017-12-04', '매디슨 카운티의 다리', 8.91)
# ('2017-12-04', '행복을 찾아서', 8.9)
# ('2017-12-04', '여배우는 오늘도', 8.88)
# ('2017-12-04', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-04', '토르: 라그나로크', 8.87)
# ('2017-12-04', '넛잡 2', 8.83)
# ('2017-12-04', '김광석', 8.77)
# ('2017-12-04', '순정', 8.77)
# ('2017-12-04', '행복한 사전', 8.67)
# ('2017-12-04', '배드 지니어스', 8.64)
# ('2017-12-04', '문영', 8.55)
# ('2017-12-04', '반드시 잡는다', 8.51)
# ('2017-12-04', '오두막', 8.49)
# ('2017-12-04', '오리엔트 특급 살인', 8.48)
# ('2017-12-04', '기억의 밤', 8.47)
# ('2017-12-04', '해피 데스데이', 8.36)
# ('2017-12-04', '딥', 8.16)
# ('2017-12-04', '블레이드 러너 2049', 8.02)
# ('2017-12-04', '잠깐만 회사 좀 관두고 올게', 8.02)
# ('2017-12-04', '너의 췌장을 먹고 싶어', 7.98)
# ('2017-12-04', '프랭크', 7.94)
# ('2017-12-04', '저스티스 리그', 7.94)
# ('2017-12-04', '메소드', 7.93)
# ('2017-12-04', '꾼', 7.93)
# ('2017-12-04', '최악의 하루', 7.88)
# ('2017-12-04', '침묵', 7.72)
# ('2017-12-04', '부라더', 7.49)
# ('2017-12-04', '7호실', 6.88)
# ('2017-12-04', '유리정원', 6.85)
# ('2017-12-05', '살인의 추억', 9.37)
# ('2017-12-05', '뷰티풀 투모로우', 9.36)
# ('2017-12-05', '아이 캔 스피크', 9.34)
# ('2017-12-05', '다시 태어나도 우리', 9.32)
# ('2017-12-05', '록키', 9.31)
# ('2017-12-05', '시네마 천국', 9.29)
# ('2017-12-05', '빌리 엘리어트', 9.28)
# ('2017-12-05', '땐뽀걸즈', 9.26)
# ('2017-12-05', '나, 다니엘 블레이크', 9.22)
# ('2017-12-05', '스쿨 오브 락', 9.21)
# ('2017-12-05', '러빙 빈센트', 9.2)
# ('2017-12-05', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12
'킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-09', '극장판 쿠로코의 농구 라스트 게임', 9.19)
# ('2017-12-09', '동급생', 9.18)
# ('2017-12-09', '내 사랑', 9.18)
# ('2017-12-09', '범죄도시', 9.16)
# ('2017-12-09', '댄서', 9.12)
# ('2017-12-09', '이프 온리', 9.09)
# ('2017-12-09', '버킷리스트: 죽기 전에 꼭 하고 싶은 것들', 9.07)
# ('2017-12-09', '택시운전사', 9.06)
# ('2017-12-09', '뽀로로 극장판 공룡섬 대모험', 9.06)
# ('2017-12-09', '하이큐!! 승자와 패자', 9.03)
# ('2017-12-09', '조제, 호랑이 그리고 물고기들', 9.01)
# ('2017-12-09', '채비', 8.94)
# ('2017-12-09', '빅풋 주니어', 8.92)
# ('2017-12-09', '하이큐!! 끝과 시작', 8.91)
# ('2017-12-09', '매디슨 카운티의 다리', 8.91)
# ('2017-12-09', '행복을 찾아서', 8.9)
# ('2017-12-09', '미션', 8.9)
# ('2017-12-09', '여배우는 오늘도', 8.88)
# ('2017-12-09', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-09', '토르: 라그나로크', 8.87)
# ('2017-12-09', '넛잡 2', 8.82)
# ('2017-12-09', '순정', 8.77)
# ('2017-12-09', '너의 이름은.', 8.75)
# ('2017-12-09', '행복한 사전', 8.67)
# ('2017-12-09', '라라랜드', 8.59)
# ('2017-12-09', '배드 지니어스', 8.59)
# ('2017-12-09', '록키 호러 픽쳐 쇼', 8.57)
# ('2017-12-09', '러브 라이브! 더 스쿨 아이돌 무비', 8.53)
# ('2017-12-09', '문영', 8.53)
# ('2017-12-09', '몬스터 콜', 8.51)
# ('2017-12-09', '옥자', 8.46)
# ('2017-12-09', '기억의 밤', 8.44)
# ('2017-12-09', '해피 데스데이', 8.35)
# ('2017-12-09', '덩케르크', 8.34)
# ('2017-12-09', '반드시 잡는다', 8.34)
# ('2017-12-09', '공조', 8.3)
# ('2017-12-09', '오리엔트 특급 살인', 8.27)
# ('2017-12-09', '우리의 20세기', 8.26)
# ('2017-12-10', '살인의 추억', 9.37)
# ('2017-12-10', '아이 캔 스피크', 9.34)
# ('2017-12-10', '다시 태어나도 우리', 9.32)
# ('2017-12-10', '록키', 9.3)
# ('2017-12-10', '빌리 엘리어트', 9.28)
# ('2017-12-10', '땐뽀걸즈', 9.26)
# ('2017-12-10', '가위손', 9.25)
# ('2017-12-10', '킹 오브 프리즘', 9.23)
# ('2017-12-10', '나, 다니엘 블레이크', 9.22)
# ('2017-12-10', '흑집사 : 북 오브 더 아틀란틱', 9.22)
# ('2017-12-10', '스쿨 오브 락', 9.21)
# ('2017-12-10', '러빙 빈센트', 9.2)
# ('2017-12-10', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-10', '극장판 쿠로코의 농구 라스트 게임', 9.19)
# ('2017-12-10', '동급생', 9.18)
# ('2017-12-10', '뽀로로 극장판 공룡섬 대모험', 9.18)
# ('2017-12-10', '내 사랑', 9.18)
# ('2017-12-10', '범죄도시', 9.16)
# ('2017-12-10', '댄서', 9.12)
# ('2017-12-10', '이프 온리', 9.09)
# ('2017-12-10', '버킷리스트: 죽기 전에 꼭 하고 싶은 것들', 9.07)
# ('2017-12-10', '택시운전사', 9.06)
# ('2017-12-10', '하이큐!! 승자와 패자', 9.03)
# ('2017-12-10', '조제, 호랑이 그리고 물고기들', 9.01)
# ('2017-12-10', '채비', 8.92)
# ('2017-12-10', '빅풋 주니어', 8.92)
# ('2017-12-10', '매디슨 카운티의 다리', 8.91)
# ('2017-12-10', '하이큐!! 끝과 시작', 8.91)
# ('2017-12-10', '행복을 찾아서', 8.9)
# ('2017-12-10', '미션', 8.9)
# ('2017-12-10', '여배우는 오늘도', 8.88)
# ('2017-12-10', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-10', '토르: 라그나로크', 8.87)
# ('2017-12-10', '순정', 8.77)
# ('2017-12-10', '너의 이름은.', 8.75)
# ('2017-12-10', '행복한 사전', 8.67)
# ('2017-12-10', '라라랜드', 8.59)
# ('2017-12-10', '배드 지니어스', 8.58)
# ('2017-12-10', '실버라이닝 플레이북', 8.56)
# ('2017-12-10', '러브 라이브! 더 스쿨 아이돌 무비', 8.53)
# ('2017-12-10', '문영', 8.53)
# ('2017-12-10', '캐롤', 8.52)
# ('2017-12-10', '몬스터 콜', 8.51)
# ('2017-12-10', '옥자', 8.46)
# ('2017-12-10', '기억의 밤', 8.43)
# ('2017-12-10', '해피 데스데이', 8.34)
# ('2017-12-10', '덩케르크', 8.34)
# ('2017-12-10', '반드시 잡는다', 8.28)
# ('2017-12-10', '우리의 20세기', 8.26)
# ('2017-12-10', '언어의 정원', 8.24)
# ('2017-12-11', '살인의 추억', 9.37)
# ('2017-12-11', '아이 캔 스피크', 9.34)
# ('2017-12-11', '다시 태어나도 우리', 9.32)
# ('2017-12-11', '록키', 9.3)
# ('2017-12-11', '빌리 엘리어트', 9.28)
# ('2017-12-11', '땐뽀걸즈', 9.26)
# ('2017-12-11', '가위손', 9.25)
# ('2017-12-11', '뽀로로 극장판 공룡섬 대모험', 9.22)
# ('2017-12-11', '나, 다니엘 블레이크', 9.22)
# ('2017-12-11', '스쿨 오브 락', 9.21)
# ('2017-12-11', '러빙 빈센트', 9.2)
# ('2017-12-11', '내 사랑', 9.17)
# ('2017-12-11', '범죄도시', 9.16)
# ('2017-12-11', '댄서', 9.12)
# ('2017-12-11', '히트', 9.11)
# ('2017-12-11', '이프 온리', 9.09)
# ('2017-12-11', '버킷리스트: 죽기 전에 꼭 하고 싶은 것들', 9.07)
# ('2017-12-11', '조제, 호랑이 그리고 물고기들', 9.01)
# ('2017-12-11', '파도가 지나간 자리', 8.99)
# ('2017-12-11', '빅풋 주니어', 8.92)
# ('2017-12-11', '채비', 8.92)
# ('2017-12-11', '매디슨 카운티의 다리', 8.91)
# ('2017-12-11', '행복을 찾아서', 8.9)
# ('2017-12-11', '미션', 8.9)
# ('2017-12-11', '여배우는 오늘도', 8.89)
# ('2017-12-11', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-11', '토르: 라그나로크', 8.87)
# ('2017-12-11', '순정', 8.77)
# ('2017-12-11', '행복한 사전', 8.67)
# ('2017-12-11', '라라랜드', 8.59)
# ('2017-12-11', '배드 지니어스', 8.57)
# ('2017-12-11', '실버라이닝 플레이북', 8.56)
# ('2017-12-11', '문영', 8.53)
# ('2017-12-11', '캐롤', 8.52)
# ('2017-12-11', '몬스터 콜', 8.51)
# ('2017-12-11', '옥자', 8.46)
# ('2017-12-11', '기억의 밤', 8.42)
# ('2017-12-11', '해피 데스데이', 8.34)
# ('2017-12-11', '덩케르크', 8.33)
# ('2017-12-11', '반드시 잡는다', 8.27)
# ('2017-12-11', '우리의 20세기', 8.26)
# ('2017-12-11', '오리엔트 특급 살인', 8.22)
# ('2017-12-11', '문라이트', 8.1)
# ('2017-12-11', '베이비 드라이버', 8.08)
# ('2017-12-11', '잠깐만 회사 좀 관두고 올게', 8.01)
# ('2017-12-11', '메소드', 8.0)
# ('2017-12-11', '너의 췌장을 먹고 싶어', 7.97)
# ('2017-12-11', '프랭크', 7.94)
# ('2017-12-11', '저스티스 리그', 7.93)
# ('2017-12-11', '꾼', 7.88)
# ('2017-12-12', '아이 캔 스피크', 9.34)
# ('2017-12-12', '다시 태어나도 우리', 9.32)
# ('2017-12-12', '록키', 9.3)
# ('2017-12-12', '빌리 엘리어트', 9.28)
# ('2017-12-12', '가위손', 9.25)
# ('2017-12-12', '뽀로로 극장판 공룡섬 대모험', 9.24)
# ('2017-12-12', '나, 다니엘 블레이크', 9.22)
# ('2017-12-12', '스쿨 오브 락', 9.21)
# ('2017-12-12', '러빙 빈센트', 9.2)
# ('2017-12-12', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-12', '내 사랑', 9.17)
# ('2017-12-12', '범죄도시', 9.16)
# ('2017-12-12', '댄서', 9.12)
# ('2017-12-12', '히트', 9.11)
# ('2017-12-12', '이프 온리', 9.09)
# ('2017-12-12', '버킷리스트: 죽기 전에 꼭 하고 싶은 것들', 9.07)
# ('2017-12-12', '조제, 호랑이 그리고 물고기들', 9.01)
# ('2017-12-12', '파도가 지나간 자리', 8.99)
# ('2017-12-12', '빅풋 주니어', 8.92)
# ('2017-12-12', '매디슨 카운티의 다리', 8.91)
# ('2017-12-12', '채비', 8.91)
# ('2017-12-12', '행복을 찾아서', 8.9)
# ('2017-12-12', '미션', 8.9)
# ('2017-12-12', '여배우는 오늘도', 8.89)
# ('2017-12-12', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-12', '토르: 라그나로크', 8.87)
# ('2017-12-12', '순정', 8.77)
# ('2017-12-12', '마미', 8.68)
# ('2017-12-12', '행복한 사전', 8.67)
# ('2017-12-12', '라라랜드', 8.6)
# ('2017-12-12', '배드 지니어스', 8.58)
# ('2017-12-12', '실버라이닝 플레이북', 8.56)
# ('2017-12-12', '문영', 8.53)
# ('2017-12-12', '캐롤', 8.52)
# ('2017-12-12', '몬스터 콜', 8.51)
# ('2017-12-12', '옥자', 8.46)
# ('2017-12-12', '기억의 밤', 8.4)
# ('2017-12-12', '덩케르크', 8.33)
# ('2017-12-12', '해피 데스데이', 8.33)
# ('2017-12-12', '우리의 20세기', 8.26)
# ('2017-12-12', '반드시 잡는다', 8.26)
# ('2017-12-12', '오리엔트 특급 살인', 8.2)
# ('2017-12-12', '문라이트', 8.1)
# ('2017-12-12', '베이비 드라이버', 8.07)
# ('2017-12-12', '잠깐만 회사 좀 관두고 올게', 8.01)
# ('2017-12-12', '메소드', 7.99)
# ('2017-12-12', '너의 췌장을 먹고 싶어', 7.97)
# ('2017-12
'벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-14', '토르: 라그나로크', 8.87)
# ('2017-12-14', '거인', 8.77)
# ('2017-12-14', '마미', 8.68)
# ('2017-12-14', '행복한 사전', 8.67)
# ('2017-12-14', '라라랜드', 8.6)
# ('2017-12-14', '배드 지니어스', 8.58)
# ('2017-12-14', '록키 호러 픽쳐 쇼', 8.57)
# ('2017-12-14', '문영', 8.53)
# ('2017-12-14', '몬스터 콜', 8.51)
# ('2017-12-14', '옥자', 8.46)
# ('2017-12-14', '기억의 밤', 8.37)
# ('2017-12-14', '덩케르크', 8.33)
# ('2017-12-14', '우리의 20세기', 8.26)
# ('2017-12-14', '강철비', 8.23)
# ('2017-12-14', '반드시 잡는다', 8.21)
# ('2017-12-14', '오리엔트 특급 살인', 8.18)
# ('2017-12-14', '스타워즈: 라스트 제다이', 8.12)
# ('2017-12-14', '문라이트', 8.1)
# ('2017-12-14', '베이비 드라이버', 8.07)
# ('2017-12-14', '잠깐만 회사 좀 관두고 올게', 8.01)
# ('2017-12-14', '너의 췌장을 먹고 싶어', 7.97)
# ('2017-12-14', '프랭크', 7.94)
# ('2017-12-14', '저스티스 리그', 7.93)
# ('2017-12-14', '꾼', 7.86)
# ('2017-12-14', '메리와 마녀의 꽃', 7.61)
# ('2017-12-14', '어쌔신: 더 비기닝', 7.39)
# ('2017-12-14', '용순', 7.31)
# ('2017-12-14', '그것', 7.02)
# ('2017-12-14', '매혹당한 사람들', 6.94)
# ('2017-12-15', '아이 캔 스피크', 9.34)
# ('2017-12-15', '다시 태어나도 우리', 9.32)
# ('2017-12-15', '나, 다니엘 블레이크', 9.22)
# ('2017-12-15', '러빙 빈센트', 9.2)
# ('2017-12-15', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-15', '파수꾼', 9.19)
# ('2017-12-15', '뽀로로 극장판 공룡섬 대모험', 9.18)
# ('2017-12-15', '내 사랑', 9.17)
# ('2017-12-15', '범죄도시', 9.16)
# ('2017-12-15', '러브레터', 9.09)
# ('2017-12-15', '이프 온리', 9.08)
# ('2017-12-15', '우린 액션배우다', 8.96)
# ('2017-12-15', '노무현입니다', 8.93)
# ('2017-12-15', '빅풋 주니어', 8.92)
# ('2017-12-15', '매디슨 카운티의 다리', 8.91)
# ('2017-12-15', '미션', 8.9)
# ('2017-12-15', '채비', 8.89)
# ('2017-12-15', '여배우는 오늘도', 8.89)
# ('2017-12-15', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-15', '토르: 라그나로크', 8.87)
# ('2017-12-15', '거인', 8.77)
# ('2017-12-15', '마미', 8.68)
# ('2017-12-15', '라라랜드', 8.6)
# ('2017-12-15', '배드 지니어스', 8.59)
# ('2017-12-15', '록키 호러 픽쳐 쇼', 8.57)
# ('2017-12-15', '문영', 8.53)
# ('2017-12-15', '몬스터 콜', 8.51)
# ('2017-12-15', '옥자', 8.46)
# ('2017-12-15', '기억의 밤', 8.36)
'너의 췌장을 먹고 싶어', 7.96)
# ('2017-12-19', '저스티스 리그', 7.91)
# ('2017-12-19', '꾼', 7.86)
# ('2017-12-19', '메리와 마녀의 꽃', 7.41)
# ('2017-12-19', '용순', 7.31)
# ('2017-12-19', '어쌔신: 더 비기닝', 7.3)
# ('2017-12-19', '스타워즈: 라스트 제다이', 7.17)
# ('2017-12-19', '그것', 7.02)
# ('2017-12-19', '페이트 스테이 나이트 헤븐즈필 제1장 프레시지 플라워', 6.81)
# ('2017-12-19', '불한당: 나쁜 놈들의 세상', 6.01)
# ('2017-12-19', '꼭두각시', 5.47)
# ('2017-12-20', '위대한 쇼맨', 9.63)
# ('2017-12-20', '아이 캔 스피크', 9.34)
# ('2017-12-20', '다시 태어나도 우리', 9.32)
# ('2017-12-20', '나, 다니엘 블레이크', 9.22)
# ('2017-12-20', '뽀로로 극장판 공룡섬 대모험', 9.2)
# ('2017-12-20', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-20', '러빙 빈센트', 9.2)
# ('2017-12-20', '파수꾼', 9.19)
# ('2017-12-20', '빠삐용', 9.17)
# ('2017-12-20', '내 사랑', 9.17)
# ('2017-12-20', '이터널 선샤인', 9.1)
# ('2017-12-20', '러브레터', 9.1)
# ('2017-12-20', '물랑 루즈', 9.09)
# ('2017-12-20', '이프 온리', 9.08)
# ('2017-12-20', '러브 액츄얼리', 9.0)
# ('2017-12-20', '우린 액션배우다', 8.96)
# ('2017-12-20', '여배우는 오늘도', 8.88)
# ('2017-12-20', '토르: 라그나로크', 8.87)
# ('2017-12-20', '채비', 8.86)
# ('2017-12-20', '거인', 8.77)
# ('2017-12-20', '라라랜드', 8.6)
# ('2017-12-20', '배드 지니어스', 8.6)
# ('2017-12-20', '문영', 8.53)
# ('2017-12-20', '캐롤', 8.52)
# ('2017-12-20', '7년-그들이 없는 언론', 8.52)
# ('2017-12-20', '몬스터 콜', 8.52)
# ('2017-12-20', '그녀', 8.5)
# ('2017-12-20', '옥자', 8.46)
# ('2017-12-20', '강철비', 8.43)
# ('2017-12-20', '신과함께-죄와 벌', 8.42)
# ('2017-12-20', '들개', 8.35)
# ('2017-12-20', '기억의 밤', 8.35)
# ('2017-12-20', '덩케르크', 8.32)
# ('2017-12-20', '오리엔트 특급 살인', 8.14)
# ('2017-12-20', '시인의 사랑', 8.11)
# ('2017-12-20', '베이비 드라이버', 8.07)
# ('2017-12-20', '잠깐만 회사 좀 관두고 올게', 8.03)
# ('2017-12-20', '반드시 잡는다', 8.0)
# ('2017-12-20', '너의 췌장을 먹고 싶어', 7.97)
# ('2017-12-20', '저스티스 리그', 7.91)
# ('2017-12-20', '꾼', 7.86)
# ('2017-12-20', '메리와 마녀의 꽃', 7.4)
# ('2017-12-20', '어쌔신: 더 비기닝', 7.3)
# ('2017-12-20', '스타워즈: 라스트 제다이', 7.13)
# ('2017-12-20', '그것', 7.02)
# ('2017-12-20', '페이트 스테이 나이트 헤븐즈필 제1장 프레시지 플라워', 6.81)
# ('2017-12-20', '불한당: 나쁜 놈들의 세상', 6.01)
# ('2017-12-20', '꼭두각시', 5.47)
# ('2017-12-21', '위대한 쇼맨', 9.65)
# ('2017-12-21', '다시 태어나도 우리', 9.32)
# ('2017-12-21', '나, 다니엘 블레이크', 9.22)
# ('2017-12-21', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12
'너의 췌장을 먹고 싶어', 7.97)
# ('2017-12-22', '저스티스 리그', 7.91)
# ('2017-12-22', '꾼', 7.84)
# ('2017-12-22', '예수는 역사다', 7.66)
# ('2017-12-22', '메리와 마녀의 꽃', 7.38)
# ('2017-12-22', '어쌔신: 더 비기닝', 7.28)
# ('2017-12-22', '스타워즈: 라스트 제다이', 7.09)
# ('2017-12-22', '불한당: 나쁜 놈들의 세상', 6.01)
# ('2017-12-22', '꼭두각시', 5.47)
# ('2017-12-23', '위대한 쇼맨', 9.6)
# ('2017-12-23', '다시 태어나도 우리', 9.32)
# ('2017-12-23', '나, 다니엘 블레이크', 9.22)
# ('2017-12-23', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-23', '뽀로로 극장판 공룡섬 대모험', 9.2)
# ('2017-12-23', '파수꾼', 9.19)
# ('2017-12-23', '러빙 빈센트', 9.19)
# ('2017-12-23', '빠삐용', 9.17)
# ('2017-12-23', '내 사랑', 9.17)
# ('2017-12-23', '공범자들', 9.16)
# ('2017-12-23', '이터널 선샤인', 9.1)
# ('2017-12-23', '러브레터', 9.1)
# ('2017-12-23', '물랑 루즈', 9.09)
# ('2017-12-23', '이프 온리', 9.08)
# ('2017-12-23', '안녕, 나의 소울메이트', 9.02)
# ('2017-12-23', '러브 액츄얼리', 8.99)
# ('2017-12-23', '우린 액션배우다', 8.96)
# ('2017-12-23', '토르: 라그나로크', 8.87)
# ('2017-12-23', '거인', 8.77)
# ('2017-12-23', '라라랜드', 8.6)
# ('2017-12-23', '문영', 8.53)
# ('2017-12-23', '캐롤', 8.52)
# ('2017-12-23', '그녀', 8.5)
# ('2017-12-23', '옥자', 8.46)
# ('2017-12-23', '강철비', 8.43)
# ('2017-12-23', '기억의 밤', 8.35)
# ('2017-12-23', '신과함께-죄와 벌', 8.26)
# ('2017-12-23', '오리엔트 특급 살인', 8.14)
# ('2017-12-23', '시인의 사랑', 8.11)
# ('2017-12-23', '문라이트', 8.1)
# ('2017-12-23', '베이비 드라이버', 8.07)
# ('2017-12-23', '블레이드 러너 2049', 8.03)
# ('2017-12-23', '너의 췌장을 먹고 싶어', 7.97)
# ('2017-12-23', '저스티스 리그', 7.89)
# ('2017-12-23', '꾼', 7.82)
# ('2017-12-23', '스타워즈: 깨어난 포스', 7.76)
# ('2017-12-23', '메리와 마녀의 꽃', 7.38)
# ('2017-12-23', '어쌔신: 더 비기닝', 7.27)
# ('2017-12-23', '스타워즈: 라스트 제다이', 7.08)
# ('2017-12-23', '불한당: 나쁜 놈들의 세상', 6.02)
# ('2017-12-23', '몬스터', 5.75)
# ('2017-12-23', '꼭두각시', 5.47)
# ('2017-12-24', '위대한 쇼맨', 9.6)
# ('2017-12-24', '다시 태어나도 우리', 9.32)
# ('2017-12-24', '나, 다니엘 블레이크', 9.22)
# ('2017-12-24', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12
# ('2017-12-25', '토르: 라그나로크', 8.87)
# ('2017-12-25', '그렇게 아버지가 된다', 8.82)
# ('2017-12-25', '아무도 모른다', 8.82)
# ('2017-12-25', '거인', 8.77)
# ('2017-12-25', '바닷마을 다이어리', 8.74)
# ('2017-12-25', '걸어도 걸어도', 8.64)
# ('2017-12-25', '라라랜드', 8.6)
# ('2017-12-25', '태풍이 지나가고', 8.6)
# ('2017-12-25', '문영', 8.53)
# ('2017-12-25', '캐롤', 8.52)
# ('2017-12-25', '그녀', 8.5)
# ('2017-12-25', '강철비', 8.47)
# ('2017-12-25', '옥자', 8.46)
# ('2017-12-25', '기억의 밤', 8.35)
# ('2017-12-25', '신과함께-죄와 벌', 8.26)
# ('2017-12-25', '몬스터 패밀리', 8.24)
# ('2017-12-25', '오리엔트 특급 살인', 8.13)
# ('2017-12-25', '시인의 사랑', 8.12)
# ('2017-12-25', '문라이트', 8.1)
# ('2017-12-25', '블레이드 러너 2049', 8.03)
# ('2017-12-25', '환상의 빛', 8.02)
# ('2017-12-25', '너의 췌장을 먹고 싶어', 7.96)
# ('2017-12-25', '저스티스 리그', 7.87)
# ('2017-12-25', '꾼', 7.79)
# ('2017-12-25', '메리와 마녀의 꽃', 7.37)
# ('2017-12-25', '어쌔신: 더 비기닝', 7.26)
# ('2017-12-25', '스타워즈: 라스트 제다이', 7.03)
# ('2017-12-26', '위대한 쇼맨', 9.54)
# ('2017-12-26', '다시 태어나도 우리', 9.33)
# ('2017-12-26', '나, 다니엘 블레이크', 9.22)
# ('2017-12-26', '러빙 빈센트', 9.19)
# ('2017-12-26', '킹 오브 프리즘 프라이드 더 히어로', 9.19)
# ('2017-12-26', '빠삐용', 9.17)
# ('2017-12-26', '내 사랑', 9.17)
# ('2017-12-26', '뽀로로 극장판 공룡섬 대모험', 9.17)
# ('2017-12-26', '공범자들', 9.16)
# ('2017-12-26', '러브레터', 9.09)
# ('2017-12-26', '물랑 루즈', 9.09)
# ('2017-12-26', '이프 온리', 9.08)
# ('2017-12-26', '극장판 포켓몬스터 너로 정했다!', 9.03)
# ('2017-12-26', '러브 액츄얼리', 8.99)
# ('2017-12-26', '우린 액션배우다', 8.96)
# ('2017-12-26', '안녕, 나의 소울메이트', 8.96)
# ('2017-12-26', '토르: 라그나로크', 8.87)
# ('2017-12-26', '그렇게 아버지가 된다', 8.82)
# ('2017-12-26', '아무도 모른다', 8.82)
# ('2017-12-26', '거인', 8.77)
# ('2017-12-26', '바닷마을 다이어리', 8.74)
# ('2017-12-26', '걸어도 걸어도', 8.64)
# ('2017-12-26', '라라랜드', 8.6)
# ('2017-12-26', '태풍이 지나가고', 8.6)
# ('2017-12-26', '문영', 8.52)
# ('2017-12-26', '강철비', 8.48)
# ('2017-12-26', '몬스터 패밀리', 8.46)
# ('2017-12-26', '옥자', 8.46)
# ('2017-12-26', '기억의 밤', 8.35)
# ('2017-12-26', '신과함께-죄와 벌', 8.19)
# ('2017-12-26', '오리엔트 특급 살인', 8.13)
# ('2017-12-26', '세 번째 살인', 8.11)
# ('2017-12-26', '시인의 사랑', 8.1)
# ('2017-12-26', '문라이트', 8.1)
# ('2017-12-26', '블레이드 러너 2049', 8.03)
# ('2017-12-26', '환상의 빛', 8.02)
# ('2017-12-26', '너의 췌장을 먹고 싶어', 7.96)
# ('2017-12-26', '저스티스 리그', 7.87)
# ('2017-12-26', '꾼', 7.78)
# ('2017-12-26', '메리와 마녀의 꽃', 7.36)
# ('2017-12-26', '어쌔신: 더 비기닝', 7.24)
# ('2017-12-26', '스타워즈: 라스트 제다이', 7.02)
# ('2017-12-27', '위대한 쇼맨', 9.51)
# ('2017-12-27', '다시 태어나도 우리', 9.33)
# ('2017-12-27', '나, 다니엘 블레이크', 9.22)
# ('2017-12-27', '킹 오브 프리즘 프라이드 더 히어로', 9.19)
# ('2017-12-27', '러빙 빈센트', 9.19)
# ('2017-12-27', '빠삐용', 9.17)
# ('2017-12-27', '내 사랑', 9.17)
# ('2017-12-27', '사랑과 영혼', 9.17)
# ('2017-12-27', '뽀로로 극장판 공룡섬 대모험', 9.16)
# ('2017-12-27', '공범자들', 9.16)
# ('2017-12-27', '1987', 9.15)
# ('2017-12-27', '히트', 9.11)
# ('2017-12-27', '러브레터', 9.09)
# ('2017-12-27', '물랑 루즈', 9.09)
# ('2017-12-27', '이프 온리', 9.08)
# ('2017-12-27', '극장판 포켓몬스터 너로 정했다!', 8.99)
# ('2017-12-27', '러브 액츄얼리', 8.99)
# ('2017-12-27', '안녕, 나의 소울메이트', 8.93)
# ('2017-12-27', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-27', '토르: 라그나로크', 8.87)
# ('2017-12-27', '채비', 8.85)
# ('2017-12-27', '그렇게 아버지가 된다', 8.82)
# ('2017-12-27', '아무도 모른다', 8.82)
# ('2017-12-27', '가장 따뜻한 색, 블루', 8.82)
# ('2017-12-27', '바닷마을 다이어리', 8.74)
# ('2017-12-27', '마미', 8.68)
# ('2017-12-27', '월터의 상상은 현실이 된다', 8.66)
# ('2017-12-27', '걸어도 걸어도', 8.64)
# ('2017-12-27', '몬스터 패밀리', 8.61)
# ('2017-12-27', '라라랜드', 8.6)
# ('2017-12-27', '태풍이 지나가고', 8.6)
# ('2017-12-27', '문영', 8.52)
# ('2017-12-27', '캐롤', 8.52)
# ('2017-12-27', '그녀', 8.5)
# ('2017-12-27', '강철비', 8.48)
# ('2017-12-27', '옥자', 8.46)
# ('2017-12-27', '기억의 밤', 8.33)
# ('2017-12-27', '신과함께-죄와 벌', 8.16)
# ('2017-12-27', '오리엔트 특급 살인', 8.13)
# ('2017-12-27', '시인의 사랑', 8.1)
# ('2017-12-27', '문라이트', 8.1)
# ('2017-12-27', '세 번째 살인', 8.06)
# ('2017-12-27', '블레이드 러너 2049', 8.02)
# ('2017-12-27', '환상의 빛', 8.02)
# ('2017-12-27', '너의 췌장을 먹고 싶어', 7.96)
# ('2017-12-27', '저스티스 리그', 7.87)
# ('2017-12-27', '꾼', 7.77)
# ('2017-12-27', '메리와 마녀의 꽃', 7.36)
# ('2017-12-27', '어쌔신: 더 비기닝', 7.23)
# ('2017-12-27', '스타워즈: 라스트 제다이', 7.01)
# ('2017-12-28', '위대한 쇼맨', 9.49)
# ('2017-12-28', '다시 태어나도 우리', 9.33)
# ('2017-12-28', '나, 다니엘 블레이크', 9.22)
# ('2017-12-28', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-28', '1987', 9.2)
# ('2017-12-28', '러빙 빈센트', 9.19)
# ('2017-12-28', '빠삐용', 9.17)
# ('2017-12-28', '뽀로로 극장판 공룡섬 대모험', 9.17)
# ('2017-12-28', '사랑과 영혼', 9.17)
# ('2017-12-28', '내 사랑', 9.17)
# ('2017-12-28', '공범자들', 9.16)
# ('2017-12-28', '히트', 9.11)
# ('2017-12-28', '이터널 선샤인', 9.1)
# ('2017-12-28', '러브레터', 9.09)
# ('2017-12-28', '물랑 루즈', 9.09)
# ('2017-12-28', '이프 온리', 9.08)
# ('2017-12-28', '극장판 포켓몬스터 너로 정했다!', 9.01)
# ('2017-12-28', '러브 액츄얼리', 8.99)
# ('2017-12-28', '안녕, 나의 소울메이트', 8.93)
# ('2017-12-28', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-28', '채비', 8.85)
# ('2017-12-28', '그렇게 아버지가 된다', 8.82)
# ('2017-12-28', '아무도 모른다', 8.82)
# ('2017-12-28', '가장 따뜻한 색, 블루', 8.82)
# ('2017-12-28', '바닷마을 다이어리', 8.74)
# ('2017-12-28', '마미', 8.68)
# ('2017-12-28', '월터의 상상은 현실이 된다', 8.65)
# ('2017-12-28', '걸어도 걸어도', 8.64)
# ('2017-12-28', '몬스터 패밀리', 8.64)
# ('2017-12-28', '라라랜드', 8.6)
# ('2017-12-28', '태풍이 지나가고', 8.6)
# ('2017-12-28', '문영', 8.52)
# ('2017-12-28', '캐롤', 8.52)
# ('2017-12-28', '그녀', 8.5)
# ('2017-12-28', '강철비', 8.48)
# ('2017-12-28', '옥자', 8.45)
# ('2017-12-28', '신과함께-죄와 벌', 8.15)
# ('2017-12-28', '오리엔트 특급 살인', 8.13)
# ('2017-12-28', '시인의 사랑', 8.1)
# ('2017-12-28', '문라이트', 8.1)
# ('2017-12-28', '환상의 빛', 8.02)
# ('2017-12-28', '세 번째 살인', 8.01)
# ('2017-12-28', '블레이드 러너 2049', 8.01)
# ('2017-12-28', '너의 췌장을 먹고 싶어', 7.96)
# ('2017-12-28', '꾼', 7.76)
# ('2017-12-28', '메리와 마녀의 꽃', 7.36)
# ('2017-12-28', '어쌔신: 더 비기닝', 7.23)
# ('2017-12-28', '스타워즈: 라스트 제다이', 6.99)
# ('2017-12-29', '위대한 쇼맨', 9.48)
# ('2017-12-29', '다시 태어나도 우리', 9.33)
# ('2017-12-29', '나, 다니엘 블레이크', 9.22)
# ('2017-12-29', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-29', '1987', 9.19)
# ('2017-12-29', '러빙 빈센트', 9.19)
# ('2017-12-29', '빠삐용', 9.17)
# ('2017-12-29', '뽀로로 극장판 공룡섬 대모험', 9.17)
# ('2017-12-29', '사랑과 영혼', 9.17)
# ('2017-12-29', '내 사랑', 9.17)
# ('2017-12-29', '공범자들', 9.16)
# ('2017-12-29', '히트', 9.11)
# ('2017-12-29', '이터널 선샤인', 9.1)
# ('2017-12-29', '러브레터', 9.09)
# ('2017-12-29', '물랑 루즈', 9.09)
# ('2017-12-29', '이프 온리', 9.08)
# ('2017-12-29', '극장판 포켓몬스터 너로 정했다!', 9.01)
# ('2017-12-29', '러브 액츄얼리', 8.99)
# ('2017-12-29', '안녕, 나의 소울메이트', 8.92)
# ('2017-12-29', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-29', '채비', 8.85)
# ('2017-12-29', '그렇게 아버지가 된다', 8.82)
# ('2017-12-29', '아무도 모른다', 8.82)
# ('2017-12-29', '가장 따뜻한 색, 블루', 8.82)
# ('2017-12-29', '바닷마을 다이어리', 8.74)
# ('2017-12-29', '마미', 8.68)
# ('2017-12-29', '몬스터 패밀리', 8.66)
# ('2017-12-29', '월터의 상상은 현실이 된다', 8.65)
# ('2017-12-29', '걸어도 걸어도', 8.64)
# ('2017-12-29', '라라랜드', 8.6)
# ('2017-12-29', '태풍이 지나가고', 8.6)
# ('2017-12-29', '문영', 8.52)
# ('2017-12-29', '캐롤', 8.52)
# ('2017-12-29', '그녀', 8.5)
# ('2017-12-29', '강철비', 8.48)
# ('2017-12-29', '옥자', 8.45)
# ('2017-12-29', '신과함께-죄와 벌', 8.14)
# ('2017-12-29', '오리엔트 특급 살인', 8.13)
# ('2017-12-29', '시인의 사랑', 8.1)
# ('2017-12-29', '문라이트', 8.1)
# ('2017-12-29', '세 번째 살인', 8.02)
# ('2017-12-29', '환상의 빛', 8.02)
# ('2017-12-29', '블레이드 러너 2049', 8.0)
# ('2017-12-29', '너의 췌장을 먹고 싶어', 7.96)
# ('2017-12-29', '꾼', 7.76)
# ('2017-12-29', '메리와 마녀의 꽃', 7.35)
# ('2017-12-29', '어쌔신: 더 비기닝', 7.22)
# ('2017-12-29', '스타워즈: 라스트 제다이', 6.98)
# ('2017-12-30', '원더', 9.49)
# ('2017-12-30', '위대한 쇼맨', 9.45)
# ('2017-12-30', '다시 태어나도 우리', 9.33)
# ('2017-12-30', '나, 다니엘 블레이크', 9.22)
# ('2017-12-30', '1987', 9.21)
# ('2017-12-30', '킹 오브 프리즘 프라이드 더 히어로', 9.2)
# ('2017-12-30', '러빙 빈센트', 9.18)
# ('2017-12-30', '뽀로로 극장판 공룡섬 대모험', 9.18)
# ('2017-12-30', '사랑과 영혼', 9.17)
# ('2017-12-30', '빠삐용', 9.17)
# ('2017-12-30', '내 사랑', 9.17)
# ('2017-12-30', '공범자들', 9.16)
# ('2017-12-30', '이터널 선샤인', 9.1)
# ('2017-12-30', '러브레터', 9.09)
# ('2017-12-30', '물랑 루즈', 9.09)
# ('2017-12-30', '이프 온리', 9.08)
# ('2017-12-30', '극장판 포켓몬스터 너로 정했다!', 9.0)
# ('2017-12-30', '러브 액츄얼리', 8.99)
# ('2017-12-30', '안녕, 나의 소울메이트', 8.93)
# ('2017-12-30', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-30', '채비', 8.84)
# ('2017-12-30', '아무도 모른다', 8.82)
# ('2017-12-30', '그렇게 아버지가 된다', 8.82)
# ('2017-12-30', '가장 따뜻한 색, 블루', 8.82)
# ('2017-12-30', '바닷마을 다이어리', 8.74)
# ('2017-12-30', '마미', 8.68)
# ('2017-12-30', '월터의 상상은 현실이 된다', 8.65)
# ('2017-12-30', '몬스터 패밀리', 8.65)
# ('2017-12-30', '걸어도 걸어도', 8.64)
# ('2017-12-30', '라라랜드', 8.6)
# ('2017-12-30', '태풍이 지나가고', 8.6)
# ('2017-12-30', '문영', 8.52)
# ('2017-12-30', '캐롤', 8.52)
# ('2017-12-30', '그녀', 8.5)
# ('2017-12-30', '강철비', 8.48)
# ('2017-12-30', '옥자', 8.45)
# ('2017-12-30', '오리엔트 특급 살인', 8.13)
# ('2017-12-30', '신과함께-죄와 벌', 8.12)
# ('2017-12-30', '시인의 사랑', 8.1)
# ('2017-12-30', '문라이트', 8.09)
# ('2017-12-30', '세 번째 살인', 8.03)
# ('2017-12-30', '환상의 빛', 8.02)
# ('2017-12-30', '블레이드 러너 2049', 8.0)
# ('2017-12-30', '너의 췌장을 먹고 싶어', 7.96)
# ('2017-12-30', '꾼', 7.76)
# ('2017-12-30', '메리와 마녀의 꽃', 7.35)
# ('2017-12-30', '어쌔신: 더 비기닝', 7.22)
# ('2017-12-30', '스타워즈: 라스트 제다이', 6.98)
# ('2017-12-31', '위대한 쇼맨', 9.44)
# ('2017-12-31', '원더', 9.42)
# ('2017-12-31', '다시 태어나도 우리', 9.33)
# ('2017-12-31', '1987', 9.23)
# ('2017-12-31', '나, 다니엘 블레이크', 9.22)
# ('2017-12-31', '러빙 빈센트', 9.18)
# ('2017-12-31', '뽀로로 극장판 공룡섬 대모험', 9.17)
# ('2017-12-31', '빠삐용', 9.17)
# ('2017-12-31', '사랑과 영혼', 9.17)
# ('2017-12-31', '내 사랑', 9.17)
# ('2017-12-31', '공범자들', 9.16)
# ('2017-12-31', '히트', 9.11)
# ('2017-12-31', '이터널 선샤인', 9.1)
# ('2017-12-31', '러브레터', 9.09)
# ('2017-12-31', '물랑 루즈', 9.09)
# ('2017-12-31', '이프 온리', 9.08)
# ('2017-12-31', '극장판 포켓몬스터 너로 정했다!', 8.99)
# ('2017-12-31', '러브 액츄얼리', 8.99)
# ('2017-12-31', '안녕, 나의 소울메이트', 8.94)
# ('2017-12-31', '벤자민 버튼의 시간은 거꾸로 간다', 8.87)
# ('2017-12-31', '아무도 모른다', 8.82)
# ('2017-12-31', '그렇게 아버지가 된다', 8.82)
# ('2017-12-31', '가장 따뜻한 색, 블루', 8.82)
# ('2017-12-31', '바닷마을 다이어리', 8.74)
# ('2017-12-31', '마미', 8.68)
# ('2017-12-31', '몬스터 패밀리', 8.66)
# ('2017-12-31', '월터의 상상은 현실이 된다', 8.65)
# ('2017-12-31', '걸어도 걸어도', 8.64)
# ('2017-12-31', '라라랜드', 8.6)
# ('2017-12-31', '태풍이 지나가고', 8.6)
# ('2017-12-31', '문영', 8.53)
# ('2017-12-31', '캐롤', 8.53)
# ('2017-12-31', '그녀', 8.5)
# ('2017-12-31', '강철비', 8.48)
# ('2017-12-31', '패터슨', 8.28)
# ('2017-12-31', '오리엔트 특급 살인', 8.12)
# ('2017-12-31', '시인의 사랑', 8.1)
# ('2017-12-31', '문라이트', 8.09)
# ('2017-12-31', '신과함께-죄와 벌', 8.09)
# ('2017-12-31', '세 번째 살인', 8.03)
# ('2017-12-31', '환상의 빛', 8.02)
# ('2017-12-31', '블레이드 러너 2049', 8.0)
# ('2017-12-31', '너의 췌장을 먹고 싶어', 7.96)
# ('2017-12-31', '꾼', 7.75)
# ('2017-12-31', '메리와 마녀의 꽃', 7.35)
# ('2018-03-10', '문라이트', 8.09)
# ('2018-03-10', '50가지 그림자: 해방', 8.08)
# ('2018-03-10', '너의 췌장을 먹고 싶어', 8.06)
# ('2018-03-10', '세 번째 살인', 8.05)
# ('2018-03-10', '수면의 과학', 7.96)
# ('2018-03-10', '파리로 가는 길', 7.93)
# ('2018-03-10', '신과함께-죄와 벌', 7.91)
# ('2018-03-10', '툼레이더', 7.9)
# ('2018-03-10', '블랙 팬서', 7.54)
# ('2018-03-10', '사라진 밤', 7.54)
# ('2018-03-10', '나미야 잡화점의 기적', 7.49)
# ('2018-03-10', '궁합', 7.15)
# ('2018-03-10', '조선명탐정: 흡혈괴마의 비밀', 6.82)
# ('2018-03-10', '골든슬럼버', 5.53)
# ('2018-03-10', '게이트', 4.83)

# %%
movie_cur.execute("select * from movie_table")

for result in movie_cur.fetchall():
    print(result)
# Out:
# (datetime.date(2017, 12, 1), '뷰티풀 투모로우', 9.36)
# (datetime.date(2017, 12, 1), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 1), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 1), '록키', 9.31)
# (datetime.date(2017, 12, 1), '저수지 게임', 9.29)
# (datetime.date(2017, 12, 1), '땐뽀걸즈', 9.25)
# (datetime.date(2017, 12, 1), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 1), '러빙 빈센트', 9.21)
# (datetime.date(2017, 12, 1), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 1), '킹 오브 프리즘 프라이드 더 ', 9.19)
# (datetime.date(2017, 12, 1), '내 사랑', 9.18)
# (datetime.date(2017, 12, 1), '범죄도시', 9.17)
# (datetime.date(2017, 12, 1), '공범자들', 9.16)
# (datetime.date(2017, 12, 1), '댄서', 9.13)
# (datetime.date(2017, 12, 1), '히트', 9.11)
# (datetime.date(2017, 12, 1), '이프 온리', 9.08)
# (datetime.date(2017, 12, 1), '버킷리스트: 죽기 전에 꼭 하', 9.08)
# (datetime.date(2017, 12, 1), '채비', 9.04)
# (datetime.date(2017, 12, 1), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 1), '원스', 8.99)
# (datetime.date(2017, 12, 1), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 1), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 1), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 1), '10분', 8.89)
# (datetime.date(2017, 12, 1), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 1), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 1), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 1), '넛잡 2', 8.83)
# (datetime.date(2017, 12, 1), '순정', 8.77)
# (datetime.date(2017, 12, 1), '김광석', 8.77)
# (datetime.date(2017, 12, 1), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 1), '오리엔트 특급 살인', 8.66)
# (datetime.date(2017, 12, 1), '배드 지니어스', 8.59)
# (datetime.date(2017, 12, 1), '문영', 8.55)
# (datetime.date(2017, 12, 1), '반드시 잡는다', 8.5)
# (datetime.date(2017, 12, 1), '오두막', 8.49)
# (datetime.date(2017, 12, 1), '기억의 밤', 8.49)
# (datetime.date(2017, 12, 1), '해피 데스데이', 8.37)
# (datetime.date(2017, 12, 1), '딥', 8.16)
# (datetime.date(2017, 12, 1), '더 테이블', 8.07)
# (datetime.date(2017, 12, 1), '블레이드 러너 2049', 8.02)
# (datetime.date(2017, 12, 1), '잠깐만 회사 좀 관두고 올게', 8.02)
# (datetime.date(2017, 12, 1), '너의 췌장을 먹고 싶어', 7.98)
# (datetime.date(2017, 12, 1), '메소드', 7.98)
# (datetime.date(2017, 12, 1), '저스티스 리그', 7.96)
# (datetime.date(2017, 12, 1), '프랭크', 7.95)
# (datetime.date(2017, 12, 1), '꾼', 7.92)
# (datetime.date(2017, 12, 1), '최악의 하루', 7.88)
# (datetime.date(2017, 12, 1), '침묵', 7.74)
# (datetime.date(2017, 12, 1), '부라더', 7.51)
# (datetime.date(2017, 12, 2), '뷰티풀 투모로우', 9.36)
# (datetime.date(2017, 12, 2), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 2), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 2), '록키', 9.31)
# (datetime.date(2017, 12, 2), '저수지 게임', 9.29)
# (datetime.date(2017, 12, 2), '땐뽀걸즈', 9.25)
# (datetime.date(2017, 12, 2), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 2), '러빙 빈센트', 9.21)
# (datetime.date(2017, 12, 2), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 2), '킹 오브 프리즘 프라이드 더 ', 9.19)
# (datetime.date(2017, 12, 2), '내 사랑', 9.18)
# (datetime.date(2017, 12, 2), '범죄도시', 9.17)
# (datetime.date(2017, 12, 2), '공범자들', 9.16)
# (datetime.date(2017, 12, 2), '댄서', 9.13)
# (datetime.date(2017, 12, 2), '히트', 9.11)
# (datetime.date(2017, 12, 2), '이프 온리', 9.09)
# (datetime.date(2017, 12, 2), '버킷리스트: 죽기 전에 꼭 하', 9.08)
# (datetime.date(2017, 12, 2), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 2), '채비', 8.99)
# (datetime.date(2017, 12, 2), '원스', 8.99)
# (datetime.date(2017, 12, 2), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 2), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 2), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 2), '10분', 8.89)
# (datetime.date(2017, 12, 2), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 2), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 2), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 2), '넛잡 2', 8.83)
# (datetime.date(2017, 12, 2), '순정', 8.77)
# (datetime.date(2017, 12, 2), '김광석', 8.77)
# (datetime.date(2017, 12, 2), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 2), '배드 지니어스', 8.62)
# (datetime.date(2017, 12, 2), '반드시 잡는다', 8.55)
# (datetime.date(2017, 12, 2), '문영', 8.55)
# (datetime.date(2017, 12, 2), '오리엔트 특급 살인', 8.55)
# (datetime.date(2017, 12, 2), '오두막', 8.49)
# (datetime.date(2017, 12, 2), '기억의 밤', 8.41)
# (datetime.date(2017, 12, 2), '해피 데스데이', 8.36)
# (datetime.date(2017, 12, 2), '딥', 8.16)
# (datetime.date(2017, 12, 2), '블레이드 러너 2049', 8.03)
# (datetime.date(2017, 12, 2), '잠깐만 회사 좀 관두고 올게', 8.02)
# (datetime.date(2017, 12, 2), '너의 췌장을 먹고 싶어', 7.98)
# (datetime.date(2017, 12, 2), '메소드', 7.95)
# (datetime.date(2017, 12, 2), '저스티스 리그', 7.95)
# (datetime.date(2017, 12, 2), '꾼', 7.95)
# (datetime.date(2017, 12, 2), '프랭크', 7.94)
# (datetime.date(2017, 12, 2), '최악의 하루', 7.88)
# (datetime.date(2017, 12, 2), '침묵', 7.73)
# (datetime.date(2017, 12, 2), '부라더', 7.5)
# (datetime.date(2017, 12, 2), '7호실', 6.96)
# (datetime.date(2017, 12, 3), '뷰티풀 투모로우', 9.37)
# (datetime.date(2017, 12, 3), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 3), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 3), '록키', 9.3)
# (datetime.date(2017, 12, 3), '저수지 게임', 9.29)
# (datetime.date(2017, 12, 3), '땐뽀걸즈', 9.25)
# (datetime.date(2017, 12, 3), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 3), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 3), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 3), '킹 오브 프리즘 프라이드 더 ', 9.19)
# (datetime.date(2017, 12, 3), '내 사랑', 9.18)
# (datetime.date(2017, 12, 3), '범죄도시', 9.16)
# (datetime.date(2017, 12, 3), '댄서', 9.13)
# (datetime.date(2017, 12, 3), '히트', 9.11)
# (datetime.date(2017, 12, 3), '이프 온리', 9.09)
# (datetime.date(2017, 12, 3), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 3), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 3), '원스', 8.99)
# (datetime.date(2017, 12, 3), '채비', 8.94)
# (datetime.date(2017, 12, 3), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 3), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 3), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 3), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 3), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 3), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 3), '넛잡 2', 8.83)
# (datetime.date(2017, 12, 3), '김광석', 8.77)
# (datetime.date(2017, 12, 3), '순정', 8.77)
# (datetime.date(2017, 12, 3), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 3), '배드 지니어스', 8.64)
# (datetime.date(2017, 12, 3), '오리엔트 특급 살인', 8.61)
# (datetime.date(2017, 12, 3), '문영', 8.55)
# (datetime.date(2017, 12, 3), '오두막', 8.49)
# (datetime.date(2017, 12, 3), '기억의 밤', 8.47)
# (datetime.date(2017, 12, 3), '반드시 잡는다', 8.46)
# (datetime.date(2017, 12, 3), '해피 데스데이', 8.36)
# (datetime.date(2017, 12, 3), '딥', 8.16)
# (datetime.date(2017, 12, 3), '블레이드 러너 2049', 8.02)
# (datetime.date(2017, 12, 3), '잠깐만 회사 좀 관두고 올게', 8.02)
# (datetime.date(2017, 12, 3), '너의 췌장을 먹고 싶어', 7.98)
# (datetime.date(2017, 12, 3), '꾼', 7.97)
# (datetime.date(2017, 12, 3), '저스티스 리그', 7.95)
# (datetime.date(2017, 12, 3), '프랭크', 7.94)
# (datetime.date(2017, 12, 3), '메소드', 7.94)
# (datetime.date(2017, 12, 3), '최악의 하루', 7.88)
# (datetime.date(2017, 12, 3), '침묵', 7.72)
# (datetime.date(2017, 12, 3), '부라더', 7.5)
# (datetime.date(2017, 12, 3), '7호실', 6.91)
# (datetime.date(2017, 12, 3), '유리정원', 6.88)
# (datetime.date(2017, 12, 3), '뜨거운 것이 좋아', 6.84)
# (datetime.date(2017, 12, 4), '뷰티풀 투모로우', 9.37)
# (datetime.date(2017, 12, 4), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 4), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 4), '록키', 9.3)
# (datetime.date(2017, 12, 4), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 4), '땐뽀걸즈', 9.25)
# (datetime.date(2017, 12, 4), '가위손', 9.25)
# (datetime.date(2017, 12, 4), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 4), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 4), '러빙 빈센트', 9.21)
# (datetime.date(2017, 12, 4), '킹 오브 프리즘 프라이드 더 ', 9.19)
# (datetime.date(2017, 12, 4), '내 사랑', 9.18)
# (datetime.date(2017, 12, 4), '범죄도시', 9.16)
# (datetime.date(2017, 12, 4), '댄서', 9.13)
# (datetime.date(2017, 12, 4), '히트', 9.11)
# (datetime.date(2017, 12, 4), '이프 온리', 9.09)
# (datetime.date(2017, 12, 4), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 4), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 4), '원스', 8.99)
# (datetime.date(2017, 12, 4), '채비', 8.93)
# (datetime.date(2017, 12, 4), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 4), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 4), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 4), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 4), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 4), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 4), '넛잡 2', 8.83)
# (datetime.date(2017, 12, 4), '김광석', 8.77)
# (datetime.date(2017, 12, 4), '순정', 8.77)
# (datetime.date(2017, 12, 4), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 4), '배드 지니어스', 8.64)
# (datetime.date(2017, 12, 4), '문영', 8.55)
# (datetime.date(2017, 12, 4), '반드시 잡는다', 8.51)
# (datetime.date(2017, 12, 4), '오두막', 8.49)
# (datetime.date(2017, 12, 4), '오리엔트 특급 살인', 8.48)
# (datetime.date(2017, 12, 4), '기억의 밤', 8.47)
# (datetime.date(2017, 12, 4), '해피 데스데이', 8.36)
# (datetime.date(2017, 12, 4), '딥', 8.16)
# (datetime.date(2017, 12, 4), '블레이드 러너 2049', 8.02)
# (datetime.date(2017, 12, 4), '잠깐만 회사 좀 관두고 올게', 8.02)
# (datetime.date(2017, 12, 4), '너의 췌장을 먹고 싶어', 7.98)
# (datetime.date(2017, 12, 4), '프랭크', 7.94)
# (datetime.date(2017, 12, 4), '저스티스 리그', 7.94)
# (datetime.date(2017, 12, 4), '메소드', 7.93)
# (datetime.date(2017, 12, 4), '꾼', 7.93)
# (datetime.date(2017, 12, 4), '최악의 하루', 7.88)
# (datetime.date(2017, 12, 4), '침묵', 7.72)
# (datetime.date(2017, 12, 4), '부라더', 7.49)
# (datetime.date(2017, 12, 4), '7호실', 6.88)
# (datetime.date(2017, 12, 4), '유리정원', 6.85)
# (datetime.date(2017, 12, 5), '살인의 추억', 9.37)
# (datetime.date(2017, 12, 5), '뷰티풀 투모로우', 9.36)
# (datetime.date(2017, 12, 5), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 5), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 5), '록키', 9.31)
# (datetime.date(2017, 12, 5), '시네마 천국', 9.29)
# (datetime.date(2017, 12, 5), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 5), '땐뽀걸즈', 9.26)
# (datetime.date(2017, 12, 5), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 5), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 5), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 5), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 5), '내 사랑', 9.18)
# (datetime.date(2017, 12, 5), '범죄도시', 9.16)
# (datetime.date(2017, 12, 5), '댄서', 9.13)
# (datetime.date(2017, 12, 5), '히트', 9.11)
# (datetime.date(2017, 12, 5), '이프 온리', 9.09)
# (datetime.date(2017, 12, 5), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 5), '택시운전사', 9.06)
# (datetime.date(2017, 12, 5), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 5), '원스', 8.99)
# (datetime.date(2017, 12, 5), '채비', 8.93)
# (datetime.date(2017, 12, 5), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 5), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 5), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 5), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 5), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 5), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 5), '스윗 프랑세즈', 8.82)
# (datetime.date(2017, 12, 5), '넛잡 2', 8.82)
# (datetime.date(2017, 12, 5), '순정', 8.77)
# (datetime.date(2017, 12, 5), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 5), '배드 지니어스', 8.62)
# (datetime.date(2017, 12, 5), '문영', 8.55)
# (datetime.date(2017, 12, 5), '반드시 잡는다', 8.51)
# (datetime.date(2017, 12, 5), '오두막', 8.49)
# (datetime.date(2017, 12, 5), '기억의 밤', 8.44)
# (datetime.date(2017, 12, 5), '오리엔트 특급 살인', 8.41)
# (datetime.date(2017, 12, 5), '해피 데스데이', 8.35)
# (datetime.date(2017, 12, 5), '러스트 앤 본', 8.34)
# (datetime.date(2017, 12, 5), '공조', 8.3)
# (datetime.date(2017, 12, 5), '딥', 8.16)
# (datetime.date(2017, 12, 5), '박열', 8.08)
# (datetime.date(2017, 12, 5), '잠깐만 회사 좀 관두고 올게', 8.02)
# (datetime.date(2017, 12, 5), '블레이드 러너 2049', 8.02)
# (datetime.date(2017, 12, 5), '마더', 7.99)
# (datetime.date(2017, 12, 5), '너의 췌장을 먹고 싶어', 7.98)
# (datetime.date(2017, 12, 5), '프랭크', 7.94)
# (datetime.date(2017, 12, 5), '저스티스 리그', 7.94)
# (datetime.date(2017, 12, 5), '메소드', 7.93)
# (datetime.date(2017, 12, 6), '살인의 추억', 9.37)
# (datetime.date(2017, 12, 6), '뷰티풀 투모로우', 9.36)
# (datetime.date(2017, 12, 6), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 6), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 6), '록키', 9.31)
# (datetime.date(2017, 12, 6), '시네마 천국', 9.29)
# (datetime.date(2017, 12, 6), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 6), '땐뽀걸즈', 9.26)
# (datetime.date(2017, 12, 6), '킹 오브 프리즘', 9.23)
# (datetime.date(2017, 12, 6), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 6), '흑집사 : 북 오브 더 아틀란', 9.22)
# (datetime.date(2017, 12, 6), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 6), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 6), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 6), '극장판 쿠로코의 농구 라스트 ', 9.19)
# (datetime.date(2017, 12, 6), '동급생', 9.18)
# (datetime.date(2017, 12, 6), '내 사랑', 9.18)
# (datetime.date(2017, 12, 6), '범죄도시', 9.16)
# (datetime.date(2017, 12, 6), '댄서', 9.13)
# (datetime.date(2017, 12, 6), '이프 온리', 9.09)
# (datetime.date(2017, 12, 6), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 6), '택시운전사', 9.06)
# (datetime.date(2017, 12, 6), '하이큐!! 승자와 패자', 9.03)
# (datetime.date(2017, 12, 6), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 6), '원스', 8.99)
# (datetime.date(2017, 12, 6), '채비', 8.94)
# (datetime.date(2017, 12, 6), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 6), '하이큐!! 끝과 시작', 8.91)
# (datetime.date(2017, 12, 6), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 6), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 6), '미션', 8.9)
# (datetime.date(2017, 12, 6), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 6), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 6), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 6), '스윗 프랑세즈', 8.82)
# (datetime.date(2017, 12, 6), '넛잡 2', 8.82)
# (datetime.date(2017, 12, 6), '순정', 8.77)
# (datetime.date(2017, 12, 6), '너의 이름은.', 8.75)
# (datetime.date(2017, 12, 6), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 6), '배드 지니어스', 8.62)
# (datetime.date(2017, 12, 6), '나는 내일, 어제의 너와 만난', 8.58)
# (datetime.date(2017, 12, 6), '문영', 8.53)
# (datetime.date(2017, 12, 6), '러브 라이브! 더 스쿨 아이돌', 8.53)
# (datetime.date(2017, 12, 6), '몬스터 콜', 8.5)
# (datetime.date(2017, 12, 6), '오두막', 8.49)
# (datetime.date(2017, 12, 6), '옥자', 8.46)
# (datetime.date(2017, 12, 6), '기억의 밤', 8.44)
# (datetime.date(2017, 12, 6), '반드시 잡는다', 8.43)
# (datetime.date(2017, 12, 6), '덩케르크', 8.36)
# (datetime.date(2017, 12, 6), '해피 데스데이', 8.35)
# (datetime.date(2017, 12, 7), '살인의 추억', 9.37)
# (datetime.date(2017, 12, 7), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 7), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 7), '록키', 9.3)
# (datetime.date(2017, 12, 7), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 7), '땐뽀걸즈', 9.26)
# (datetime.date(2017, 12, 7), '킹 오브 프리즘', 9.23)
# (datetime.date(2017, 12, 7), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 7), '흑집사 : 북 오브 더 아틀란', 9.22)
# (datetime.date(2017, 12, 7), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 7), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 7), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 7), '극장판 쿠로코의 농구 라스트 ', 9.19)
# (datetime.date(2017, 12, 7), '동급생', 9.18)
# (datetime.date(2017, 12, 7), '내 사랑', 9.18)
# (datetime.date(2017, 12, 7), '범죄도시', 9.16)
# (datetime.date(2017, 12, 7), '댄서', 9.13)
# (datetime.date(2017, 12, 7), '이프 온리', 9.09)
# (datetime.date(2017, 12, 7), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 7), '택시운전사', 9.06)
# (datetime.date(2017, 12, 7), '하이큐!! 승자와 패자', 9.03)
# (datetime.date(2017, 12, 7), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 7), '채비', 8.94)
# (datetime.date(2017, 12, 7), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 7), '하이큐!! 끝과 시작', 8.91)
# (datetime.date(2017, 12, 7), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 7), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 7), '미션', 8.9)
# (datetime.date(2017, 12, 7), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 7), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 7), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 7), '넛잡 2', 8.82)
# (datetime.date(2017, 12, 7), '순정', 8.77)
# (datetime.date(2017, 12, 7), '너의 이름은.', 8.75)
# (datetime.date(2017, 12, 7), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 7), '배드 지니어스', 8.61)
# (datetime.date(2017, 12, 7), '록키 호러 픽쳐 쇼', 8.57)
# (datetime.date(2017, 12, 7), '문영', 8.53)
# (datetime.date(2017, 12, 7), '러브 라이브! 더 스쿨 아이돌', 8.53)
# (datetime.date(2017, 12, 7), '메리와 마녀의 꽃', 8.53)
# (datetime.date(2017, 12, 7), '몬스터 콜', 8.5)
# (datetime.date(2017, 12, 7), '오두막', 8.49)
# (datetime.date(2017, 12, 7), '옥자', 8.46)
# (datetime.date(2017, 12, 7), '기억의 밤', 8.45)
# (datetime.date(2017, 12, 7), '반드시 잡는다', 8.39)
# (datetime.date(2017, 12, 7), '덩케르크', 8.35)
# (datetime.date(2017, 12, 7), '해피 데스데이', 8.35)
# (datetime.date(2017, 12, 7), '오리엔트 특급 살인', 8.31)
# (datetime.date(2017, 12, 7), '공조', 8.3)
# (datetime.date(2017, 12, 7), '우리의 20세기', 8.26)
# (datetime.date(2017, 12, 8), '살인의 추억', 9.37)
# (datetime.date(2017, 12, 8), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 8), '다시 태어나도 우리', 9.33)
# (datetime.date(2017, 12, 8), '록키', 9.3)
# (datetime.date(2017, 12, 8), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 8), '땐뽀걸즈', 9.26)
# (datetime.date(2017, 12, 8), '킹 오브 프리즘', 9.23)
# (datetime.date(2017, 12, 8), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 8), '흑집사 : 북 오브 더 아틀란', 9.22)
# (datetime.date(2017, 12, 8), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 8), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 8), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 8), '극장판 쿠로코의 농구 라스트 ', 9.19)
# (datetime.date(2017, 12, 8), '동급생', 9.18)
# (datetime.date(2017, 12, 8), '내 사랑', 9.18)
# (datetime.date(2017, 12, 8), '범죄도시', 9.16)
# (datetime.date(2017, 12, 8), '댄서', 9.12)
# (datetime.date(2017, 12, 8), '이프 온리', 9.09)
# (datetime.date(2017, 12, 8), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 8), '택시운전사', 9.06)
# (datetime.date(2017, 12, 8), '하이큐!! 승자와 패자', 9.03)
# (datetime.date(2017, 12, 8), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 8), '채비', 8.94)
# (datetime.date(2017, 12, 8), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 8), '하이큐!! 끝과 시작', 8.91)
# (datetime.date(2017, 12, 8), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 8), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 8), '미션', 8.9)
# (datetime.date(2017, 12, 8), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 8), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 8), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 8), '넛잡 2', 8.82)
# (datetime.date(2017, 12, 8), '순정', 8.77)
# (datetime.date(2017, 12, 8), '너의 이름은.', 8.75)
# (datetime.date(2017, 12, 8), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 8), '배드 지니어스', 8.62)
# (datetime.date(2017, 12, 8), '라라랜드', 8.59)
# (datetime.date(2017, 12, 8), '록키 호러 픽쳐 쇼', 8.57)
# (datetime.date(2017, 12, 8), '문영', 8.53)
# (datetime.date(2017, 12, 8), '러브 라이브! 더 스쿨 아이돌', 8.53)
# (datetime.date(2017, 12, 8), '몬스터 콜', 8.5)
# (datetime.date(2017, 12, 8), '오두막', 8.49)
# (datetime.date(2017, 12, 8), '메리와 마녀의 꽃', 8.48)
# (datetime.date(2017, 12, 8), '옥자', 8.46)
# (datetime.date(2017, 12, 8), '기억의 밤', 8.45)
# (datetime.date(2017, 12, 8), '반드시 잡는다', 8.35)
# (datetime.date(2017, 12, 8), '해피 데스데이', 8.35)
# (datetime.date(2017, 12, 8), '덩케르크', 8.35)
# (datetime.date(2017, 12, 8), '공조', 8.3)
# (datetime.date(2017, 12, 8), '오리엔트 특급 살인', 8.29)
# (datetime.date(2017, 12, 9), '살인의 추억', 9.37)
# (datetime.date(2017, 12, 9), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 9), '다시 태어나도 우리', 9.33)
# (datetime.date(2017, 12, 9), '록키', 9.3)
# (datetime.date(2017, 12, 9), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 9), '땐뽀걸즈', 9.26)
# (datetime.date(2017, 12, 9), '킹 오브 프리즘', 9.23)
# (datetime.date(2017, 12, 9), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 9), '흑집사 : 북 오브 더 아틀란', 9.22)
# (datetime.date(2017, 12, 9), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 9), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 9), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 9), '극장판 쿠로코의 농구 라스트 ', 9.19)
# (datetime.date(2017, 12, 9), '동급생', 9.18)
# (datetime.date(2017, 12, 9), '내 사랑', 9.18)
# (datetime.date(2017, 12, 9), '범죄도시', 9.16)
# (datetime.date(2017, 12, 9), '댄서', 9.12)
# (datetime.date(2017, 12, 9), '이프 온리', 9.09)
# (datetime.date(2017, 12, 9), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 9), '택시운전사', 9.06)
# (datetime.date(2017, 12, 9), '뽀로로 극장판 공룡섬 대모험', 9.06)
# (datetime.date(2017, 12, 9), '하이큐!! 승자와 패자', 9.03)
# (datetime.date(2017, 12, 9), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 9), '채비', 8.94)
# (datetime.date(2017, 12, 9), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 9), '하이큐!! 끝과 시작', 8.91)
# (datetime.date(2017, 12, 9), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 9), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 9), '미션', 8.9)
# (datetime.date(2017, 12, 9), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 9), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 9), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 9), '넛잡 2', 8.82)
# (datetime.date(2017, 12, 9), '순정', 8.77)
# (datetime.date(2017, 12, 9), '너의 이름은.', 8.75)
# (datetime.date(2017, 12, 9), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 9), '라라랜드', 8.59)
# (datetime.date(2017, 12, 9), '배드 지니어스', 8.59)
# (datetime.date(2017, 12, 9), '록키 호러 픽쳐 쇼', 8.57)
# (datetime.date(2017, 12, 9), '러브 라이브! 더 스쿨 아이돌', 8.53)
# (datetime.date(2017, 12, 9), '문영', 8.53)
# (datetime.date(2017, 12, 9), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 9), '옥자', 8.46)
# (datetime.date(2017, 12, 9), '기억의 밤', 8.44)
# (datetime.date(2017, 12, 9), '해피 데스데이', 8.35)
# (datetime.date(2017, 12, 9), '덩케르크', 8.34)
# (datetime.date(2017, 12, 9), '반드시 잡는다', 8.34)
# (datetime.date(2017, 12, 9), '공조', 8.3)
# (datetime.date(2017, 12, 9), '오리엔트 특급 살인', 8.27)
# (datetime.date(2017, 12, 9), '우리의 20세기', 8.26)
# (datetime.date(2017, 12, 10), '살인의 추억', 9.37)
# (datetime.date(2017, 12, 10), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 10), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 10), '록키', 9.3)
# (datetime.date(2017, 12, 10), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 10), '땐뽀걸즈', 9.26)
# (datetime.date(2017, 12, 10), '가위손', 9.25)
# (datetime.date(2017, 12, 10), '킹 오브 프리즘', 9.23)
# (datetime.date(2017, 12, 10), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 10), '흑집사 : 북 오브 더 아틀란', 9.22)
# (datetime.date(2017, 12, 10), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 10), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 10), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 10), '극장판 쿠로코의 농구 라스트 ', 9.19)
# (datetime.date(2017, 12, 10), '동급생', 9.18)
# (datetime.date(2017, 12, 10), '뽀로로 극장판 공룡섬 대모험', 9.18)
# (datetime.date(2017, 12, 10), '내 사랑', 9.18)
# (datetime.date(2017, 12, 10), '범죄도시', 9.16)
# (datetime.date(2017, 12, 10), '댄서', 9.12)
# (datetime.date(2017, 12, 10), '이프 온리', 9.09)
# (datetime.date(2017, 12, 10), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 10), '택시운전사', 9.06)
# (datetime.date(2017, 12, 10), '하이큐!! 승자와 패자', 9.03)
# (datetime.date(2017, 12, 10), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 10), '채비', 8.92)
# (datetime.date(2017, 12, 10), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 10), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 10), '하이큐!! 끝과 시작', 8.91)
# (datetime.date(2017, 12, 10), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 10), '미션', 8.9)
# (datetime.date(2017, 12, 10), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 10), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 10), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 10), '순정', 8.77)
# (datetime.date(2017, 12, 10), '너의 이름은.', 8.75)
# (datetime.date(2017, 12, 10), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 10), '라라랜드', 8.59)
# (datetime.date(2017, 12, 10), '배드 지니어스', 8.58)
# (datetime.date(2017, 12, 10), '실버라이닝 플레이북', 8.56)
# (datetime.date(2017, 12, 10), '러브 라이브! 더 스쿨 아이돌', 8.53)
# (datetime.date(2017, 12, 10), '문영', 8.53)
# (datetime.date(2017, 12, 10), '캐롤', 8.52)
# (datetime.date(2017, 12, 10), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 10), '옥자', 8.46)
# (datetime.date(2017, 12, 10), '기억의 밤', 8.43)
# (datetime.date(2017, 12, 10), '해피 데스데이', 8.34)
# (datetime.date(2017, 12, 10), '덩케르크', 8.34)
# (datetime.date(2017, 12, 10), '반드시 잡는다', 8.28)
# (datetime.date(2017, 12, 10), '우리의 20세기', 8.26)
# (datetime.date(2017, 12, 10), '언어의 정원', 8.24)
# (datetime.date(2017, 12, 11), '살인의 추억', 9.37)
# (datetime.date(2017, 12, 11), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 11), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 11), '록키', 9.3)
# (datetime.date(2017, 12, 11), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 11), '땐뽀걸즈', 9.26)
# (datetime.date(2017, 12, 11), '가위손', 9.25)
# (datetime.date(2017, 12, 11), '뽀로로 극장판 공룡섬 대모험', 9.22)
# (datetime.date(2017, 12, 11), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 11), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 11), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 11), '내 사랑', 9.17)
# (datetime.date(2017, 12, 11), '범죄도시', 9.16)
# (datetime.date(2017, 12, 11), '댄서', 9.12)
# (datetime.date(2017, 12, 11), '히트', 9.11)
# (datetime.date(2017, 12, 11), '이프 온리', 9.09)
# (datetime.date(2017, 12, 11), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 11), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 11), '파도가 지나간 자리', 8.99)
# (datetime.date(2017, 12, 11), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 11), '채비', 8.92)
# (datetime.date(2017, 12, 11), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 11), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 11), '미션', 8.9)
# (datetime.date(2017, 12, 11), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 11), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 11), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 11), '순정', 8.77)
# (datetime.date(2017, 12, 11), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 11), '라라랜드', 8.59)
# (datetime.date(2017, 12, 11), '배드 지니어스', 8.57)
# (datetime.date(2017, 12, 11), '실버라이닝 플레이북', 8.56)
# (datetime.date(2017, 12, 11), '문영', 8.53)
# (datetime.date(2017, 12, 11), '캐롤', 8.52)
# (datetime.date(2017, 12, 11), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 11), '옥자', 8.46)
# (datetime.date(2017, 12, 11), '기억의 밤', 8.42)
# (datetime.date(2017, 12, 11), '해피 데스데이', 8.34)
# (datetime.date(2017, 12, 11), '덩케르크', 8.33)
# (datetime.date(2017, 12, 11), '반드시 잡는다', 8.27)
# (datetime.date(2017, 12, 11), '우리의 20세기', 8.26)
# (datetime.date(2017, 12, 11), '오리엔트 특급 살인', 8.22)
# (datetime.date(2017, 12, 11), '문라이트', 8.1)
# (datetime.date(2017, 12, 11), '베이비 드라이버', 8.08)
# (datetime.date(2017, 12, 11), '잠깐만 회사 좀 관두고 올게', 8.01)
# (datetime.date(2017, 12, 11), '메소드', 8.0)
# (datetime.date(2017, 12, 11), '너의 췌장을 먹고 싶어', 7.97)
# (datetime.date(2017, 12, 11), '프랭크', 7.94)
# (datetime.date(2017, 12, 11), '저스티스 리그', 7.93)
# (datetime.date(2017, 12, 11), '꾼', 7.88)
# (datetime.date(2017, 12, 12), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 12), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 12), '록키', 9.3)
# (datetime.date(2017, 12, 12), '빌리 엘리어트', 9.28)
# (datetime.date(2017, 12, 12), '가위손', 9.25)
# (datetime.date(2017, 12, 12), '뽀로로 극장판 공룡섬 대모험', 9.24)
# (datetime.date(2017, 12, 12), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 12), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 12), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 12), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 12), '내 사랑', 9.17)
# (datetime.date(2017, 12, 12), '범죄도시', 9.16)
# (datetime.date(2017, 12, 12), '댄서', 9.12)
# (datetime.date(2017, 12, 12), '히트', 9.11)
# (datetime.date(2017, 12, 12), '이프 온리', 9.09)
# (datetime.date(2017, 12, 12), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 12), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 12), '파도가 지나간 자리', 8.99)
# (datetime.date(2017, 12, 12), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 12), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 12), '채비', 8.91)
# (datetime.date(2017, 12, 12), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 12), '미션', 8.9)
# (datetime.date(2017, 12, 12), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 12), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 12), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 12), '순정', 8.77)
# (datetime.date(2017, 12, 12), '마미', 8.68)
# (datetime.date(2017, 12, 12), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 12), '라라랜드', 8.6)
# (datetime.date(2017, 12, 12), '배드 지니어스', 8.58)
# (datetime.date(2017, 12, 12), '실버라이닝 플레이북', 8.56)
# (datetime.date(2017, 12, 12), '문영', 8.53)
# (datetime.date(2017, 12, 12), '캐롤', 8.52)
# (datetime.date(2017, 12, 12), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 12), '옥자', 8.46)
# (datetime.date(2017, 12, 12), '기억의 밤', 8.4)
# (datetime.date(2017, 12, 12), '덩케르크', 8.33)
# (datetime.date(2017, 12, 12), '해피 데스데이', 8.33)
# (datetime.date(2017, 12, 12), '우리의 20세기', 8.26)
# (datetime.date(2017, 12, 12), '반드시 잡는다', 8.26)
# (datetime.date(2017, 12, 12), '오리엔트 특급 살인', 8.2)
# (datetime.date(2017, 12, 12), '문라이트', 8.1)
# (datetime.date(2017, 12, 12), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 12), '잠깐만 회사 좀 관두고 올게', 8.01)
# (datetime.date(2017, 12, 12), '메소드', 7.99)
# (datetime.date(2017, 12, 12), '너의 췌장을 먹고 싶어', 7.97)
# (datetime.date(2017, 12, 12), '프랭크', 7.95)
# (datetime.date(2017, 12, 12), '저스티스 리그', 7.93)
# (datetime.date(2017, 12, 12), '최악의 하루', 7.88)
# (datetime.date(2017, 12, 13), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 13), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 13), '록키', 9.3)
# (datetime.date(2017, 12, 13), '뽀로로 극장판 공룡섬 대모험', 9.23)
# (datetime.date(2017, 12, 13), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 13), '스쿨 오브 락', 9.21)
# (datetime.date(2017, 12, 13), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 13), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 13), '파수꾼', 9.19)
# (datetime.date(2017, 12, 13), '내 사랑', 9.17)
# (datetime.date(2017, 12, 13), '범죄도시', 9.16)
# (datetime.date(2017, 12, 13), '댄서', 9.12)
# (datetime.date(2017, 12, 13), '히트', 9.11)
# (datetime.date(2017, 12, 13), '러브레터', 9.09)
# (datetime.date(2017, 12, 13), '이프 온리', 9.08)
# (datetime.date(2017, 12, 13), '버킷리스트: 죽기 전에 꼭 하', 9.07)
# (datetime.date(2017, 12, 13), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 13), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 13), '노무현입니다', 8.93)
# (datetime.date(2017, 12, 13), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 13), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 13), '행복을 찾아서', 8.9)
# (datetime.date(2017, 12, 13), '미션', 8.9)
# (datetime.date(2017, 12, 13), '채비', 8.89)
# (datetime.date(2017, 12, 13), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 13), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 13), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 13), '거인', 8.77)
# (datetime.date(2017, 12, 13), '마미', 8.68)
# (datetime.date(2017, 12, 13), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 13), '라라랜드', 8.6)
# (datetime.date(2017, 12, 13), '배드 지니어스', 8.58)
# (datetime.date(2017, 12, 13), '록키 호러 픽쳐 쇼', 8.57)
# (datetime.date(2017, 12, 13), '문영', 8.53)
# (datetime.date(2017, 12, 13), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 13), '옥자', 8.46)
# (datetime.date(2017, 12, 13), '기억의 밤', 8.37)
# (datetime.date(2017, 12, 13), '덩케르크', 8.33)
# (datetime.date(2017, 12, 13), '해피 데스데이', 8.31)
# (datetime.date(2017, 12, 13), '우리의 20세기', 8.26)
# (datetime.date(2017, 12, 13), '반드시 잡는다', 8.22)
# (datetime.date(2017, 12, 13), '오리엔트 특급 살인', 8.19)
# (datetime.date(2017, 12, 13), '문라이트', 8.1)
# (datetime.date(2017, 12, 13), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 13), '잠깐만 회사 좀 관두고 올게', 8.01)
# (datetime.date(2017, 12, 13), '메소드', 8.01)
# (datetime.date(2017, 12, 13), '너의 췌장을 먹고 싶어', 7.97)
# (datetime.date(2017, 12, 13), '프랭크', 7.95)
# (datetime.date(2017, 12, 13), '저스티스 리그', 7.93)
# (datetime.date(2017, 12, 13), '꾼', 7.87)
# (datetime.date(2017, 12, 14), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 14), '다시 태어나도 우리', 9.33)
# (datetime.date(2017, 12, 14), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 14), '뽀로로 극장판 공룡섬 대모험', 9.21)
# (datetime.date(2017, 12, 14), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 14), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 14), '파수꾼', 9.19)
# (datetime.date(2017, 12, 14), '내 사랑', 9.17)
# (datetime.date(2017, 12, 14), '범죄도시', 9.16)
# (datetime.date(2017, 12, 14), '댄서', 9.12)
# (datetime.date(2017, 12, 14), '러브레터', 9.09)
# (datetime.date(2017, 12, 14), '이프 온리', 9.08)
# (datetime.date(2017, 12, 14), '조제, 호랑이 그리고 물고기들', 9.01)
# (datetime.date(2017, 12, 14), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 14), '노무현입니다', 8.93)
# (datetime.date(2017, 12, 14), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 14), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 14), '채비', 8.9)
# (datetime.date(2017, 12, 14), '미션', 8.9)
# (datetime.date(2017, 12, 14), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 14), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 14), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 14), '거인', 8.77)
# (datetime.date(2017, 12, 14), '마미', 8.68)
# (datetime.date(2017, 12, 14), '행복한 사전', 8.67)
# (datetime.date(2017, 12, 14), '라라랜드', 8.6)
# (datetime.date(2017, 12, 14), '배드 지니어스', 8.58)
# (datetime.date(2017, 12, 14), '록키 호러 픽쳐 쇼', 8.57)
# (datetime.date(2017, 12, 14), '문영', 8.53)
# (datetime.date(2017, 12, 14), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 14), '옥자', 8.46)
# (datetime.date(2017, 12, 14), '기억의 밤', 8.37)
# (datetime.date(2017, 12, 14), '덩케르크', 8.33)
# (datetime.date(2017, 12, 14), '우리의 20세기', 8.26)
# (datetime.date(2017, 12, 14), '강철비', 8.23)
# (datetime.date(2017, 12, 14), '반드시 잡는다', 8.21)
# (datetime.date(2017, 12, 14), '오리엔트 특급 살인', 8.18)
# (datetime.date(2017, 12, 14), '스타워즈: 라스트 제다이', 8.12)
# (datetime.date(2017, 12, 14), '문라이트', 8.1)
# (datetime.date(2017, 12, 14), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 14), '잠깐만 회사 좀 관두고 올게', 8.01)
# (datetime.date(2017, 12, 14), '너의 췌장을 먹고 싶어', 7.97)
# (datetime.date(2017, 12, 14), '프랭크', 7.94)
# (datetime.date(2017, 12, 14), '저스티스 리그', 7.93)
# (datetime.date(2017, 12, 14), '꾼', 7.86)
# (datetime.date(2017, 12, 14), '메리와 마녀의 꽃', 7.61)
# (datetime.date(2017, 12, 14), '어쌔신: 더 비기닝', 7.39)
# (datetime.date(2017, 12, 14), '용순', 7.31)
# (datetime.date(2017, 12, 14), '그것', 7.02)
# (datetime.date(2017, 12, 14), '매혹당한 사람들', 6.94)
# (datetime.date(2017, 12, 15), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 15), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 15), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 15), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 15), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 15), '파수꾼', 9.19)
# (datetime.date(2017, 12, 15), '뽀로로 극장판 공룡섬 대모험', 9.18)
# (datetime.date(2017, 12, 15), '내 사랑', 9.17)
# (datetime.date(2017, 12, 15), '범죄도시', 9.16)
# (datetime.date(2017, 12, 15), '러브레터', 9.09)
# (datetime.date(2017, 12, 15), '이프 온리', 9.08)
# (datetime.date(2017, 12, 15), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 15), '노무현입니다', 8.93)
# (datetime.date(2017, 12, 15), '빅풋 주니어', 8.92)
# (datetime.date(2017, 12, 15), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 15), '미션', 8.9)
# (datetime.date(2017, 12, 15), '채비', 8.89)
# (datetime.date(2017, 12, 15), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 15), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 15), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 15), '거인', 8.77)
# (datetime.date(2017, 12, 15), '마미', 8.68)
# (datetime.date(2017, 12, 15), '라라랜드', 8.6)
# (datetime.date(2017, 12, 15), '배드 지니어스', 8.59)
# (datetime.date(2017, 12, 15), '록키 호러 픽쳐 쇼', 8.57)
# (datetime.date(2017, 12, 15), '문영', 8.53)
# (datetime.date(2017, 12, 15), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 15), '옥자', 8.46)
# (datetime.date(2017, 12, 15), '기억의 밤', 8.36)
# (datetime.date(2017, 12, 15), '덩케르크', 8.33)
# (datetime.date(2017, 12, 15), '우리의 20세기', 8.27)
# (datetime.date(2017, 12, 15), '강철비', 8.25)
# (datetime.date(2017, 12, 15), '오리엔트 특급 살인', 8.17)
# (datetime.date(2017, 12, 15), '스타워즈: 라스트 제다이', 8.14)
# (datetime.date(2017, 12, 15), '반드시 잡는다', 8.14)
# (datetime.date(2017, 12, 15), '문라이트', 8.1)
# (datetime.date(2017, 12, 15), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 15), '잠깐만 회사 좀 관두고 올게', 8.01)
# (datetime.date(2017, 12, 15), '너의 췌장을 먹고 싶어', 7.97)
# (datetime.date(2017, 12, 15), '저스티스 리그', 7.92)
# (datetime.date(2017, 12, 15), '꾼', 7.86)
# (datetime.date(2017, 12, 15), '메리와 마녀의 꽃', 7.58)
# (datetime.date(2017, 12, 15), '어쌔신: 더 비기닝', 7.36)
# (datetime.date(2017, 12, 15), '용순', 7.31)
# (datetime.date(2017, 12, 15), '그것', 7.03)
# (datetime.date(2017, 12, 15), '뜨거운 것이 좋아', 6.84)
# (datetime.date(2017, 12, 15), '페이트 스테이 나이트 헤븐즈필', 6.78)
# (datetime.date(2017, 12, 15), '7호실', 6.75)
# (datetime.date(2017, 12, 15), '불한당: 나쁜 놈들의 세상', 6.01)
# (datetime.date(2017, 12, 15), '꼭두각시', 5.47)
# (datetime.date(2017, 12, 16), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 16), '다시 태어나도 우리', 9.33)
# (datetime.date(2017, 12, 16), '시네마 천국', 9.29)
# (datetime.date(2017, 12, 16), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 16), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 16), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 16), '뽀로로 극장판 공룡섬 대모험', 9.19)
# (datetime.date(2017, 12, 16), '파수꾼', 9.19)
# (datetime.date(2017, 12, 16), '내 사랑', 9.17)
# (datetime.date(2017, 12, 16), '범죄도시', 9.16)
# (datetime.date(2017, 12, 16), '러브레터', 9.09)
# (datetime.date(2017, 12, 16), '이프 온리', 9.08)
# (datetime.date(2017, 12, 16), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 16), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 16), '미션', 8.89)
# (datetime.date(2017, 12, 16), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 16), '채비', 8.88)
# (datetime.date(2017, 12, 16), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 16), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 16), '거인', 8.77)
# (datetime.date(2017, 12, 16), '마미', 8.68)
# (datetime.date(2017, 12, 16), '라라랜드', 8.6)
# (datetime.date(2017, 12, 16), '배드 지니어스', 8.59)
# (datetime.date(2017, 12, 16), '나는 내일, 어제의 너와 만난', 8.58)
# (datetime.date(2017, 12, 16), '록키 호러 픽쳐 쇼', 8.57)
# (datetime.date(2017, 12, 16), '캐롤', 8.52)
# (datetime.date(2017, 12, 16), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 16), '옥자', 8.46)
# (datetime.date(2017, 12, 16), '강철비', 8.41)
# (datetime.date(2017, 12, 16), '기억의 밤', 8.35)
# (datetime.date(2017, 12, 16), '덩케르크', 8.32)
# (datetime.date(2017, 12, 16), '우리의 20세기', 8.27)
# (datetime.date(2017, 12, 16), '오리엔트 특급 살인', 8.16)
# (datetime.date(2017, 12, 16), '문라이트', 8.1)
# (datetime.date(2017, 12, 16), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 16), '반드시 잡는다', 8.04)
# (datetime.date(2017, 12, 16), '잠깐만 회사 좀 관두고 올게', 8.02)
# (datetime.date(2017, 12, 16), '너의 췌장을 먹고 싶어', 7.96)
# (datetime.date(2017, 12, 16), '저스티스 리그', 7.92)
# (datetime.date(2017, 12, 16), '꾼', 7.86)
# (datetime.date(2017, 12, 16), '스타워즈: 라스트 제다이', 7.78)
# (datetime.date(2017, 12, 16), '메리와 마녀의 꽃', 7.54)
# (datetime.date(2017, 12, 16), '어쌔신: 더 비기닝', 7.35)
# (datetime.date(2017, 12, 16), '용순', 7.31)
# (datetime.date(2017, 12, 16), '그것', 7.02)
# (datetime.date(2017, 12, 16), '페이트 스테이 나이트 헤븐즈필', 6.79)
# (datetime.date(2017, 12, 16), '7호실', 6.75)
# (datetime.date(2017, 12, 16), '불한당: 나쁜 놈들의 세상', 6.01)
# (datetime.date(2017, 12, 16), '꼭두각시', 5.47)
# (datetime.date(2017, 12, 17), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 17), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 17), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 17), '뽀로로 극장판 공룡섬 대모험', 9.2)
# (datetime.date(2017, 12, 17), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 17), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 17), '파수꾼', 9.19)
# (datetime.date(2017, 12, 17), '내 사랑', 9.17)
# (datetime.date(2017, 12, 17), '범죄도시', 9.16)
# (datetime.date(2017, 12, 17), '러브레터', 9.09)
# (datetime.date(2017, 12, 17), '이프 온리', 9.08)
# (datetime.date(2017, 12, 17), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 17), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 17), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 17), '채비', 8.87)
# (datetime.date(2017, 12, 17), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 17), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 17), '거인', 8.77)
# (datetime.date(2017, 12, 17), '마미', 8.68)
# (datetime.date(2017, 12, 17), '라라랜드', 8.6)
# (datetime.date(2017, 12, 17), '배드 지니어스', 8.59)
# (datetime.date(2017, 12, 17), '캐롤', 8.52)
# (datetime.date(2017, 12, 17), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 17), '옥자', 8.46)
# (datetime.date(2017, 12, 17), '강철비', 8.45)
# (datetime.date(2017, 12, 17), '기억의 밤', 8.36)
# (datetime.date(2017, 12, 17), '덩케르크', 8.32)
# (datetime.date(2017, 12, 17), '우리의 20세기', 8.27)
# (datetime.date(2017, 12, 17), '오리엔트 특급 살인', 8.16)
# (datetime.date(2017, 12, 17), '문라이트', 8.1)
# (datetime.date(2017, 12, 17), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 17), '반드시 잡는다', 8.03)
# (datetime.date(2017, 12, 17), '잠깐만 회사 좀 관두고 올게', 8.02)
# (datetime.date(2017, 12, 17), '너의 췌장을 먹고 싶어', 7.96)
# (datetime.date(2017, 12, 17), '저스티스 리그', 7.92)
# (datetime.date(2017, 12, 17), '꾼', 7.86)
# (datetime.date(2017, 12, 17), '메리와 마녀의 꽃', 7.5)
# (datetime.date(2017, 12, 17), '스타워즈: 라스트 제다이', 7.49)
# (datetime.date(2017, 12, 17), '어쌔신: 더 비기닝', 7.32)
# (datetime.date(2017, 12, 17), '용순', 7.31)
# (datetime.date(2017, 12, 17), '그것', 7.02)
# (datetime.date(2017, 12, 17), '페이트 스테이 나이트 헤븐즈필', 6.8)
# (datetime.date(2017, 12, 17), '7호실', 6.75)
# (datetime.date(2017, 12, 17), '불한당: 나쁜 놈들의 세상', 6.01)
# (datetime.date(2017, 12, 17), '꼭두각시', 5.47)
# (datetime.date(2017, 12, 18), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 18), '다시 태어나도 우리', 9.31)
# (datetime.date(2017, 12, 18), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 18), '뽀로로 극장판 공룡섬 대모험', 9.2)
# (datetime.date(2017, 12, 18), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 18), '파수꾼', 9.19)
# (datetime.date(2017, 12, 18), '내 사랑', 9.17)
# (datetime.date(2017, 12, 18), '범죄도시', 9.16)
# (datetime.date(2017, 12, 18), '이터널 선샤인', 9.1)
# (datetime.date(2017, 12, 18), '러브레터', 9.1)
# (datetime.date(2017, 12, 18), '물랑 루즈', 9.09)
# (datetime.date(2017, 12, 18), '이프 온리', 9.08)
# (datetime.date(2017, 12, 18), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 18), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 18), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 18), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 18), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 18), '채비', 8.86)
# (datetime.date(2017, 12, 18), '거인', 8.77)
# (datetime.date(2017, 12, 18), '마미', 8.68)
# (datetime.date(2017, 12, 18), '라라랜드', 8.6)
# (datetime.date(2017, 12, 18), '배드 지니어스', 8.6)
# (datetime.date(2017, 12, 18), '캐롤', 8.52)
# (datetime.date(2017, 12, 18), '몬스터 콜', 8.51)
# (datetime.date(2017, 12, 18), '강철비', 8.46)
# (datetime.date(2017, 12, 18), '옥자', 8.46)
# (datetime.date(2017, 12, 18), '기억의 밤', 8.36)
# (datetime.date(2017, 12, 18), '덩케르크', 8.32)
# (datetime.date(2017, 12, 18), '해피 데스데이', 8.29)
# (datetime.date(2017, 12, 18), '오리엔트 특급 살인', 8.15)
# (datetime.date(2017, 12, 18), '문라이트', 8.1)
# (datetime.date(2017, 12, 18), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 18), '잠깐만 회사 좀 관두고 올게', 8.02)
# (datetime.date(2017, 12, 18), '반드시 잡는다', 8.02)
# (datetime.date(2017, 12, 18), '너의 췌장을 먹고 싶어', 7.96)
# (datetime.date(2017, 12, 18), '저스티스 리그', 7.92)
# (datetime.date(2017, 12, 18), '꾼', 7.86)
# (datetime.date(2017, 12, 18), '메리와 마녀의 꽃', 7.46)
# (datetime.date(2017, 12, 18), '용순', 7.31)
# (datetime.date(2017, 12, 18), '어쌔신: 더 비기닝', 7.31)
# (datetime.date(2017, 12, 18), '스타워즈: 라스트 제다이', 7.27)
# (datetime.date(2017, 12, 18), '그것', 7.02)
# (datetime.date(2017, 12, 18), '페이트 스테이 나이트 헤븐즈필', 6.8)
# (datetime.date(2017, 12, 18), '7호실', 6.74)
# (datetime.date(2017, 12, 18), '불한당: 나쁜 놈들의 세상', 6.01)
# (datetime.date(2017, 12, 18), '꼭두각시', 5.47)
# (datetime.date(2017, 12, 19), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 19), '다시 태어나도 우리', 9.31)
# (datetime.date(2017, 12, 19), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 19), '뽀로로 극장판 공룡섬 대모험', 9.2)
# (datetime.date(2017, 12, 19), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 19), '파수꾼', 9.19)
# (datetime.date(2017, 12, 19), '내 사랑', 9.17)
# (datetime.date(2017, 12, 19), '이터널 선샤인', 9.1)
# (datetime.date(2017, 12, 19), '러브레터', 9.1)
# (datetime.date(2017, 12, 19), '물랑 루즈', 9.09)
# (datetime.date(2017, 12, 19), '이프 온리', 9.08)
# (datetime.date(2017, 12, 19), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 19), '매디슨 카운티의 다리', 8.91)
# (datetime.date(2017, 12, 19), '여배우는 오늘도', 8.89)
# (datetime.date(2017, 12, 19), '벤자민 버튼의 시간은 거꾸로 ', 8.87)
# (datetime.date(2017, 12, 19), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 19), '채비', 8.87)
# (datetime.date(2017, 12, 19), '거인', 8.77)
# (datetime.date(2017, 12, 19), '라라랜드', 8.6)
# (datetime.date(2017, 12, 19), '배드 지니어스', 8.6)
# (datetime.date(2017, 12, 19), '문영', 8.53)
# (datetime.date(2017, 12, 19), '캐롤', 8.52)
# (datetime.date(2017, 12, 19), '몬스터 콜', 8.52)
# (datetime.date(2017, 12, 19), '옥자', 8.46)
# (datetime.date(2017, 12, 19), '강철비', 8.44)
# (datetime.date(2017, 12, 19), '기억의 밤', 8.36)
# (datetime.date(2017, 12, 19), '들개', 8.35)
# (datetime.date(2017, 12, 19), '덩케르크', 8.32)
# (datetime.date(2017, 12, 19), '오리엔트 특급 살인', 8.14)
# (datetime.date(2017, 12, 19), '시인의 사랑', 8.11)
# (datetime.date(2017, 12, 19), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 19), '잠깐만 회사 좀 관두고 올게', 8.03)
# (datetime.date(2017, 12, 19), '반드시 잡는다', 7.99)
# (datetime.date(2017, 12, 19), '너의 췌장을 먹고 싶어', 7.96)
# (datetime.date(2017, 12, 19), '저스티스 리그', 7.91)
# (datetime.date(2017, 12, 19), '꾼', 7.86)
# (datetime.date(2017, 12, 19), '메리와 마녀의 꽃', 7.41)
# (datetime.date(2017, 12, 19), '용순', 7.31)
# (datetime.date(2017, 12, 19), '어쌔신: 더 비기닝', 7.3)
# (datetime.date(2017, 12, 19), '스타워즈: 라스트 제다이', 7.17)
# (datetime.date(2017, 12, 19), '그것', 7.02)
# (datetime.date(2017, 12, 19), '페이트 스테이 나이트 헤븐즈필', 6.81)
# (datetime.date(2017, 12, 19), '불한당: 나쁜 놈들의 세상', 6.01)
# (datetime.date(2017, 12, 19), '꼭두각시', 5.47)
# (datetime.date(2017, 12, 20), '위대한 쇼맨', 9.63)
# (datetime.date(2017, 12, 20), '아이 캔 스피크', 9.34)
# (datetime.date(2017, 12, 20), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 20), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 20), '뽀로로 극장판 공룡섬 대모험', 9.2)
# (datetime.date(2017, 12, 20), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 20), '러빙 빈센트', 9.2)
# (datetime.date(2017, 12, 20), '파수꾼', 9.19)
# (datetime.date(2017, 12, 20), '빠삐용', 9.17)
# (datetime.date(2017, 12, 20), '내 사랑', 9.17)
# (datetime.date(2017, 12, 20), '이터널 선샤인', 9.1)
# (datetime.date(2017, 12, 20), '러브레터', 9.1)
# (datetime.date(2017, 12, 20), '물랑 루즈', 9.09)
# (datetime.date(2017, 12, 20), '이프 온리', 9.08)
# (datetime.date(2017, 12, 20), '러브 액츄얼리', 9.0)
# (datetime.date(2017, 12, 20), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 20), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 20), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 20), '채비', 8.86)
# (datetime.date(2017, 12, 20), '거인', 8.77)
# (datetime.date(2017, 12, 20), '라라랜드', 8.6)
# (datetime.date(2017, 12, 20), '배드 지니어스', 8.6)
# (datetime.date(2017, 12, 20), '문영', 8.53)
# (datetime.date(2017, 12, 20), '캐롤', 8.52)
# (datetime.date(2017, 12, 20), '7년-그들이 없는 언론', 8.52)
# (datetime.date(2017, 12, 20), '몬스터 콜', 8.52)
# (datetime.date(2017, 12, 20), '그녀', 8.5)
# (datetime.date(2017, 12, 20), '옥자', 8.46)
# (datetime.date(2017, 12, 20), '강철비', 8.43)
# (datetime.date(2017, 12, 20), '신과함께-죄와 벌', 8.42)
# (datetime.date(2017, 12, 20), '들개', 8.35)
# (datetime.date(2017, 12, 20), '기억의 밤', 8.35)
# (datetime.date(2017, 12, 20), '덩케르크', 8.32)
# (datetime.date(2017, 12, 20), '오리엔트 특급 살인', 8.14)
# (datetime.date(2017, 12, 20), '시인의 사랑', 8.11)
# (datetime.date(2017, 12, 20), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 20), '잠깐만 회사 좀 관두고 올게', 8.03)
# (datetime.date(2017, 12, 20), '반드시 잡는다', 8.0)
# (datetime.date(2017, 12, 20), '너의 췌장을 먹고 싶어', 7.97)
# (datetime.date(2017, 12, 20), '저스티스 리그', 7.91)
# (datetime.date(2017, 12, 20), '꾼', 7.86)
# (datetime.date(2017, 12, 20), '메리와 마녀의 꽃', 7.4)
# (datetime.date(2017, 12, 20), '어쌔신: 더 비기닝', 7.3)
# (datetime.date(2017, 12, 20), '스타워즈: 라스트 제다이', 7.13)
# (datetime.date(2017, 12, 20), '그것', 7.02)
# (datetime.date(2017, 12, 20), '페이트 스테이 나이트 헤븐즈필', 6.81)
# (datetime.date(2017, 12, 20), '불한당: 나쁜 놈들의 세상', 6.01)
# (datetime.date(2017, 12, 20), '꼭두각시', 5.47)
# (datetime.date(2017, 12, 21), '위대한 쇼맨', 9.65)
# (datetime.date(2017, 12, 21), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 21), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 21), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 21), '뽀로로 극장판 공룡섬 대모험', 9.2)
# (datetime.date(2017, 12, 21), '러빙 빈센트', 9.19)
# (datetime.date(2017, 12, 21), '파수꾼', 9.19)
# (datetime.date(2017, 12, 21), '빠삐용', 9.17)
# (datetime.date(2017, 12, 21), '내 사랑', 9.17)
# (datetime.date(2017, 12, 21), '이터널 선샤인', 9.1)
# (datetime.date(2017, 12, 21), '러브레터', 9.09)
# (datetime.date(2017, 12, 21), '물랑 루즈', 9.09)
# (datetime.date(2017, 12, 21), '이프 온리', 9.08)
# (datetime.date(2017, 12, 21), '러브 액츄얼리', 9.0)
# (datetime.date(2017, 12, 21), '우린 액션배우다', 8.96)
# (datetime.date(2017, 12, 21), '여배우는 오늘도', 8.88)
# (datetime.date(2017, 12, 21), '토르: 라그나로크', 8.87)
# (datetime.date(2017, 12, 21), '채비', 8.85)
# (datetime.date(2017, 12, 21), '거인', 8.77)
# (datetime.date(2017, 12, 21), '라라랜드', 8.6)
# (datetime.date(2017, 12, 21), '배드 지니어스', 8.57)
# (datetime.date(2017, 12, 21), '문영', 8.53)
# (datetime.date(2017, 12, 21), '캐롤', 8.52)
# (datetime.date(2017, 12, 21), '7년-그들이 없는 언론', 8.52)
# (datetime.date(2017, 12, 21), '그녀', 8.5)
# (datetime.date(2017, 12, 21), '옥자', 8.46)
# (datetime.date(2017, 12, 21), '강철비', 8.42)
# (datetime.date(2017, 12, 21), '기억의 밤', 8.34)
# (datetime.date(2017, 12, 21), '신과함께-죄와 벌', 8.33)
# (datetime.date(2017, 12, 21), '오리엔트 특급 살인', 8.14)
# (datetime.date(2017, 12, 21), '시인의 사랑', 8.11)
# (datetime.date(2017, 12, 21), '베이비 드라이버', 8.07)
# (datetime.date(2017, 12, 21), '반드시 잡는다', 8.01)
# (datetime.date(2017, 12, 21), '너의 췌장을 먹고 싶어', 7.97)
# (datetime.date(2017, 12, 21), '저스티스 리그', 7.91)
# (datetime.date(2017, 12, 21), '꾼', 7.86)
# (datetime.date(2017, 12, 21), '메리와 마녀의 꽃', 7.38)
# (datetime.date(2017, 12, 21), '어쌔신: 더 비기닝', 7.28)
# (datetime.date(2017, 12, 21), '스타워즈: 라스트 제다이', 7.11)
# (datetime.date(2017, 12, 21), '그것', 7.02)
# (datetime.date(2017, 12, 21), '불한당: 나쁜 놈들의 세상', 6.01)
# (datetime.date(2017, 12, 21), '꼭두각시', 5.47)
# (datetime.date(2017, 12, 22), '위대한 쇼맨', 9.63)
# (datetime.date(2017, 12, 22), '다시 태어나도 우리', 9.32)
# (datetime.date(2017, 12, 22), '나, 다니엘 블레이크', 9.22)
# (datetime.date(2017, 12, 22), '뽀로로 극장판 공룡섬 대모험', 9.2)
# (datetime.date(2017, 12, 22), '킹 오브 프리즘 프라이드 더 ', 9.2)
# (datetime.date(2017, 12, 22), '러빙 빈센트', 9.19)
# (datetime.date(2017, 12, 22), '파수꾼', 9.19)
# (datetime.date(2017, 12, 22), '빠삐용', 9.17)
# (datetime.date(2017, 12, 22), '내 사랑', 9.17)
# (datetime.date(2017, 12, 22), '이터널 선샤인', 9.1)
# ...
# (datetime.date(2018, 3, 3), '아가씨', 7.09)
# (datetime.date(2018, 3, 3), '조선명탐정: 흡혈괴마의 비밀', 6.84)
# (datetime.date(2018, 3, 3), '골든슬럼버', 5.74)
# (datetime.date(2018, 3, 3), '게이트', 5.34)
# (datetime.date(2018, 3, 3), '흥부 글로 세상을 바꾼 자', 4.55)
# (datetime.date(2018, 3, 4), '원더', 9.39)
# (datetime.date(2018, 3, 4), '위대한 쇼맨', 9.39)
# (datetime.date(2018, 3, 4), '타이타닉', 9.29)
# (datetime.date(2018, 3, 4), '1987', 9.26)
# (datetime.date(2018, 3, 4), '코코', 9.22)
# (datetime.date(2018, 3, 4), '다키스트 아워', 9.21)
# (datetime.date(2018, 3, 4), '킹 오브 프리즘 한국어판', 9.2)
# (datetime.date(2018, 3, 4), '러빙 빈센트', 9.19)
# (datetime.date(2018, 3, 4), '빅', 9.19)
# (datetime.date(2018, 3, 4), '플립', 9.18)
# (datetime.date(2018, 3, 4), '내 사랑', 9.17)
# (datetime.date(2018, 3, 4), '패딩턴 2', 9.13)
# (datetime.date(2018, 3, 4), '비밥바룰라', 9.1)
# (datetime.date(2018, 3, 4), '불멸의 연인', 9.0)
# (datetime.date(2018, 3, 4), '그것만이 내 세상', 8.95)
# (datetime.date(2018, 3, 4), '레드 스패로', 8.89)
# (datetime.date(2018, 3, 4), '프렌즈: 몬스터 섬의 비밀', 8.88)
# (datetime.date(2018, 3, 4), '리틀 포레스트', 8.87)
# (datetime.date(2018, 3, 4), '더 포스트', 8.86)
# (datetime.date(2018, 3, 4), '12 솔져스', 8.85)
# (datetime.date(2018, 3, 4), '안녕, 나의 소울메이트', 8.83)
# (datetime.date(2018, 3, 4), '블레이드 러너', 8.73)
# (datetime.date(2018, 3, 4), '맨체스터 바이 더 씨', 8.7)
# (datetime.date(2018, 3, 4), '나는 내일, 어제의 너와 만난', 8.68)
# (datetime.date(2018, 3, 4), '셰이프 오브 워터: 사랑의 모', 8.66)
# (datetime.date(2018, 3, 4), '라라랜드', 8.6)
# (datetime.date(2018, 3, 4), 'B급 며느리', 8.57)
# (datetime.date(2018, 3, 4), '명탐정 코난 : 감벽의 관', 8.44)
# (datetime.date(2018, 3, 4), '월요일이 사라졌다', 8.33)
# (datetime.date(2018, 3, 4), '올 더 머니', 8.32)
# (datetime.date(2018, 3, 4), '패터슨', 8.31)
# (datetime.date(2018, 3, 4), '덩케르크', 8.3)
# (datetime.date(2018, 3, 4), '우리의 20세기', 8.26)
# (datetime.date(2018, 3, 4), '50가지 그림자: 해방', 8.13)
# (datetime.date(2018, 3, 4), '진주 귀걸이를 한 소녀', 8.11)
# (datetime.date(2018, 3, 4), '문라이트', 8.09)
# (datetime.date(2018, 3, 4), '세 번째 살인', 8.06)
# (datetime.date(2018, 3, 4), '너의 췌장을 먹고 싶어', 8.05)
# (datetime.date(2018, 3, 4), '수면의 과학', 7.96)
# (datetime.date(2018, 3, 4), '파리로 가는 길', 7.93)
# (datetime.date(2018, 3, 4), '신과함께-죄와 벌', 7.92)
# (datetime.date(2018, 3, 4), '나미야 잡화점의 기적', 7.59)
# (datetime.date(2018, 3, 4), '블랙 팬서', 7.55)
# (datetime.date(2018, 3, 4), '궁합', 7.45)
# (datetime.date(2018, 3, 4), '립반윙클의 신부', 7.35)
# (datetime.date(2018, 3, 4), '조선명탐정: 흡혈괴마의 비밀', 6.83)
# (datetime.date(2018, 3, 4), '골든슬럼버', 5.74)
# (datetime.date(2018, 3, 4), '게이트', 5.07)
# (datetime.date(2018, 3, 4), '흥부 글로 세상을 바꾼 자', 4.53)
# (datetime.date(2018, 3, 5), '원더', 9.39)
# (datetime.date(2018, 3, 5), '위대한 쇼맨', 9.39)
# (datetime.date(2018, 3, 5), '타이타닉', 9.29)
# (datetime.date(2018, 3, 5), '젝스키스 에이틴', 9.29)
# (datetime.date(2018, 3, 5), '1987', 9.26)
# (datetime.date(2018, 3, 5), '코코', 9.22)
# (datetime.date(2018, 3, 5), '다키스트 아워', 9.21)
# (datetime.date(2018, 3, 5), '킹 오브 프리즘 한국어판', 9.2)
# (datetime.date(2018, 3, 5), '러빙 빈센트', 9.19)
# (datetime.date(2018, 3, 5), '빅', 9.19)
# (datetime.date(2018, 3, 5), '플립', 9.18)
# (datetime.date(2018, 3, 5), '뽀로로 극장판 공룡섬 대모험', 9.17)
# (datetime.date(2018, 3, 5), '내 사랑', 9.17)
# (datetime.date(2018, 3, 5), '패딩턴 2', 9.12)
# (datetime.date(2018, 3, 5), '비밥바룰라', 9.1)
# (datetime.date(2018, 3, 5), '불멸의 연인', 9.0)
# (datetime.date(2018, 3, 5), '그것만이 내 세상', 8.95)
# (datetime.date(2018, 3, 5), '프렌즈: 몬스터 섬의 비밀', 8.88)
# (datetime.date(2018, 3, 5), '레드 스패로', 8.86)
# (datetime.date(2018, 3, 5), '리틀 포레스트', 8.85)
# (datetime.date(2018, 3, 5), '12 솔져스', 8.85)
# (datetime.date(2018, 3, 5), '더 포스트', 8.83)
# (datetime.date(2018, 3, 5), '안녕, 나의 소울메이트', 8.83)
# (datetime.date(2018, 3, 5), '블레이드 러너', 8.73)
# (datetime.date(2018, 3, 5), '맨체스터 바이 더 씨', 8.7)
# (datetime.date(2018, 3, 5), '나는 내일, 어제의 너와 만난', 8.68)
# (datetime.date(2018, 3, 5), '셰이프 오브 워터: 사랑의 모', 8.63)
# (datetime.date(2018, 3, 5), '라라랜드', 8.6)
# (datetime.date(2018, 3, 5), 'B급 며느리', 8.58)
# (datetime.date(2018, 3, 5), '명탐정 코난 : 감벽의 관', 8.43)
# (datetime.date(2018, 3, 5), '패터슨', 8.32)
# (datetime.date(2018, 3, 5), '올 더 머니', 8.32)
# (datetime.date(2018, 3, 5), '월요일이 사라졌다', 8.32)
# (datetime.date(2018, 3, 5), '덩케르크', 8.3)
# (datetime.date(2018, 3, 5), '우리의 20세기', 8.27)
# (datetime.date(2018, 3, 5), '진주 귀걸이를 한 소녀', 8.11)
# (datetime.date(2018, 3, 5), '50가지 그림자: 해방', 8.1)
# (datetime.date(2018, 3, 5), '문라이트', 8.09)
# (datetime.date(2018, 3, 5), '세 번째 살인', 8.06)
# (datetime.date(2018, 3, 5), '너의 췌장을 먹고 싶어', 8.05)
# (datetime.date(2018, 3, 5), '수면의 과학', 7.96)
# (datetime.date(2018, 3, 5), '파리로 가는 길', 7.93)
# (datetime.date(2018, 3, 5), '신과함께-죄와 벌', 7.92)
# (datetime.date(2018, 3, 5), '나미야 잡화점의 기적', 7.57)
# (datetime.date(2018, 3, 5), '블랙 팬서', 7.55)
# (datetime.date(2018, 3, 5), '궁합', 7.37)
# (datetime.date(2018, 3, 5), '립반윙클의 신부', 7.35)
# (datetime.date(2018, 3, 5), '조선명탐정: 흡혈괴마의 비밀', 6.83)
# (datetime.date(2018, 3, 5), '골든슬럼버', 5.74)
# (datetime.date(2018, 3, 5), '게이트', 5.04)
# (datetime.date(2018, 3, 6), '원더', 9.39)
# (datetime.date(2018, 3, 6), '위대한 쇼맨', 9.39)
# (datetime.date(2018, 3, 6), '타이타닉', 9.29)
# (datetime.date(2018, 3, 6), '젝스키스 에이틴', 9.29)
# (datetime.date(2018, 3, 6), '1987', 9.26)
# (datetime.date(2018, 3, 6), '코코', 9.22)
# (datetime.date(2018, 3, 6), '다키스트 아워', 9.21)
# (datetime.date(2018, 3, 6), '킹 오브 프리즘 한국어판', 9.2)
# (datetime.date(2018, 3, 6), '러빙 빈센트', 9.19)
# (datetime.date(2018, 3, 6), '빅', 9.19)
# (datetime.date(2018, 3, 6), '플립', 9.18)
# (datetime.date(2018, 3, 6), '내 사랑', 9.17)
# (datetime.date(2018, 3, 6), '패딩턴 2', 9.12)
# (datetime.date(2018, 3, 6), '비밥바룰라', 9.1)
# (datetime.date(2018, 3, 6), '불멸의 연인', 9.0)
# (datetime.date(2018, 3, 6), '그것만이 내 세상', 8.95)
# (datetime.date(2018, 3, 6), '프렌즈: 몬스터 섬의 비밀', 8.88)
# (datetime.date(2018, 3, 6), '레드 스패로', 8.86)
# (datetime.date(2018, 3, 6), '12 솔져스', 8.85)
# (datetime.date(2018, 3, 6), '리틀 포레스트', 8.83)
# (datetime.date(2018, 3, 6), '안녕, 나의 소울메이트', 8.83)
# (datetime.date(2018, 3, 6), '더 포스트', 8.81)
# (datetime.date(2018, 3, 6), '블레이드 러너', 8.73)
# (datetime.date(2018, 3, 6), '맨체스터 바이 더 씨', 8.7)
# (datetime.date(2018, 3, 6), '나는 내일, 어제의 너와 만난', 8.68)
# (datetime.date(2018, 3, 6), '셰이프 오브 워터: 사랑의 모', 8.6)
# (datetime.date(2018, 3, 6), '라라랜드', 8.6)
# (datetime.date(2018, 3, 6), 'B급 며느리', 8.59)
# (datetime.date(2018, 3, 6), '명탐정 코난 : 감벽의 관', 8.44)
# (datetime.date(2018, 3, 6), '패터슨', 8.32)
# (datetime.date(2018, 3, 6), '월요일이 사라졌다', 8.32)
# (datetime.date(2018, 3, 6), '올 더 머니', 8.31)
# (datetime.date(2018, 3, 6), '덩케르크', 8.3)
# (datetime.date(2018, 3, 6), '우리의 20세기', 8.27)
# (datetime.date(2018, 3, 6), '진주 귀걸이를 한 소녀', 8.11)
# (datetime.date(2018, 3, 6), '50가지 그림자: 해방', 8.09)
# (datetime.date(2018, 3, 6), '세 번째 살인', 8.06)
# (datetime.date(2018, 3, 6), '너의 췌장을 먹고 싶어', 8.06)
# (datetime.date(2018, 3, 6), '수면의 과학', 7.96)
# (datetime.date(2018, 3, 6), '파리로 가는 길', 7.93)
# (datetime.date(2018, 3, 6), '신과함께-죄와 벌', 7.91)
# (datetime.date(2018, 3, 6), '블랙 팬서', 7.55)
# (datetime.date(2018, 3, 6), '나미야 잡화점의 기적', 7.53)
# (datetime.date(2018, 3, 6), '립반윙클의 신부', 7.35)
# (datetime.date(2018, 3, 6), '궁합', 7.31)
# (datetime.date(2018, 3, 6), '조선명탐정: 흡혈괴마의 비밀', 6.82)
# (datetime.date(2018, 3, 6), '골든슬럼버', 5.73)
# (datetime.date(2018, 3, 6), '두 개의 문', 5.15)
# (datetime.date(2018, 3, 6), '게이트', 5.01)
# (datetime.date(2018, 3, 6), '흥부 글로 세상을 바꾼 자', 4.5)
# (datetime.date(2018, 3, 7), '원더', 9.39)
# (datetime.date(2018, 3, 7), '위대한 쇼맨', 9.39)
# (datetime.date(2018, 3, 7), '타이타닉', 9.29)
# (datetime.date(2018, 3, 7), '젝스키스 에이틴', 9.29)
# (datetime.date(2018, 3, 7), '1987', 9.26)
# (datetime.date(2018, 3, 7), '코코', 9.22)
# (datetime.date(2018, 3, 7), '킹 오브 프리즘 한국어판', 9.2)
# (datetime.date(2018, 3, 7), '다키스트 아워', 9.2)
# (datetime.date(2018, 3, 7), '러빙 빈센트', 9.19)
# (datetime.date(2018, 3, 7), '빅', 9.19)
# (datetime.date(2018, 3, 7), '플립', 9.18)
# (datetime.date(2018, 3, 7), '뽀로로 극장판 공룡섬 대모험', 9.17)
# (datetime.date(2018, 3, 7), '내 사랑', 9.17)
# (datetime.date(2018, 3, 7), '패딩턴 2', 9.12)
# (datetime.date(2018, 3, 7), '비밥바룰라', 9.1)
# (datetime.date(2018, 3, 7), '불멸의 연인', 9.01)
# (datetime.date(2018, 3, 7), '그것만이 내 세상', 8.95)
# (datetime.date(2018, 3, 7), '프렌즈: 몬스터 섬의 비밀', 8.88)
# (datetime.date(2018, 3, 7), '12 솔져스', 8.85)
# (datetime.date(2018, 3, 7), '안녕, 나의 소울메이트', 8.83)
# (datetime.date(2018, 3, 7), '더 포스트', 8.83)
# (datetime.date(2018, 3, 7), '리틀 포레스트', 8.83)
# (datetime.date(2018, 3, 7), '레드 스패로', 8.82)
# (datetime.date(2018, 3, 7), '블레이드 러너', 8.73)
# (datetime.date(2018, 3, 7), '맨체스터 바이 더 씨', 8.7)
# (datetime.date(2018, 3, 7), '나는 내일, 어제의 너와 만난', 8.68)
# (datetime.date(2018, 3, 7), '라라랜드', 8.6)
# (datetime.date(2018, 3, 7), 'B급 며느리', 8.59)
# (datetime.date(2018, 3, 7), '셰이프 오브 워터: 사랑의 모', 8.57)
# (datetime.date(2018, 3, 7), '명탐정 코난 : 감벽의 관', 8.45)
# (datetime.date(2018, 3, 7), '올 더 머니', 8.32)
# (datetime.date(2018, 3, 7), '패터슨', 8.31)
# (datetime.date(2018, 3, 7), '덩케르크', 8.3)
# (datetime.date(2018, 3, 7), '월요일이 사라졌다', 8.3)
# (datetime.date(2018, 3, 7), '우리의 20세기', 8.27)
# (datetime.date(2018, 3, 7), '진주 귀걸이를 한 소녀', 8.11)
# (datetime.date(2018, 3, 7), '50가지 그림자: 해방', 8.09)
# (datetime.date(2018, 3, 7), '문라이트', 8.09)
# (datetime.date(2018, 3, 7), '세 번째 살인', 8.06)
# (datetime.date(2018, 3, 7), '너의 췌장을 먹고 싶어', 8.05)
# (datetime.date(2018, 3, 7), '수면의 과학', 7.96)
# (datetime.date(2018, 3, 7), '파리로 가는 길', 7.93)
# (datetime.date(2018, 3, 7), '신과함께-죄와 벌', 7.91)
# (datetime.date(2018, 3, 7), '블랙 팬서', 7.54)
# (datetime.date(2018, 3, 7), '나미야 잡화점의 기적', 7.52)
# (datetime.date(2018, 3, 7), '궁합', 7.26)
# (datetime.date(2018, 3, 7), '조선명탐정: 흡혈괴마의 비밀', 6.82)
# (datetime.date(2018, 3, 7), '골든슬럼버', 5.69)
# (datetime.date(2018, 3, 7), '두 개의 문', 5.15)
# (datetime.date(2018, 3, 7), '게이트', 4.95)
# (datetime.date(2018, 3, 8), '원더', 9.4)
# (datetime.date(2018, 3, 8), '위대한 쇼맨', 9.39)
# (datetime.date(2018, 3, 8), '타이타닉', 9.29)
# (datetime.date(2018, 3, 8), '젝스키스 에이틴', 9.27)
# (datetime.date(2018, 3, 8), '1987', 9.26)
# (datetime.date(2018, 3, 8), '코코', 9.22)
# (datetime.date(2018, 3, 8), '러빙 빈센트', 9.19)
# (datetime.date(2018, 3, 8), '킹 오브 프리즘 한국어판', 9.19)
# (datetime.date(2018, 3, 8), '빅', 9.19)
# (datetime.date(2018, 3, 8), '플립', 9.18)
# (datetime.date(2018, 3, 8), '뽀로로 극장판 공룡섬 대모험', 9.17)
# (datetime.date(2018, 3, 8), '내 사랑', 9.17)
# (datetime.date(2018, 3, 8), '패딩턴 2', 9.12)
# (datetime.date(2018, 3, 8), '다키스트 아워', 9.11)
# (datetime.date(2018, 3, 8), '비밥바룰라', 9.1)
# (datetime.date(2018, 3, 8), '불멸의 연인', 9.01)
# (datetime.date(2018, 3, 8), '그것만이 내 세상', 8.95)
# (datetime.date(2018, 3, 8), '프렌즈: 몬스터 섬의 비밀', 8.88)
# (datetime.date(2018, 3, 8), '12 솔져스', 8.85)
# (datetime.date(2018, 3, 8), '안녕, 나의 소울메이트', 8.83)
# (datetime.date(2018, 3, 8), '더 포스트', 8.83)
# (datetime.date(2018, 3, 8), '레드 스패로', 8.82)
# (datetime.date(2018, 3, 8), '리틀 포레스트', 8.82)
# (datetime.date(2018, 3, 8), '맨체스터 바이 더 씨', 8.7)
# (datetime.date(2018, 3, 8), '나는 내일, 어제의 너와 만난', 8.68)
# (datetime.date(2018, 3, 8), '라라랜드', 8.6)
# (datetime.date(2018, 3, 8), 'B급 며느리', 8.59)
# (datetime.date(2018, 3, 8), '셰이프 오브 워터: 사랑의 모', 8.56)
# (datetime.date(2018, 3, 8), '명탐정 코난 : 감벽의 관', 8.44)
# (datetime.date(2018, 3, 8), '올 더 머니', 8.32)
# (datetime.date(2018, 3, 8), '패터슨', 8.31)
# (datetime.date(2018, 3, 8), '덩케르크', 8.3)
# (datetime.date(2018, 3, 8), '월요일이 사라졌다', 8.3)
# (datetime.date(2018, 3, 8), '우리의 20세기', 8.27)
# (datetime.date(2018, 3, 8), '진주 귀걸이를 한 소녀', 8.11)
# (datetime.date(2018, 3, 8), '문라이트', 8.09)
# (datetime.date(2018, 3, 8), '50가지 그림자: 해방', 8.07)
# (datetime.date(2018, 3, 8), '너의 췌장을 먹고 싶어', 8.06)
# (datetime.date(2018, 3, 8), '세 번째 살인', 8.06)
# (datetime.date(2018, 3, 8), '수면의 과학', 7.96)
# (datetime.date(2018, 3, 8), '파리로 가는 길', 7.93)
# (datetime.date(2018, 3, 8), '신과함께-죄와 벌', 7.91)
# (datetime.date(2018, 3, 8), '사라진 밤', 7.73)
# (datetime.date(2018, 3, 8), '툼레이더', 7.58)
# (datetime.date(2018, 3, 8), '블랙 팬서', 7.54)
# (datetime.date(2018, 3, 8), '나미야 잡화점의 기적', 7.51)
# (datetime.date(2018, 3, 8), '궁합', 7.22)
# (datetime.date(2018, 3, 8), '조선명탐정: 흡혈괴마의 비밀', 6.82)
# (datetime.date(2018, 3, 8), '골든슬럼버', 5.62)
# (datetime.date(2018, 3, 8), '두 개의 문', 5.15)
# (datetime.date(2018, 3, 9), '원더', 9.4)
# (datetime.date(2018, 3, 9), '위대한 쇼맨', 9.39)
# (datetime.date(2018, 3, 9), '타이타닉', 9.29)
# (datetime.date(2018, 3, 9), '젝스키스 에이틴', 9.27)
# (datetime.date(2018, 3, 9), '코코', 9.22)
# (datetime.date(2018, 3, 9), '러빙 빈센트', 9.19)
# (datetime.date(2018, 3, 9), '킹 오브 프리즘 한국어판', 9.19)
# (datetime.date(2018, 3, 9), '빅', 9.19)
# (datetime.date(2018, 3, 9), '플립', 9.18)
# (datetime.date(2018, 3, 9), '뽀로로 극장판 공룡섬 대모험', 9.17)
# (datetime.date(2018, 3, 9), '내 사랑', 9.17)
# (datetime.date(2018, 3, 9), '다키스트 아워', 9.12)
# (datetime.date(2018, 3, 9), '패딩턴 2', 9.12)
# (datetime.date(2018, 3, 9), '비밥바룰라', 9.11)
# (datetime.date(2018, 3, 9), '불멸의 연인', 9.0)
# (datetime.date(2018, 3, 9), '그것만이 내 세상', 8.95)
# (datetime.date(2018, 3, 9), '프렌즈: 몬스터 섬의 비밀', 8.89)
# (datetime.date(2018, 3, 9), '12 솔져스', 8.85)
# (datetime.date(2018, 3, 9), '레드 스패로', 8.83)
# (datetime.date(2018, 3, 9), '더 포스트', 8.83)
# (datetime.date(2018, 3, 9), '리틀 포레스트', 8.81)
# (datetime.date(2018, 3, 9), '맨체스터 바이 더 씨', 8.7)
# (datetime.date(2018, 3, 9), '나는 내일, 어제의 너와 만난', 8.68)
# (datetime.date(2018, 3, 9), 'B급 며느리', 8.6)
# (datetime.date(2018, 3, 9), '라라랜드', 8.6)
# (datetime.date(2018, 3, 9), '셰이프 오브 워터: 사랑의 모', 8.55)
# (datetime.date(2018, 3, 9), '명탐정 코난 : 감벽의 관', 8.45)
# (datetime.date(2018, 3, 9), '올 더 머니', 8.32)
# (datetime.date(2018, 3, 9), '월요일이 사라졌다', 8.32)
# (datetime.date(2018, 3, 9), '패터슨', 8.31)
# (datetime.date(2018, 3, 9), '덩케르크', 8.3)
# (datetime.date(2018, 3, 9), '우리의 20세기', 8.27)
# (datetime.date(2018, 3, 9), '진주 귀걸이를 한 소녀', 8.11)
# (datetime.date(2018, 3, 9), '문라이트', 8.09)
# (datetime.date(2018, 3, 9), '50가지 그림자: 해방', 8.07)
# (datetime.date(2018, 3, 9), '너의 췌장을 먹고 싶어', 8.06)
# (datetime.date(2018, 3, 9), '세 번째 살인', 8.05)
# (datetime.date(2018, 3, 9), '수면의 과학', 7.96)
# (datetime.date(2018, 3, 9), '툼레이더', 7.95)
# (datetime.date(2018, 3, 9), '파리로 가는 길', 7.93)
# (datetime.date(2018, 3, 9), '신과함께-죄와 벌', 7.91)
# (datetime.date(2018, 3, 9), '사라진 밤', 7.7)
# (datetime.date(2018, 3, 9), '블랙 팬서', 7.54)
# (datetime.date(2018, 3, 9), '나미야 잡화점의 기적', 7.51)
# (datetime.date(2018, 3, 9), '궁합', 7.19)
# (datetime.date(2018, 3, 9), '조선명탐정: 흡혈괴마의 비밀', 6.82)
# (datetime.date(2018, 3, 9), '골든슬럼버', 5.57)
# (datetime.date(2018, 3, 9), '두 개의 문', 5.15)
# (datetime.date(2018, 3, 9), '게이트', 4.84)
# (datetime.date(2018, 3, 10), '원더', 9.4)
# (datetime.date(2018, 3, 10), '위대한 쇼맨', 9.39)
# (datetime.date(2018, 3, 10), '젝스키스 에이틴', 9.29)
# (datetime.date(2018, 3, 10), '타이타닉', 9.29)
# (datetime.date(2018, 3, 10), '1987', 9.26)
# (datetime.date(2018, 3, 10), '코코', 9.22)
# (datetime.date(2018, 3, 10), '러빙 빈센트', 9.19)
# (datetime.date(2018, 3, 10), '킹 오브 프리즘 한국어판', 9.19)
# (datetime.date(2018, 3, 10), '빅', 9.19)
# (datetime.date(2018, 3, 10), '플립', 9.18)
# (datetime.date(2018, 3, 10), '뽀로로 극장판 공룡섬 대모험', 9.17)
# (datetime.date(2018, 3, 10), '내 사랑', 9.17)
# (datetime.date(2018, 3, 10), '패딩턴 2', 9.12)
# (datetime.date(2018, 3, 10), '비밥바룰라', 9.11)
# (datetime.date(2018, 3, 10), '다키스트 아워', 9.1)
# (datetime.date(2018, 3, 10), '불멸의 연인', 9.0)
# (datetime.date(2018, 3, 10), '그것만이 내 세상', 8.95)
# (datetime.date(2018, 3, 10), '프렌즈: 몬스터 섬의 비밀', 8.88)
# (datetime.date(2018, 3, 10), '12 솔져스', 8.85)
# (datetime.date(2018, 3, 10), '더 포스트', 8.84)
# (datetime.date(2018, 3, 10), '레드 스패로', 8.82)
# (datetime.date(2018, 3, 10), '리틀 포레스트', 8.82)
# (datetime.date(2018, 3, 10), '맨체스터 바이 더 씨', 8.7)
# (datetime.date(2018, 3, 10), '나는 내일, 어제의 너와 만난', 8.68)
# (datetime.date(2018, 3, 10), '라라랜드', 8.6)
# (datetime.date(2018, 3, 10), 'B급 며느리', 8.6)
# (datetime.date(2018, 3, 10), '셰이프 오브 워터: 사랑의 모', 8.53)
# (datetime.date(2018, 3, 10), '명탐정 코난 : 감벽의 관', 8.45)
# (datetime.date(2018, 3, 10), '올 더 머니', 8.32)
# (datetime.date(2018, 3, 10), '월요일이 사라졌다', 8.32)
# (datetime.date(2018, 3, 10), '패터슨', 8.31)
# (datetime.date(2018, 3, 10), '덩케르크', 8.3)
# (datetime.date(2018, 3, 10), '우리의 20세기', 8.27)
# (datetime.date(2018, 3, 10), '진주 귀걸이를 한 소녀', 8.11)
# (datetime.date(2018, 3, 10), '문라이트', 8.09)
# (datetime.date(2018, 3, 10), '50가지 그림자: 해방', 8.08)
# (datetime.date(2018, 3, 10), '너의 췌장을 먹고 싶어', 8.06)
# (datetime.date(2018, 3, 10), '세 번째 살인', 8.05)
# (datetime.date(2018, 3, 10), '수면의 과학', 7.96)
# (datetime.date(2018, 3, 10), '파리로 가는 길', 7.93)
# (datetime.date(2018, 3, 10), '신과함께-죄와 벌', 7.91)
# (datetime.date(2018, 3, 10), '툼레이더', 7.9)
# (datetime.date(2018, 3, 10), '블랙 팬서', 7.54)
# (datetime.date(2018, 3, 10), '사라진 밤', 7.54)
# (datetime.date(2018, 3, 10), '나미야 잡화점의 기적', 7.49)
# (datetime.date(2018, 3, 10), '궁합', 7.15)
# (datetime.date(2018, 3, 10), '조선명탐정: 흡혈괴마의 비밀', 6.82)
# (datetime.date(2018, 3, 10), '골든슬럼버', 5.53)
# (datetime.date(2018, 3, 10), '게이트', 4.83)

# %%
movie.close()

# %%
import pandas as pd
def_df = pd.read_csv('../sql/data/def.csv')
def_df
# Out:
#            코드        명칭                      주소           전화번호  \
# 0    A0013146  현풍(마산방향)       대구 달성군 현풍읍 성하길 48   053-614-2437
# 1    A0010223  언양(서울방향)    울산 울주군 언양읍 경부고속도로 44   052-263-6146
# 2    A0033516  울주(울산방향)  울산 울주군 삼동면 보은리 산213-15   052-977-2243
# 3    A0033517  울주(함양방향)   울산 울주군 삼동면 보은리 산192-3   052-977-3243
# 4    A0033432  구리(일산방향)   경기도 구리시 수도권 제1순환도로 32   031-555-0740
# ..        ...       ...                     ...            ...
# 106  A0029171    내트럭 울산           울산 남구 산업로 100   052-998-8484
# 107  A0033222  내트럭 울산약수          울산 북구 산업로 1515   052-946-2200
# 108  A0022484    내트럭 여수        전남 여수시 여수산단로 140  070-8740-2803
# 109  A0033447    내트럭 김해     경남 김해시 진영읍 김해대로 243   055-903-2600
# 110  A0032994      첨단용두         광주 북구 빛고을대로 663  062-572-5189
#
#                영업시간   재고량
# 0           매일 24시간  1300
# 1           매일 24시간  4496
# 2           매일 24시간  3024
# 3           매일 24시간  2571
# 4           매일 24시간   112
# ..              ...   ...
# 106        평일 24시간     80
# 107        평일 24시간      0
# 108  평일 06:00~24:00   427
# 109  평일 06:00~23:00   700
# 110  매일 05:00~24:00   500
#
# [111 rows x 6 columns]

# %% [markdown]
# ## 퀴즈 2번

# %%
import mysql.connector

## connect 준비
def_con = mysql.connector.connect(
    host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "admin",
    password = "dltnals123$",
    database = "armbase"
)

## 커서 선언
def_cur = def_con.cursor(buffered=True)

## 테이블 만들기 쿼리
create_table = '''create table def_table (code varchar(16), name varchar(16), address varchar(32), 
                                          phonenum varchar(16), time varchar(16), cargo int)'''
def_cur.execute(create_table)

## 값 넣어주기 쿼리
insert_value = "insert into def_table values (%s, %s, %s, %s, %s, %s)"

## 커밋
for idx, row in def_df.iterrows():
    def_cur.execute(insert_value, tuple(row))
    def_con.commit()

def_cur.execute("select * from def_table")

## 결과 확인
for result in def_cur.fetchall():
    print(result)

## 연결 해제
def_con.close()
# Out:
# ('A0013146', '현풍(마산방향)', '대구 달성군 현풍읍 성하길 48', '053-614-2437', '매일 24시간', 1300)
# ('A0010223', '언양(서울방향)', '울산 울주군 언양읍 경부고속도로 44', '052-263-6146', '매일 24시간', 4496)
# ('A0033516', '울주(울산방향)', '울산 울주군 삼동면 보은리 산213-15', '052-977-2243', '매일 24시간', 3024)
# ('A0033517', '울주(함양방향)', '울산 울주군 삼동면 보은리 산192-3', '052-977-3243', '매일 24시간', 2571)
# ('A0033432', '구리(일산방향)', '경기도 구리시 수도권 제1순환도로 32', '031-555-0740', '매일 24시간', 112)
# ('A0003399', '안성(서울방향)', '경기도 안성시 원곡면 경부고속도로 372', '031-664-4096', '매일 24시간', 4200)
# ('A0004088', '이천(통영방향)', '경기도 이천시 마장면 중부대로609번길 244-35', '031-637-0401', '매일 24시간', 138)
# ('A0033485', '평택(제천방향)', '경기도 평택시 청북읍 평택제천고속도로 6', '070-4172-8087', '매일 24시간', 2380)
# ('A0033482', '평택(평택방향)', '경기도 평택시 청북읍 평택제천고속도로 6', '070-4172-8085', '매일 24시간', 1950)
# ('A0002561', '화성(목포방향)', '경기도 화성시 팔탄면 서해안고속도로 301', '031-353-8015', '매일 24시간', 1150)
# ('A0009013', '송산포도(시흥방향)', '경기도 화성시 송산면 평택시흥고속도로 25', '031-357-8192', '매일 24시간', 650)
# ('A0009012', '송산포도(평택방향)', '경기도 화성시 송산면 평택시흥고속도로 25', '031-357-8194', '매일 24시간', 7500)
# ('A0010209', '안성맞춤(제천방향)', '경기도 안성시 서운면 평택제천고속도로 40', '031-674-4406', '매일 24시간', 74)
# ('A0012447', '옥산(부산방향)', '충북 청주시 흥덕구 옥산면 경부고속도로 309', '043-269-0843', '매일 24시간', 173)
# ('A0012713', '옥천(서울방향)', '충북 옥천군 옥천읍 옥천동이로 242-34', '043-733-9924', '매일 24시간', 3250)
# ('A0012719', '옥천만남의광장', '충북 옥천군 옥천읍 중앙로 137', '043-732-0081', '매일 24시간', 4273)
# ('A0017406', '죽암(서울방향)', '충북 청주시 서원구 현도면 경부고속도로 290', '043-260-5341', '매일 24시간', 142)
# ('A0012711', '황간(부산방향)', '충북 영동군 황간면 회포길 102', '043-742-5853', '매일 24시간', 63)
# ('A0012712', '황간(서울방향)', '충북 영동군 황간면 회포1길 65 ', '043-742-1266', '매일 24시간', 2665)
# ('A0013260', '괴산(마산방향)', '충북 괴산군 장연면 중부내륙고속도로 205', '043-832-7970', '매일 24시간', 1872)
# ('A0013261', '금왕(제천방향)', '충북 음성군 금왕읍 평택제천고속도로 70', '043-881-8122 ', '매일 24시간', 516)
# ('A0013262', '금왕(평택방향)', '충북 음성군 금왕읍 평택제천고속도로 69', '043-882-8030', '매일 24시간', 1336)
# ('A0012717', '속리산(청주방향)', '충북 보은군 마로면 적암길 56-18', '043-544-6311', '매일 24시간', 1260)
# ('A0013211', '음성(하남방향)', '충북 음성군 삼성면 중부고속도로 52', '043-877-1086', '매일 24시간', 1472)
# ('A0032874', '천등산(평택방향)', '충북 충주시 산척면 평택제천고속도로109 ', '043-844-2915', '매일 24시간', 1680)
# ('A0013244', '충주(창원방향)', '충북 충주시 중앙탑면 중부내륙고속도로 231-1', '043-857-7371', '매일 24시간', 7095)
# ('A0015572', '망향(부산방향)', '충남 천안시 서북구 성거읍 돌다리길23-27', '041-557-6161', '매일 24시간', 250)
# ('A0004009', '입장거봉포도(서울방향)', '충남 천안시 서북구 입장면 연곡길407', '041-588-2184', '매일 24시간', 612)
# ('A0016127', '천안호두(부산방향)', '충남 천안시 동남구 수신면 성남로 793-40', '041-552-6367', '매일 24시간', 550)
# ('A0014844', '벌곡(논산방향)', '충남 논산시 벌곡면 호남지선고속도로 25', '041-733-7487', '매일 24시간', 1110)
# ('A0014831', '벌곡(대전방향)', '충남 논산시 벌곡면 벌곡로 9-58', '041-732-3991', '매일 24시간', 1892)
# ('A0014468', '정안알밤(서울방향)', '충남 공주시 정안면 논산천안고속도로 58', '041-858-0565', '평일 24시간', 0)
# ('A0014469', '정안알밤(논산방향)', '충남 공주시 정안면 논산천안고속도로 57', '041-858-0531', '매일 24시간', 6000)
# ('A0019044', '고창고인돌(목포방향)', '전북 고창군 신림면 서해안고속도로 81-1', '063-561-6318', '매일 24시간', 2336)
# ('A0019045', '고창고인돌(서울방향)', '전북 고창군 고창읍 서해안고속도로 80-1', '063-561-0962', '매일 24시간', 1722)
# ('A0017711', '군산(서울방향)', '전북 군산시 나포면 서해안고속도로 148', '063-453-5163', '매일 24시간', 3970)
# ('A0018666', '여산(순천방향)', '전북 익산시 여산면 호남고속도로 191', '063-836-5246', '매일 24시간', 32)
# ('A0018725', '여산(천안방향)', '전북 익산시 여산면 호남고속도로 192 ', '063-836-5272', '매일 24시간', 200)
# ('A0009924', '이서(순천방향)', '전북 완주군 이서면 호남고속도로 161', '063-227-4334', '매일 24시간', 214)
# ('A0009923', '이서(천안방향)', '전북 완주군 이서면 호남고속도로 162 ', '063-236-4400', '매일 24시간', 79)
# ('A0019048', '정읍녹두장군(천안방향)', '전북 정읍시 북면 하북1길 227-17', '063-533-0903', '매일 24시간', 284)
# ('A0009922', '오수(광양방향)', '전북 임실군 오수면 순천완주고속도로 73', '063-644-7300', '매일 24시간', 0)
# ('A0009921', '오수(전주방향)', '전북 임실군 오수면 순천완주고속도로 74', '063-644-4800', '매일 24시간', 650)
# ('A0022202', '황전(순천방향)', '전남 순천시 황전면 순천완주고속도로 25', '062-782-1737', '매일 24시간', 2430)
# ('A0022203', '황전(전주방향)', '전남 순천시 황전면 순천완주고속도로 28', '061-782-1701', '매일 24시간', 3230)
# ('A0025685', '문경(양평방향)', '경북 문경시 중부내륙고속도로 174-1', '054-554-1614', '매일 24시간', 575)
# ('A0025694', '문경(창원방향)', '경북 문경시 중부내륙고속도로173-1', '054-554-1659', '매일 24시간', 1142)
# ('A0010221', '화서(상주방향)', '경북 상주시 화서면 터골길51-25 ', '054-531-1984', '매일 24시간', 2265)
# ('A0033068', '건천(부산방향)', '경북 경주시 건천읍 경부고속도로 77', '054-751-4600', '매일 24시간', 4269)
# ('A0025176', '군위(부산방향)', '경북 군위군 군위읍 경북대로 4084', '054-383-6116', '매일 24시간', 3120)
# ('A0025177', '군위(춘천방향)', '경북 군위군 군위읍 경북대로 4082', '054-383-6117', '매일 24시간', 2417)
# ('A0033176', '삼국유사군위(상주방향)', '경북 군위군 부계면 치산효령로 989-23', '054-383-8842', '매일 24시간', 2530)
# ('A0033178', '군위영천(영천방향)', '경북 군위군 산성면 치산효령로 865-43', '054-383-9014', '매일 24시간', 1342)
# ('A0025495', '김천(부산방향)', '경북 김천시 농소면 경부고속도로 193', '054-435-0266', '매일 24시간', 1000)
# ('A0025491', '김천(서울방향)', '경북 김천시 농소면경부고속도로194 ', '054-431-4477', '매일 24시간', 2780)
# ('A0025492', '남성주참외(양평방향)', '경북 성주군 선남면 중부내륙고속도로 76', '054-931-5149', '매일 24시간', 1)
# ('A0025494', '남성주참외(창원방향)', '경북 성주군 선남면 중부내륙고속도로 77', '054-932-0031', '매일 24시간', 1151)
# ('A0033257', '성주(양평방향)', '경북 성주군 초전면 중부내륙고속도로 98', '054-933-0820', '매일 24시간', 4706)
# ('A0033258', '성주(창원방향)', '경북 성주군 초전면 중부내륙고속도로 97', '054-932-1200', '매일 24시간', 4714)
# ('A0024288', '영천(대구방향)', '경북 영천시 임고면 운주로 791', '054-338-9301', '매일 24시간', 300)
# ('A0027009', '와촌(포항방향)', '경북 경산시 와촌면 강학길 103', '053-853-1082', '매일 24시간', 1543)
# ('A0024296', '청통(대구방향)', '경북 영천시 청통면 청통로 334-42', '054-337-5074', '매일 24시간', 2622)
# ('A0025482', '추풍령(부산방향)', '경북 김천시 봉산면 경부고속도로 213', '054-430-0502', '매일 24시간', 2545)
# ('A0033259', '김해금관가야(기장방향)', '경남 김해시 대동면 동남로 400', '055-312-2862', '매일 24시간', 1710)
# ('A0033260', '김해금관가야(창원방향)', '경남 김해시 대동면 월촌리 761', '055-312-2864', '매일 24시간', 1412)
# ('A0030173', '문산(순천방향)', '경남 진주시 문산읍 남해고속도로 195', '055-762-2048', '매일 24시간', 1926)
# ('A0030186', '사천(부산방향)', '경남 사천시 곤양면 서삼로 619', '055-854-8622', '매일 24시간', 1997)
# ('A0030185', '사천(순천방향)', '경남 사천시 곤양면 묵실길 31-11', '055-854-6732', '매일 24시간', 3003)
# ('A0030119', '산청(하남방향)', '경남 산청군 단성면 통영대전고속도로76 ', '055-973-6138', '매일 24시간', 1900)
# ('A0028434', '영산(마산방향)', '경남 창녕군 영산면 장척호수길 56-110', '055-521-3284', '매일 24시간', 3550)
# ('A0033505', '진영(부산방향)', '경남 김해시 진영읍 하계로96번길 94-4', '055-342-8700', '매일 24시간', 6000)
# ('A0030770', '진영(순천방향)', '경남 김해시 진영읍 하계로96번길 68', '055-342-0878', '매일 24시간', 2500)
# ('A0032977', '진주(부산방향)', '경남 진주시 남해고속도로 194', '055-759-1028', '매일 24시간', 200)
# ('A0028437', '칠서(양평방향)', '경남 함안군 칠서면 계룡로 122-1', '055-587-1420', '매일 24시간', 2330)
# ('A0032083', '통도사(부산방향)', '경남 양산시 하북면 경부고속도로 31-1', '055-372-6163', '매일 24시간', 2796)
# ('A0031971', '함안(부산방향)', '경남 함안군 군북면 현포로 205', '055-583-9341', '매일 24시간', 1253)
# ('A0028480', '함안(순천방향)', '경남 함안군 군북면 현포로 205-1', '055-582-6321', '매일 24시간', 2215)
# ('A0029367', '함양(대전방향)', '경남 함양군 지곡면 효산길 23-11', '055-964-1041', '매일 24시간', 1117)
# ('A0033193', '내린천(서울방향)', '강원 인제군 상남면 서울양양고속도로 117', '033-852-7110', '매일 24시간', 0)
# ('A0033192', '내린천(양양방향)', '강원 인제군 상남면 서울양양고속도로 117', '033-852-7220', '매일 24시간', 0)
# ('A0011366', '평창(강릉방향)', '강원 평창군 용평면 경강로 2159-58', '033-334-5107', '매일 24시간', 400)
# ('A0011367', '평창(인천방향)', '강원 평창군 용평면 탑거리길 63', '033-333-6131', '매일 24시간', 0)
# ('A0001982', '군포터미널', '경기 군포시 번영로 82', '031-460-2991', '평일 24시간', 800)
# ('A0008176', '의왕아이시디', '경기 의왕시 창말로 39', '031-461-8005', '평일 08:00~20:00', 0)
# ('A0014382', '중부화물터미널(세종)', '세종시 부강면 연청로 745-46', '044-260-5189', '평일 24시간 ', 750)
# ('A0000658', '영남복합물류(칠곡)', '경북 칠곡군 지천면 금호로 272', '054-380-1111', '평일 24시간', 2400)
# ('A0031380', '내트럭 부산(감만)', '부산 남구 신선로 168', '051-638-3971', '평일 24시간', 1103)
# ('A0031393', '내트럭 부산용당', '부산 남구 신선로 261', '051-931-8001', '평일 24시간', 597)
# ('A0028784', '내트럭 부산신항', '경남 창원시 진해구 신항북로 320', '055-543-9461', '평일 24시간', 2050)
# ('A0033060', '내트럭 부산신항남컨', '부산 강서구 신항남로 507', '051-941-9800', '평일 24시간', 1276)
# ('A0001505', '내트럭 인천', '인천 중구 축항대로 296번길 183', '032-891-7800', '평일 04:00~24:00', 0)
# ('A0022180', '내트럭 광양', '전남 광양시 중마로 15', '061-795-0111', '평일 07:00~22:00', 601)
# ('A0033028', '내트럭 광양 황금', '전남 광양시 항만대로 200', '061-795-9806', '평일 07:00~23:00', 0)
# ('A0033058', '내트럭 평택', '경기 평택시 포승읍 하만호길 229', '032-684-1201', '평일 06:00~24:00', 2180)
# ('A0033530', '내트럭 울산신항', '울산 남구 신항로 716번길 13', '052-947-6500', '평일 06:00~22:00', 312)
# ('A0031396', '부산(북항) 우암', '부산 남구 우암로 204', '051-644-0142', '평일 05:00~23:00', 1600)
# ('A0027428', '부산(신항) 보배산', '경남 창원시 진해구 진해대로 2170', '055-551-0098', '평일 05:00~23:00', 0)
# ('A0028540', '부산(신항) 남송', '경남 창원시 진해구 진해대로 2455', '055-552-5145', '평일 06:00~24:00', 2000)
# ('A0001248', '인천 광역 만석점', '인천 동구 인중로 441', '032-761-5149 ', '평일 04:00~24:00', 650)
# ('A0001541', '인천 갤러리', '인천 동구 인중로 431', '032-772-2031', '평일 04:00~23:00', 2250)
# ('A0001327', '인천 알뜰 부광', '인천 중구 인중로 180', '032-765-5145', '평일 06:00~22:00', 300)
# ('A0001540', '인천 동양 오일캠프', '인천 중구 축항대로 282', '032-888-2066', '평일 24시간', 0)
# ('A0022096', '광양 고향', '전남 광양시 백운로 1027', '061-792-6060', '평일 06:00~24:00', 0)
# ('A0022031', '광양 시원 태양', '전남 광양시 백운로 965', '061-791-5188', '평일 24시간', 0)
# ('A0006491', '평택 만호', '평택시 포승읍 서동대로 771 ', '031-681-1800', '평일 05:00~23:00', 2600)
# ('A0002768', '평택 포승행복', '평택시 포승읍 포승공단로 68 ', '031-681-5022', '평일 04:00~22:00', 1600)
# ('A0029171', '내트럭 울산', '울산 남구 산업로 100', '052-998-8484', '평일 24시간 ', 80)
# ('A0033222', '내트럭 울산약수', '울산 북구 산업로 1515', '052-946-2200', '평일 24시간 ', 0)
# ('A0022484', '내트럭 여수', '전남 여수시 여수산단로 140', '070-8740-2803', '평일 06:00~24:00', 427)
# ('A0033447', '내트럭 김해', '경남 김해시 진영읍 김해대로 243', '055-903-2600', '평일 06:00~23:00', 700)
# ('A0032994', '첨단용두', '광주 북구 빛고을대로 663', '062-572-5189 ', '매일 05:00~24:00', 500)

# %% [markdown]
# # LaneNet-Lane-Detection
# Use tensorflow to implement a Deep Neural Network for real time lane detection mainly based on the IEEE IV conference
# paper "Towards End-to-End Lane Detection: an Instance Segmentation Approach".You can refer to their paper for details
# https://arxiv.org/abs/1802.05591. This model consists of a encoder-decoder stage, binary semantic segmentation stage
# and instance semantic segmentation using discriminative loss function for real time lane detection task.
#
# The main network architecture is as follows:
#
# `Network Architecture`
# ![NetWork_Architecture](./data/source_image/network_architecture.png)
#
# ## Installation
# This software has only been tested on ubuntu 16.04(x64), python3.5, cuda-9.0, cudnn-7.0 with a GTX-1070 GPU.
# To install this software you need tensorflow 1.12.0 and other version of tensorflow has not been tested but I think
# it will be able to work properly in tensorflow above version 1.12. Other required package you may install them by
#
# ```
# pip3 install -r requirements.txt
# ```
#
# ## Test model
# In this repo I uploaded a model trained on tusimple lane dataset [Tusimple_Lane_Detection](http://benchmark.tusimple.ai/#/).
# The deep neural network inference part can achieve around a 50fps which is similar to the description in the paper. But
# the input pipeline I implemented now need to be improved to achieve a real time lane detection system.
#
# The trained lanenet model weights files are stored in
# [lanenet_pretrained_model](https://www.dropbox.com/sh/0b6r0ljqi76kyg9/AADedYWO3bnx4PhK1BmbJkJKa?dl=0). You can
# download the model and put them in folder model/tusimple_lanenet/
#
# You can test a single image on the trained model as follows
#
# ```
# python tools/test_lanenet.py --weights_path /PATH/TO/YOUR/CKPT_FILE_PATH
# --image_path ./data/tusimple_test_image/0.jpg
# ```
# The results are as follows:
#
# `Test Input Image`
#
# ![Test Input](./data/tusimple_test_image/0.jpg)
#
# `Test Lane Mask Image`
#
# ![Test Lane_Mask](./data/source_image/lanenet_mask_result.png)
#
# `Test Lane Binary Segmentation Image`
#
# ![Test Lane_Binary_Seg](./data/source_image/lanenet_binary_seg.png)
#
# `Test Lane Instance Segmentation Image`
#
# ![Test Lane_Instance_Seg](./data/source_image/lanenet_instance_seg.png)
#
# If you want to evaluate the model on the whole tusimple test dataset you may call
# ```
# python tools/evaluate_lanenet_on_tusimple.py
# --image_dir ROOT_DIR/TUSIMPLE_DATASET/test_set/clips
# --weights_path /PATH/TO/YOUR/CKPT_FILE_PATH
# --save_dir ROOT_DIR/TUSIMPLE_DATASET/test_set/test_output
# ```
# If you set the save_dir argument the result will be saved in that folder
# or the result will not be saved but be
# displayed during the inference process holding on 3 seconds per image.
# I test the model on the whole tusimple lane
# detection dataset and make it a video. You may catch a glimpse of it bellow.
#
# `Tusimple test dataset gif`
# ![tusimple_batch_test_gif](./data/source_image/lanenet_batch_test.gif)
#
# ## Train your own model
# #### Data Preparation
# Firstly you need to organize your training data refer to the data/training_data_example folder structure. And you need
# to generate a train.txt and a val.txt to record the data used for training the model.
#
# The training samples consist of three components, a binary segmentation label file, a instance segmentation label
# file and the original image. The binary segmentation uses 255 to represent the lane field and 0 for the rest. The
# instance use different pixel value to represent different lane field and 0 for the rest.
#
# All your training image will be scaled into the same scale according to the config file.
#
# Use the script here to generate the tensorflow records file
#
# ```
# python tools/make_tusimple_tfrecords.py
# ```
#
# #### Train model
# In my experiment the training epochs are 80010, batch size is 4, initialized learning rate is 0.001 and use polynomial
# decay with power 0.9. About training parameters you can check the global_configuration/config.py for details.
# You can switch --net argument to change the base encoder stage. If you choose --net vgg then the vgg16 will be used as
# the base encoder stage and a pretrained parameters will be loaded. And you can modified the training
# script to load your own pretrained parameters or you can implement your own base encoder stage.
# You may call the following script to train your own model
#
# ```
# python tools/train_lanenet_tusimple.py
# ```
#
# You may monitor the training process using tensorboard tools
#
# During my experiment the `Total loss` drops as follows:
# ![Training loss](./data/source_image/total_loss.png)
#
# The `Binary Segmentation loss` drops as follows:
# ![Training binary_seg_loss](./data/source_image/binary_seg_loss.png)
#
# The `Instance Segmentation loss` drops as follows:
# ![Training instance_seg_loss](./data/source_image/instance_seg_loss.png)
#
# ## Experiment
# The accuracy during training process rises as follows:
# ![Training accuracy](./data/source_image/accuracy.png)
#
# Please cite my repo [lanenet-lane-detection](https://github.com/MaybeShewill-CV/lanenet-lane-detection) if you use it.
#
# ## Recently updates 2018.11.10
# Adjust some basic cnn op according to the new tensorflow api. Use the
# traditional SGD optimizer to optimize the whole model instead of the
# origin Adam optimizer used in the origin paper. I have found that the
# SGD optimizer will lead to more stable training process and will not
# easily stuck into nan loss which may often happen when using the origin
# code.
#
# ## Recently updates 2018.12.13
# Since a lot of user want a automatic tools to generate the training samples
# from the Tusimple Dataset. I upload the tools I use to generate the training
# samples. You need to firstly download the Tusimple dataset and unzip the
# file to your local disk. Then run the following command to generate the
# training samples and the train.txt file.
#
# ```angular2html
# python tools/generate_tusimple_dataset.py --src_dir path/to/your/unzipped/file
# ```
#
# The script will make the train folder and the test folder. The training
# samples of origin rgb image, binary label image, instance label image will
# be automatically generated in the training/gt_image, training/gt_binary_image,
# training/gt_instance_image folder.You may check it yourself before start
# the training process.
#
# Pay attention that the script only process the training samples and you
# need to select several lines from the train.txt to generate your own
# val.txt file. In order to obtain the test images you can modify the
# script on your own.
#
# ## Recently updates 2020.06.12
#
# Add real-time segmentation model BiseNetV2 as lanenet backbone. You may modify the
# config/tusimple_lanenet.yaml config file to choose the front-end of lanenet model.
#
# New lanenet model trainned based on BiseNetV2 can be found [here](https://www.dropbox.com/sh/0b6r0ljqi76kyg9/AADedYWO3bnx4PhK1BmbJkJKa?dl=0)
#
# The new model can reach 78 fps in single image inference process.
#
# ## MNN Project
#
# Add tools to convert lanenet tensorflow ckpt model into mnn model and deploy
# the model on mobile device
#
# #### Freeze your tensorflow ckpt model weights file
# ```
# cd LANENET_PROJECT_ROOT_DIR
# python mnn_project/freeze_lanenet_model.py -w lanenet.ckpt -s lanenet.pb
# ```
#
# #### Convert pb model into mnn model
# ```
# cd MNN_PROJECT_ROOT_DIR/tools/converter/build
# ./MNNConver -f TF --modelFile lanenet.pb --MNNModel lanenet.mnn --bizCode MNN
# ```
#
# #### Add lanenet source code into MNN project
#
# Add lanenet source code into MNN project and modified CMakeList.txt to
# compile the executable binary file.
#
# ## TODO
# - [x] Add a embedding visualization tools to visualize the embedding feature map
# - [x] Add detailed explanation of training the components of lanenet separately.
# - [x] Training the model on different dataset
# - ~~[ ] Adjust the lanenet hnet model and merge the hnet model to the main lanenet model~~
# - ~~[ ] Change the normalization function from BN to GN~~
#
# ## Acknowledgement
#
# The lanenet project refers to the following projects:
#
# - [MNN](https://github.com/alibaba/MNN)
# - [SimpleDBSCAN](https://github.com/CallmeNezha/SimpleDBSCAN)
# - [PaddleSeg](https://github.com/PaddlePaddle/PaddleSeg)
#
# ## Contact
#
# Scan the following QR to disscuss :)
# ![qr](./data/source_image/qr.jpg)
