# %% [markdown]
# # 10. naver api

# %%
! pwd
# Out:
# /home/soomin/dev_ws/np

# %% [markdown]
# ## 01. 네이버 API 사용 등록

# %% [markdown]
# - 네이버 개발자 센터
# - https://developers.naver.com/main/
# - Application
#     - 어플리케이션 등록
#     - 어플리케이션 이름
#     - 사용 API
#         - 검색
#     - 환경추가
#         - WEB 설정
#         - http://localhost
#     - Client_ID
#     - Client secret

# %%
Client_id  = "jobnkhjep0MgIGeZTCsr" 
client_secret = "rzlneYbRxB"

# %% [markdown]
# ## 02. 네이버 검색 API 사용하기
# - 개발 가이드 : https://developers.naver.com/docs/serviceapi/search/blog/blog.md#python

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "jobnkhjep0MgIGeZTCsr"
client_secret = "rzlneYbRxB"
encText = urllib.parse.quote("검색할 단어")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 11 Aug 2023 15:49:18 +0900",
# 	"total":938728,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"아이폰 사파리 텍스트 찾기 <b>단어<\/b> <b>검색<\/b> 방법 정리",
# 			"link":"https:\/\/blog.naver.com\/jhbksgi\/222982804031",
# 			"description":"아이폰 사파리 크롬 텍스트 찾기 <b>단어<\/b> <b>검색<\/b> 방법 정리 글\/사진 : 곰T 기본적으로 컴퓨터용, 모바일용 Browser에는 '<b>검색<\/b>' 기능이 있습니다. 그냥 <b>검색<\/b>(Search)이라고 하면 감이 잘 오지 않을 수 있겠네요. 좀 더... ",
# 			"bloggername":"곰T의 IT트러블슈팅",
# 			"bloggerlink":"blog.naver.com\/jhbksgi",
# 			"postdate":"20230112"
# 		},
# 		{
# 			"title":"직장인이 최근 많이 <b>검색<\/b>한 <b>단어<\/b>",
# 			"link":"https:\/\/blog.naver.com\/blueyoungman\/223099437889",
# 			"description":"- 직장인이라면 한 번쯤 머릿속을 스쳐간 <b>단어<\/b>가 있을 것이다. '권고사직'이다. 권고사직이... 직장인 소셜 플랫폼 블라인드에서 권고사직을 <b>검색<\/b>한 직장인이 1년만에 9배 이상 증가한 것으로 나타났다.... ",
# 			"bloggername":"재테크와 일상 그 어딘가.",
# 			"bloggerlink":"blog.naver.com\/blueyoungman",
# 			"postdate":"20230511"
# 		},
# 		{
# ...

# %% [markdown]
# # 03. 실습
# - url decode = https://www.urldecoder.org/

# %%
import os
import sys
import urllib.request


client_id = "jobnkhjep0MgIGeZTCsr"
client_secret = "rzlneYbRxB"

# 클라이언트가 서버에 요청할 정보 생성(url 생성)
encText = urllib.parse.quote('로지텍 키보드')
url = 'https://openapi.naver.com/v1/search/shop.json?query=' + encText

# url 정보로 서버에게 요청과 응답
request = urllib.request.Request(url)
request.add_header('X-Naver-Client-Id', client_id)
request.add_header('X-Naver-Client-Secret', client_secret)
response = urllib.request.urlopen(request)

# 응답을 제대로 받았는지 확인
rescode = response.getcode()
if (rescode ==200):
    response_body=response.read()
    print(response_body.decode('utf-8'))
else:
    print("error : ", rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 11 Aug 2023 15:49:20 +0900",
# 	"total":113137,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>로지텍<\/b> K380",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=8974763652",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8974763\/8974763652.20221116165947.jpg",
# 			"lprice":"22800",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"8974763652",
# 			"productType":"1",
# 			"brand":"로지텍",
# 			"maker":"로지텍",
# 			"category1":"디지털\/가전",
# 			"category2":"주변기기",
# 			"category3":"키보드",
# 			"category4":"무선키보드"
# 		},
# 		{
# 			"title":"<b>로지텍<\/b> MX KEYS MINI",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=30488263622",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3048826\/30488263622.20220110170830.jpg",
# 			"lprice":"90770",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"30488263622",
# 			"productType":"1",
# 			"brand":"로지텍",
# 			"maker":"로지텍",
# ...

# %% [markdown]
# ## 04. 네이버 검색 api 응용
# - 1. url
#     - gen_Search_url 만들기
#     - 검색해야할 url 만들기

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = 'https://openapi.naver.com/v1/search'
    ## 검색할 테마
    node = '/' + api_node + '.json'
    ## 검색할 단어
    param_query = '?query=' + urllib.parse.quote(search_text)
    ## 페이지 번호
    param_start = '&start=' + str(start_num)
    ## 몇 개 상품 보여줄건지
    param_disp = '&display=' + str(disp_num)

    return base + node + param_query + param_start + param_disp

# %%
gen_search_url('shop', '맥북', 1, 5)
# Out:
# 'https://openapi.naver.com/v1/search/shop.json?query=%EB%A7%A5%EB%B6%81&start=1&display=5'

# %% [markdown]
# ## 04 -2

# %%
import json
import datetime

def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header('X-Naver-Client-Id', client_id)
    request.add_header('X-Naver-Client-Secret', client_secret)
    response = urllib.request.urlopen(request)
    print(f'{datetime.datetime.now()}Url Request Success')

    return json.loads(response.read().decode('utf-8'))

# %%
get_result_onpage(gen_search_url('shop', '맥북', 1, 100))
## 광고로 붙어 있는 거는 안 불러와지는 거 같음
# Out:
# 2023-08-11 16:50:07.992461Url Request Success
# {'lastBuildDate': 'Fri, 11 Aug 2023 16:50:07 +0900',
#  'total': 1369953,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': 'Apple <b>맥북</b> 프로 14 2023년 M2 Pro 10코어 실버 (MPHH3KH/A)',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=37931021622',
#    'image': 'https://shopping-phinf.pstatic.net/main_3793102/37931021622.20230216144530.jpg',
#    'lprice': '2200000',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '37931021622',
#    'productType': '1',
#    'brand': 'Apple',
#    'maker': 'Apple',
#    'category1': '디지털/가전',
#    'category2': '노트북',
#    'category3': '',
#    'category4': ''},
#   {'title': 'Apple <b>맥북</b> 에어 15 2023년 M2 8코어 실버 MQKT3KH/A',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=40883203624',
#    'image': 'https://shopping-phinf.pstatic.net/main_4088320/40883203624.20230707161349.jpg',
#    'lprice': '2052000',
#    'hprice': '',
#    'mallName': '네이버',
# ...

# %%
url  = gen_search_url('shop', '아이패드', 1, 10)
on_result = get_result_onpage(url)
on_result
# Out:
# 2023-08-11 16:10:32.743644Url Request Success
# {'lastBuildDate': 'Fri, 11 Aug 2023 16:10:02 +0900',
#  'total': 2529057,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': 'Apple <b>아이패드</b> 에어\xa05세대 M1 WIFI 64G 스페이스 그레이 (MM9C3KH/A)',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=31530843620',
#    'image': 'https://shopping-phinf.pstatic.net/main_3153084/31530843620.20220705164247.jpg',
#    'lprice': '779900',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '31530843620',
#    'productType': '1',
#    'brand': 'Apple',
#    'maker': 'Apple',
#    'category1': '디지털/가전',
#    'category2': '태블릿PC',
#    'category3': '',
#    'category4': ''},
#   {'title': 'Apple <b>아이패드</b> 10세대 WIFI 64G 실버 (MPQ03KH/A)',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=35322861618',
#    'image': 'https://shopping-phinf.pstatic.net/main_3532286/35322861618.20221118114143.jpg',
#    'lprice': '587870',
#    'hprice': '',
#    'mallName': '네이버',
# ...

# %%
# 상품 판매처
import pandas as pd

# %% [markdown]
# ## 04 -3

# %% [markdown]
# - DataFrame

# %%
for each in on_result['items']:
    print(each['title'])
# Out:
# Apple <b>아이패드</b> 에어 5세대 M1 WIFI 64G 스페이스 그레이 (MM9C3KH/A)
# Apple <b>아이패드</b> 10세대 WIFI 64G 실버 (MPQ03KH/A)
# Apple <b>아이패드</b> 프로 11 4세대 M2 WIFI 128G 스페이스 그레이 (MNXD3KH/A)
# [당일출고] 애플 <b>아이패드</b> 9세대 Apple <b>iPad</b> 9 64GB WiFi 미국애플정품
# Apple <b>아이패드</b> 9세대 WIFI 64G 스페이스 그레이(MK2K3KH/A)
# Apple <b>아이패드</b> 9세대 WIFI 64G 스페이스 그레이 (MK2K3KH/A)
# Apple <b>아이패드</b> 프로 12.9 6세대 M2 WIFI 256G 스페이스 그레이 (MNXR3KH/A)
# Apple <b>아이패드</b> 에어 5세대 WIFI 64G
# Apple <b>아이패드</b> 프로 11 4세대 M2 WIFI 128G 실버 (MNXE3KH/A)
# Apple <b>아이패드</b> 10세대 WIFI 64G 블루 (MPQ13KH/A)

# %%
def delete_tag(input_str):
    input_str = input_str.replace('<b>', '')
    input_str = input_str.replace('</b>', '')
    input_str = input_str.replace('\xa0', '')

    return input_str

# %%
def get_fields(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    link =  [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]

    result = pd.DataFrame({
        'title' : title,
        'link' : link,
        'lprice' :lprice,
        'mall': mall_name
    }, columns= ['title', 'lprice', 'mall', 'link'])
    

    return result

# %%
get_fields(on_result)
# Out:
#                                                title   lprice    mall  \
# 0  Apple 아이패드 에어5세대 M1 WIFI 64G 스페이스 그레이 (MM9C3KH/A)   779900     네이버
# 1            Apple 아이패드 10세대 WIFI 64G 실버 (MPQ03KH/A)   587870     네이버
# 2  Apple 아이패드 프로 11 4세대 M2 WIFI 128G 스페이스 그레이 (MN...  1075330     네이버
# 3   [당일출고] 애플 아이패드 9세대 Apple iPad 9 64GB WiFi 미국애플정품   309800  브루클린덤보
# 4        Apple 아이패드 9세대 WIFI 64G 스페이스 그레이(MK2K3KH/A)   355000     네이버
# 5       Apple 아이패드 9세대 WIFI 64G 스페이스 그레이 (MK2K3KH/A)   454910     네이버
# 6  Apple 아이패드 프로 12.9 6세대 M2 WIFI 256G 스페이스 그레이 (...  1699420     네이버
# 7                         Apple 아이패드 에어 5세대 WIFI 64G   701500     네이버
# 8   Apple 아이패드 프로 11 4세대 M2 WIFI 128G 실버 (MNXE3KH/A)  1079890     네이버
# 9            Apple 아이패드 10세대 WIFI 64G 블루 (MPQ13KH/A)   584070     네이버
#
#                                                 link
# 0  https://search.shopping.naver.com/gate.nhn?id=...
# 1  https://search.shopping.naver.com/gate.nhn?id=...
# ...

# %% [markdown]
# ## 5. actmain

# %%
for n in range(1, 1000, 100):
    print(n)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %%
result_datas = []

for n in range(1, 1000, 100):
    url = gen_search_url('shop', '아이패드', n, 100)
    json_result = get_result_onpage(url)
    result = get_fields(json_result)
    result_datas.append(result)
# Out:
# 2023-08-11 16:44:44.259083Url Request Success
# 2023-08-11 16:44:44.327043Url Request Success
# 2023-08-11 16:44:44.382947Url Request Success
# 2023-08-11 16:44:44.465201Url Request Success
# 2023-08-11 16:44:44.539197Url Request Success
# 2023-08-11 16:44:44.621773Url Request Success
# 2023-08-11 16:44:44.695777Url Request Success
# 2023-08-11 16:44:44.759630Url Request Success
# 2023-08-11 16:44:44.817904Url Request Success
# 2023-08-11 16:44:44.872098Url Request Success

# %%
final_datas = pd.concat(result_datas)
final_datas.tail()
# Out:
#                                                 title   lprice  mall  \
# 95                       아이패드 6세대 32GB Wi-Fi 스페이스 그레이   262280  11번가
# 96            아이패드 아이패드 프로 M2 12.9 6세대 WIFI 1TB  //정품  2665390   G마켓
# 97          아이패드 아이패드 프로 M2 12.9 6세대 WIFI 512GB  //정품  1983710   G마켓
# 98  Apple 아이패드 프로 11 4세대 M2 WIFI 1T 스페이스 그레이 (MNXK...  2151090   네이버
# 99                  Apple 아이패드 mini  핑크  256GB  Wi-Fi   908100    쿠팡
#
#                                                  link
# 95  https://search.shopping.naver.com/gate.nhn?id=...
# 96  https://search.shopping.naver.com/gate.nhn?id=...
# 97  https://search.shopping.naver.com/gate.nhn?id=...
# 98  https://search.shopping.naver.com/gate.nhn?id=...
# 99  https://search.shopping.naver.com/gate.nhn?id=...

# %%
final_datas
# Out:
#                                                 title   lprice    mall  \
# 0   Apple 아이패드 에어5세대 M1 WIFI 64G 스페이스 그레이 (MM9C3KH/A)   779900     네이버
# 1             Apple 아이패드 10세대 WIFI 64G 실버 (MPQ03KH/A)   587870     네이버
# 2   Apple 아이패드 프로 11 4세대 M2 WIFI 128G 스페이스 그레이 (MN...  1075330     네이버
# 3    [당일출고] 애플 아이패드 9세대 Apple iPad 9 64GB WiFi 미국애플정품   309800  브루클린덤보
# 4         Apple 아이패드 9세대 WIFI 64G 스페이스 그레이(MK2K3KH/A)   355000     네이버
# ..                                                ...      ...     ...
# 95                       아이패드 6세대 32GB Wi-Fi 스페이스 그레이   262280    11번가
# 96            아이패드 아이패드 프로 M2 12.9 6세대 WIFI 1TB  //정품  2665390     G마켓
# 97          아이패드 아이패드 프로 M2 12.9 6세대 WIFI 512GB  //정품  1983710     G마켓
# 98  Apple 아이패드 프로 11 4세대 M2 WIFI 1T 스페이스 그레이 (MNXK...  2151090     네이버
# 99                  Apple 아이패드 mini  핑크  256GB  Wi-Fi   908100      쿠팡
#
#                                                  link
# 0   https://search.shopping.naver.com/gate.nhn?id=...
# ...

# %%
final_datas.reset_index(drop=True, inplace=True)
final_datas.tail()
# Out:
#                                                  title   lprice  mall  \
# 995                       아이패드 6세대 32GB Wi-Fi 스페이스 그레이   262280  11번가
# 996            아이패드 아이패드 프로 M2 12.9 6세대 WIFI 1TB  //정품  2665390   G마켓
# 997          아이패드 아이패드 프로 M2 12.9 6세대 WIFI 512GB  //정품  1983710   G마켓
# 998  Apple 아이패드 프로 11 4세대 M2 WIFI 1T 스페이스 그레이 (MNXK...  2151090   네이버
# 999                  Apple 아이패드 mini  핑크  256GB  Wi-Fi   908100    쿠팡
#
#                                                   link
# 995  https://search.shopping.naver.com/gate.nhn?id=...
# 996  https://search.shopping.naver.com/gate.nhn?id=...
# 997  https://search.shopping.naver.com/gate.nhn?id=...
# 998  https://search.shopping.naver.com/gate.nhn?id=...
# 999  https://search.shopping.naver.com/gate.nhn?id=...

# %%
final_datas['lprice'] = final_datas['lprice'].astype('float')
final_datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   float64
#  2   mall    1000 non-null   object
#  3   link    1000 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %%
## 엑셀로 저장

writer = pd.ExcelWriter("./shop_ipad_in_naver_shop.xlsx", engine = 'xlsxwriter')
final_datas.to_excel(writer, sheet)
