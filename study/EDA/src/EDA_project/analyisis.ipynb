# %% [markdown]
# ## 데이터 분석

# %% [markdown]
# ### 데이터 베이스에 컬럼 추가

# %%
import mysql.connector

employ_con = mysql.connector.connect(
    host = 'database-1.ca4ikbv2yxyc.ap-northeast-2.rds.amazonaws.com',
    port = 3306,
    user = "gorani", 
    password = "1",
    database = "amrbase"
)

employ_cur = employ_con.cursor(buffered=True)
employ_cur.execute("select * from corperation")

# %% [markdown]
# ### robot_type 컬럼 추가

# %%
employ_cur.execute("alter table corperation add column robot_type varchar(32)")
employ_con.commit()

# %%
employ_cur.execute("select * from corperation")

# %%
result = employ_cur.fetchall()
for row in result:
    print(row[2])
# Out:
# ㈜티라로보틱스
# (주)유진로봇
# (주)트위니
# 엑스와이지
# 텔레웍스
# 가온그룹(주)
# (주)로보스타
# ㈔대덕이노폴리스벤처협회
# ㈜에스티앤아이
# 에이지로보틱스
# (주)에스와이에스홀딩스
# (주)테솔로
# 클로봇
# 로보티즈
# (주)고스트로보틱스테크놀로지
# (주)씨디알시스템
# 주식회사 루덴스파트너스
# (주)베이리스
# 큐렉소(주)
# (주)제우스로보틱스
# (주)인텔렉투스
# (주)세오
# 에이알247(주)
# (주)제스엔지니어링
# 에이알247(주)
# 한화오션(주)
# 엘지전자(주)
# 현대글로비스(주)
# 엘지전자(주)
# 포스코홀딩스
# 슈어소프트테크(주)
# 원익
# 두산로보틱스
# 드림텍
# 포스코DX
# (주)엘템
# (주)원익로보틱스
# (주)티로보틱스
# (주)인티그리트
# 써니팩토리
# (주)테스트웍스
# 가천대학교 산학협력단
# 록시스
# (주)파이엇 (PIOT Inc
# 에브리봇(주)
# 로봇제조기업
# 솔루션 전문기업
# 임플란트 중견기업
# 협동로봇 개발 제조사
# 서비스로봇 전문기업
# 물류로봇 시스템기업
# 로봇 제조회사
# 서비스로봇제조업
# 업종 안써있음
# 의료기기 연구소
# 기계 제조 대기업
# 포스코 홀딩스
# 한국생산기술연구원
# 포스코
# KT
# 랑데뷰
# 뉴빌리티
# 언맨드 솔루션
# (주)아이들
# (주)메디인테크
# 우아한 형제들
# 에스티피씨
# 코가로보틱스
# 알지티
# 에이스랩
# 아데코코리아
# 에이알247
# 현대자동차

# %% [markdown]
# ### 주소 줄바꿈 처리

# %%
JD =  pd.DataFrame(result)

# %%
for id in range(len(JD.index)):
    if '\n' in JD.iloc[id,2]:
        JD.iloc[id,2] = JD.iloc[id,2].replace('\n', ' ')

# %% [markdown]
# ### 기업 형태 줄바꿈 처리

# %%
for id in range(len(JD.index)):
    if '\n' in JD.iloc[id,3]:
        JD.iloc[id,3] = JD.iloc[id,3].replace('\n', ' ')
    if '(' in JD.iloc[id, 3]:
        JD.iloc[id,3] = JD.iloc[id,3].split('(')[0]

# %% [markdown]
# ### 주소 결측치 확인

# %%
for id in range(len(JD.index)):
    if not '로' in JD.iloc[id,2]:
        print(JD.iloc[id,1], ' : ' ,JD.iloc[id,2])
# Out:
# (주)트위니  :  대전시 유성구
# (주)씨디알시스템  :  경기도 화성시
# 주식회사 루덴스파트너스   :  서울시 성동구, 서울시 중구
# (주)베이리스  :  경기도 성남시 수정구
# 큐렉소(주)  :  서울시 송파구
# (주)제우스로보틱스  :  경기도 화성시
# (주)인텔렉투스  :  서울시 서초구
# (주)세오  :  경기도 안양시 동안구
# 에이알247(주)  :  경기도 성남시 분당구
# (주)제스엔지니어링  :  서울시 금천구
# 에이알247(주)  :  성남시 분당구
# 한화오션(주)  :  경남 거제시
# 엘지전자(주)  :  전국
# 현대글로비스(주)  :  서울시 성동구
# 엘지전자(주)  :  서울시 강서구
# 포스코홀딩스  :  경북 포항시 남구
# 슈어소프트테크(주)  :  경기도 성남시 수정구
# 원익  :  전국
# 두산로보틱스   :  경기도 성남시 분당구
# 드림텍  :  경기도 성남시 분당구
# 포스코DX   :  경기도 성남시 분당구
# (주)엘템   :  전북 전주시 완산구
# (주)원익로보틱스  :  경기도 성남시 분당구
# (주)티로보틱스  :  경기도 성남시 분당구
# (주)인티그리트  :  서울시 강남구
# 써니팩토리  :  광주 동구
# (주)테스트웍스  :  서울시 송파구
# 가천대학교 산학협력단  :  인천시 남동구
# 록시스   :  경남 진주시
# (주)파이엇 (PIOT Inc  :  서울시 강남구
# 에브리봇(주)  :   경기도 성남시 분당구
# 로봇제조기업  :  성남시 분당구
# 솔루션 전문기업  :  성남시 분당구
# 임플란트 중견기업  :  경기도 전지역
# 협동로봇 개발 제조사  :  성남시 분당구
# 서비스로봇 전문기업  :  서울 금천구
# 물류로봇 시스템기업  :  용인시 기흥구
# 로봇 제조회사  :  성남시 분당구
# 서비스로봇제조업  :  인천 연수구
# 업종 안써있음  :  성남시 분당구
# 의료기기 연구소  :  성남시 분당구
# 기계 제조 대기업  :  서울 강남구
# ...

# %% [markdown]
# ### 데이터 베이스에 업데이트

# %%
soomin_con = mysql.connector.connect(
host = "database-1.cmdlhagy2um9.ap-northeast-2.rds.amazonaws.com",
port = 3306,
user = "admin", 
password = "dltnals123$",
database = "armbase"
)
soomin_db_cur = soomin_con.cursor(buffered=True)

## 테이블 만드는 쿼리
query = '''create table corperation(
                cor_id int unsigned NOT NULL,  
                cor_name varchar(16) NOT NULL,
                cor_location varchar(64), 
                cor_scale varchar(16),
                robot_type varchar(32),
                primary key(cor_id)); '''
soomin_db_cur.execute(query)

# %%
for idx, row in JD.iterrows():
    insert_values = "insert into corperation values(%s, %s, %s, %s, %s)"
    
    ## 쿼리 실행
    soomin_db_cur.execute(insert_values,tuple(row))
    soomin_con.commit()
soomin_con.close()

# %% [markdown]
# ### 병철님이 주신 주소 시각화

# %%
import pandas as pd
new_address = pd.read_excel('../../../../Downloads/company (1).xlsx')
new_address
# Out:
#                  회사이름                                                 위치  \
# 0             ㈜티라로보틱스        경기 성남시\n중남구\n둔촌대로\n388\n상대원동,\n크란츠테크노\n304호
# 1             (주)유진로봇              인천 연수구\n하모니로\n187번길 33\n송도동,\n(주)유진로봇
# 2              (주)트위니                                  대전광역시 유성구 가정북로 90
# 3               엑스와이지                            서울 성동구 아차산로17길 48, 401호
# 4                텔레웍스      서울 금천구\n가산디지털1로\n168\n가산동\n우림라이온스벨리\nA동 1212호
# 5             가온그룹(주)                경기 성남시\n분당구\n성남대로\n884-3\n야탑동\n가온그룹
# 6             (주)로보스타                    경기 안산시\n상록수\n수인로 700\n사사동\n로보스타
# 7        ㈔대덕이노폴리스벤처협회  대전 유성구\n가정로 218\n가정동\n,한국전자통신연구원\n융합기술연구생산센터\n...
# 8             ㈜에스티앤아이                    울산 중구 \n종가로\n406-21\n복산동\n1130호
# 9             에이지로보틱스            경남 창원시\n의창구\n평산로 23\n팔용동\n신화테크노밸리\n320호
# 10       (주)에스와이에스홀딩스                        서울 용산구\n청파로 74\n한강로3가\n전자랜드
# 11             (주)테솔로                   경기 광명시\n일직로 43\n일직동\nGIDC A동 26층
# ...

# %% [markdown]
# ### 시각화

# %%
for address in new_address.iterrows():
    print(list(address)[1]["위도"])
# Out:
# 37.4327078
# 37.3779695
# 36.353984
# 37.1618138
# 37.4799048
# 37.40877649999999
# 37.2954888197085
# 36.415674
# 35.5651848
# 35.2463175
# 37.3894673
# 37.2710822
# 37.4130682
# 37.5701649
# 37.50823011970849
# 37.200492
# 37.3739085197085
# 37.41108
# 37.5078937
# 37.2116712802915
# 37.5009452
# 37.3923387
# 37.331739
# 37.4722248
# 37.331739
# 34.8721913
# 37.5278847
# 37.5443796
# 37.5278847
# 35.9866664
# 37.4067662
# 37.4849344
# 37.36408369999999
# 37.3844485
# 37.4040681
# 35.8231899
# 37.404611
# 37.1720655
# 37.5095206
# 35.1482745
# 37.5091181
# 37.4507128
# 35.1654112
# 37.5232008
# 37.4012839127.1086461

# %%
import googlemaps
import folium

## folium 지도 선언
map = folium.Map((37.5, 127.04), zoom_start=14, tiles = 'Stamen Toner')

## 구글 맵스
gmaps = googlemaps.Client(key='AIzaSyBTIsL54y7akR2KMb4KVYTzRPMlNDKgbvU')

## 위치 받아오기
for address in new_address.iterrows():
    # tmp = gmaps.geocode(address[] , language='ko')
    try:
        location = (float(list(address)[1]["위도"]), float(list(address)[1]["경도"]))
    except:
        continue

    ## folium으로 매장 위치 표시
    folium.Marker(
        location= location, 
        tooltip=list(address)[1]["회사이름"],
        icon = folium.Icon(
            color='lightblue',
            icon_color= 'white',
            icon ='glyphicon glyphicon-font',
            angle=0,
            prefix = 'glyphicon'
        )
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### 병철님께 새로운 회사 드리는 코드

# %%
JD.to_excel('my_excel_file.xlsx', index=False)

# %% [markdown]
# ### 회사별 로봇 종류 데이터 수집

# %%
JD.iloc[0,1]
# Out:
# '㈜티라로보틱스'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 import pandas as pd
# ----> 2 jd_sql = pd.DataFrame.to_sql(JD)
#
# TypeError: NDFrame.to_sql() missing 2 required positional arguments: 'name' and 'con'
