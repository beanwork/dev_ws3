# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

options = webdriver.ChromeOptions()

prefs = {'download.default_directory':'../../data/html/',
         'download.prompt_for_download' : False}
options.add_experimental_option('prefs', prefs)

url = "https://www.opinet.co.kr/searRgSelect.do"
driver = webdriver.Chrome(service=Service("../../driver/chromedriver-linux64/chromedriver"),
                          options=options)

# %%
driver.get(url)

# %%
from selenium.webdriver.common.by import By

sido_name = driver.find_element(By.ID, "SIDO_NM0")
si_list = sido_name.find_elements(By.TAG_NAME , "option")
sido_list = []
for idx, si_name in enumerate(si_list):
    print(idx)
    print(si_name.get_attribute("value"))
    sido_list.append(si_name.get_attribute("value"))
# Out:
# 0
#
# 1
# 서울특별시
# 2
# 부산광역시
# 3
# 대구광역시
# 4
# 인천광역시
# 5
# 광주광역시
# 6
# 대전광역시
# 7
# 울산광역시
# 8
# 세종특별자치시
# 9
# 경기도
# 10
# 충청북도
# 11
# 충청남도
# 12
# 전라북도
# 13
# 전라남도
# 14
# 경상북도
# 15
# 경상남도
# 16
# 제주특별자치도
# 17
# 강원특별자치도

# %%
sido_list = sido_list[1:]
sido_list
# Out:
# ['서울특별시',
#  '부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도',
#  '제주특별자치도',
#  '강원특별자치도']

# %%
sido_name.send_keys(sido_list[0])

# %%
sigungu = driver.find_element(By.ID, "SIGUNGU_NM0")
sigungu_list = sigungu.find_elements(By.TAG_NAME, "option")
sigungu_nm_list = []
for idx, sigungu_name in enumerate(sigungu_list):
    print(idx)
    print(sigungu_name.get_attribute("value"))
    sigungu_nm_list.append(sigungu_name.get_attribute("value"))
# Out:
# 0
#
# 1
# 강남구
# 2
# 강동구
# 3
# 강북구
# 4
# 강서구
# 5
# 관악구
# 6
# 광진구
# 7
# 구로구
# 8
# 금천구
# 9
# 노원구
# 10
# 도봉구
# 11
# 동대문구
# 12
# 동작구
# 13
# 마포구
# 14
# 서대문구
# 15
# 서초구
# 16
# 성동구
# 17
# 성북구
# 18
# 송파구
# 19
# 양천구
# 20
# 영등포구
# 21
# 용산구
# 22
# 은평구
# 23
# 종로구
# 24
# 중구
# 25
# 중랑구

# %%
sigungu_nm_list = sigungu_nm_list[1:]
sigungu_nm_list
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
import time
from tqdm.notebook import tqdm
os_info =[]
os = []
for sigungu_name in tqdm(sigungu_nm_list):
    sigungu = driver.find_element(By.ID, "SIGUNGU_NM0")
    sigungu.send_keys(sigungu_name)
    gasoline = driver.find_element(By.XPATH, '''//*[@id="os_layer2"]/p/a''')
    gasoline.click()
    oilstation = driver.find_element(By.XPATH, '''//*[@id="body1"]/tr[1]/td[1]/a''')
    oilstation.click()

    os_address = driver.find_element(By.ID, "rd_addr")
    os_info.append(os_address.text)
    
    os_property = driver.find_element(By.ID, "rd_addr")
    os_info.append(os_property.text)
    
    os_nm = driver.find_element(By.ID, "os_nm")
    os_info.append(os_nm.text)

    os.append(os_info)

    

    time.sleep(3)
print(os)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# [['', '', '', '', '', '', '', '서울 강북구 도봉로 395 (수유동)', '', '', '', '', '서울 관악구 보라매로 41', '서울 관악구 보라매로 41', '', '', '', '', '', '', '', '', '', '', '서울 노원구 월계로 252 (월계동)', '서울 노원구 월계로 252 (월계동)', '', '', '', '', '서울 동대문구 답십리로 223 (답십리동)', '서울 동대문구 답십리로 223 (답십리동)', '', '', '', '', '서울 마포구 월드컵북로 62', '서울 마포구 월드컵북로 62', '', '', '', '', '서울 서초구 양재대로12길 73-71', '서울 서초구 양재대로12길 73-71', '', '', '', '', '서울 성북구 돌곶이로 142 (장위동)', '서울 성북구 돌곶이로 142 (장위동)', '', '', '', '', '', '', '', '', '', '', '', '', '', '서울 은평구 증산로 441', '서울 은평구 증산로 441', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '서울 강북구 도봉로 395 (수유동)', '', '', '', '', '서울 관악구 보라매로 41', '서울 관악구 보라매로 41', '', '', '', '', '', '', '', '', '', '', '서울 노원구 월계로 252 (월계동)', '서울 노원구 월계로 252 (월계동)', '', '', '', '', '서울 동대문구 답십리로 223 (답십리동)', '서울 동대문구 답십리로 223 (답십리동)', '', '', '', '', '서울 마포구 월드컵북로 62', '서울 마포구 월드컵북로 62', '', '', '', '', '서울 서초구 양재대로12길 73-71', '서울 서초구 양재대로12길 73-71', '', '', '', '', '서울 성북구 돌곶이로 142 (장위동)', '서울 성북구 돌곶이로 142 (장위동)', '', '', '', '', '', '', '', '', '', '', '', '', '', '서울 은평구 증산로 441', '서울 은평구 증산로 441', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '서울 강북구 도봉로 395 (수유동)', '', '', '', '', '서울 관악구 보라매로 41', '서울 관악구 보라매로 41', '', '', '', '', '', '', '', '', '', '', '서울 노원구 월계로 252 (월계동)', '서울 노원구 월계로 252 (월계동)', '', '', '', '', '서울 동대문구 답십리로 223 (답십리동)', '서울 동대문구 답십리로 223 (답십리동)', '', '', '', '', '서울 마포구 월드컵북로 62', '서울 마포구 월드컵북로 62', '', '', '', '', '서울 서초구 양재대로12길 73-71', '서울 서초구 양재대로12길 73-71', '', '', '', '', '서울 성북구 돌곶이로 142 (장위동)', '서울 성북구 돌곶이로 142 (장위동)', '', '', '', '', '', '', '', '', '', '', '', '', '', '서울 은평구 증산로 441', '서울 은평구 증산로 441', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '서울 강북구 도봉로 395 (수유동)', '', '', '', '', '서울 관악구 보라매로 41', '서울 관악구 보라매로 41', '', '', '', '', '', '', '', '', '', '', '서울 노원구 월계로 252 (월계동)', '서울 노원구 월계로 252 (월계동)', '', '', '', '', '서울 동대문구 답십리로 223 (답십리동)', '서울 동대문구 답십리로 223 (답십리동)', '', '', '', '', '서울 마포구 월드컵북로 62', '서울 마포구 월드컵북로 62', '', '', '', '', '서울 서초구 양재대로12길 73-71', '서울 서초구 양재대로12길 73-71', '', '', '', '', '서울 성북구 돌곶이로 142 (장위동)', '서울 성북구 돌곶이로 142 (장위동)', '', '', '', '', '', '', '', '', '', '', '', '', '', '서울 은평구 증산로 441', '서울 은평구 증산로 441', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '서울 강북구 도봉로 395 (수유동)', '', '', '', '', '서울 관악구 보라매로 41', '서울 관악구 보라매로 41', '', '', '', '', '', '', '', '', '', '', '서울 노원구 월계로 252 (월계동)', '서울 노원구 월계로 252 (월계동)', '', '', '', '', '서울 동대문구 답십리로 223 (답십리동)', '서울 동대문구 답십리로 223 (답십리동)', '', '', '', '', '서울 마포구 월드컵북로 62', '서울 마포구 월드컵북로 62', '', '', '', '', '서울 서초구 양재대로12길 73-71', '서울 서초구 양재대로12길 73-71', '', '', '', '', '서울 성북구 돌곶이로 142 (장위동)', '서울 성북구 돌곶이로 142 (장위동)', '', '', '', '', '', '', '', '', '', '', '', '', '', '서울 은평구 증산로 441', '서울 은평구 증산로 441', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '서울 강북구 도봉로 395 (수유동)', '', '', '', '', '서울 관악구 보라매로 41', '서울 관악구 보라매로 41', '', '', '', '', '', '', '', '', '', '', '서울 노원구 월계로 252 (월계동)', '서울 노원구 월계로 252 (월계동)', '', '', '', '', '서울 동대문구 답십리로 223 (답십리동)', '서울 동대문구 답십리로 223 (답십리동)', '', '', '', '', '서울 마포구 월드컵북로 62', '서울 마포구 월드컵북로 62', '', '', '', '', '서울 서초구 양재대로12길 73-71', '서울 서초구 양재대로12길 73-71', '', '', '', '', '서울 성북구 돌곶이로 142 (장위동)', '서울 성북구 돌곶이로 142 (장위동)', '', '', '', '', '', '', '', '', '', '', '', '', '', '서울 은평구 증산로 441', '서울 은평구 증산로 441', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '서울 강북구 도봉로 395 (수유동)', '', '', '', '', '서울 관악구 보라매로 41', '서울 관악구 보라매로 41', '', '', '', '', '', '', '', '', '', '', '서울 노원구 월계로 252 (월계동)', '서울 노원구 월계로 252 (월계동)', '', '', '', '', '서울 동대문구 답십리로 223 (답십리동)', '서울 동대문구 답십리로 223 (답십리동)', '', '', '', '', '서울 마포구 월드컵북로 62', '서울 마포구 월드컵북로 62', '', '', '', '', '서울 서초구 양재대로12길 73-71', '서울 서초구 양재대로12길 73-71', '', '', '', '', '서울 성북구 돌곶이로 142 (장위동)', '서울 성북구 돌곶이로 142 (장위동)', '', '', '', '', '', '', '', '', '', '', '', '', '', '서울 은평구 증산로 441', '서울 은평구 증산로 441', '', '',  ...

# %%
gasoline = driver.find_element(By.XPATH, '''//*[@id="os_layer2"]/p/a''')
gasoline.click()
oilstation = driver.find_element(By.XPATH, '''//*[@id="body1"]/tr[1]/td[1]/a''')
oilstation.click()

from bs4 import BeautifulSoup

page = driver.page_source
soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <html lang="ko">
#  <head>
#   <title>
#    싼 주유소 찾기 Opinet &gt; 싼주유소찾기 &gt; 지역별
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="initial-scale=1.0,user-scalable=no" name="viewport"/>
#   <link href="/css/user/gis.css" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="/js/user/jquery-1.11.1.min.js" type="text/javascript">
#   </script>
#   <script src="/js/user/OpinetUIGis.js" type="text/javascript">
#   </script>
#   <script src="/js/user/OpinetUICommon.js" type="text/javascript">
#   </script>
#   <script src="/js/user/fammilySite.js" type="text/javascript">
#   </script>
#   <script src="/js/com/common-ajax.js" type="text/javascript">
#   </script>
#   <script src="/js/com/common.js" type="text/javascript">
#   </script>
#   <script src="/js/user/gis_ui_script.js" type="text/javascript">
#   </script>
#   <script src="/js/user/gis.js" type="text/javascript">
#   </script>
#   <!-- 기존 맵 src 시작 -->
#   <!-- <script type="text/javascript" src="http://api.ktgis.com:10080/v3/olleh/mapAPI.js?key=YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=&module=Map,Geocoder" charset="utf-8"> -->
#   <!-- </script> -->
#   <!-- <script type="text/javascript" src="http://api.ktgis.com:10080/v3/olleh/mapsSpatialAPI.js?key=YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY="> -->
#   <!-- </script> -->
#   <!-- 기존 맵 src 끝 -->
#   <!-- 2017.05.08 map src 변경 시작-->
#   <script charset="utf-8" src="https://api.ollehmap.com:10083/v3/olleh/mapAPI.js?key=YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .ollehmap *,.ollehmap :after,.ollehmap :before{box-sizing:content-box;-webkit-box-sizing:content-box;-moz-box-sizing:content-box}.ollehmap{position:relative;overflow:hidden;padding:0;margin:0;border:none;background-color:#EEE;-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.ollehmap-noevent{pointer-events:none!important}.ollehmap-event{pointer-events:auto}.ollehmap-drag .ollehmap-info,.ollehmap-drag .ollehmap-info-shadow{opacity:.3}.ollehmap-dragging{z-index:357913941!important}.ollehmap-vector{pointer-events:visiblePainted}.ollehmap-info{position:absolute}.ollehmap-info-defaultStyle{font-family:Dotum,Baekmuk Dotum,Undotum,Apple Gothic,Latin font,sans-serif;font-size:12px;font-weight:400;line-height:normal;font-style:normal}.ollehmap-info-area{cursor:default;position:relative;left:0;top:0;background-color:#fff;border:2px solid #474747}.ollehmap-info-content{cursor:auto;position:absolute;min-height:60px;min-width:300px;max-height:500px;z-index:9999;-webkit-user-select:text;-khtml-user-select:text;-moz-user-select:text;-ms-user-select:text;user-select:text}.ollehmap-info-content-overflow{overflow:auto;-webkit-overflow-scrolling:auto}.ollehmap-info-tip{width:16px;height:26px;overflow:hidden;z-index:1;position:absolute}.ollehmap-info-tip-img{position:absolute;border:0;padding:0;margin:0;top:-348px;left:0;z-index:auto}.ollehmap-info-bottom{position:absolute;left:0;top:0;border:2px solid #474747}.ollehmap-info-shadow{position:absolute}.ollehmap-info-shadow>div{overflow:hidden;position:absolute;z-index:1;-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.ollehmap-info-shadow img{position:absolute;-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;border:0;padding:0;margin:0}.ollehmap-info-shadow-topleft,.ollehmap-info-shadow-topright{top:0;width:70px;height:10px}.ollehmap-info-shadow-topleft>img{left:-296px;top:0}.ollehmap-info-shadow-topright>img{left:-1036px;top:0}.ollehmap-info-shadow-bottomleft,.ollehmap-info-shadow-bottomright{width:70px;height:30px}.ollehmap-info-shadow-bottomleft>img{left:12px;top:-315px}.ollehmap-info-shadow-bottomright>img{left:-716px;top:-315px}.ollehmap-info-shadow-bottomtip{width:40px;height:30px}.ollehmap-info-shadow-bottomtip>img{left:-356px;top:-315px}.ollehmap-info-shadow-topcenter{height:10px}.ollehmap-info-shadow-topcenter>img{left:-366px;top:0}.ollehmap-info-shadow-centerleft>img{top:-10px}.ollehmap-info-shadow-centerright>img{top:-10px}.ollehmap-info-shadow-bottomleftoftip,.ollehmap-info-shadow-bottomrightoftip{height:30px}.ollehmap-info-shadow-bottomleftoftip>img,.ollehmap-info-shadow-bottomrightoftip>img{left:-396px;top:-315px}.ollehmap-info-shadow-center>img{left:-366px;top:-10px}.ollehmap-info-tooltip-area{position:relative;background-color:#fff;left:0;top:0;border:1px solid #555;border-radius:2px}.ollehmap-info-tooltip-data{font-family:Dotum,Baekmuk Dotum,Undotum,Apple Gothic,Latin font,sans-serif;font-size:13px;font-weight:700;line-height:normal;font-style:normal}.ollehmap-corner-container{position:relative}.ollehmap-corner-container-horizontal{display:inline-block}.ollehmap-corner{position:absolute;z-index:1}.ollehmap-corner-area{position:relative;display:inline-block}.ollehmap-control-rightAlign{margin-left:auto;margin-right:0}.ollehmap-copyright-control{color:#000;font:700 12px/1.5 Dotum,Arial,Helvetica,sans-serif;text-shadow:-1px 0 white,0 1px white,1px 0 white,0 -1px #fff;display:inline}.ollehmap-logo-control,.ollehmap-logo-control.imagery{background-position:-78px -316px;width:22px;height:22px;margin:0 8px 12px 2px}.ollehmap-logo-control.imagery{background-position:-100px -316px}.ollehmap-maptype-control-expandtype{padding:6px;margin:6px;box-shadow:0 1px 7px #999;border:1px solid #000;background-color:#fff;border-radius:8px;-moz-border-radius:8px;font:12px/1.5 "Helvetica Neue",Arial,Helvetica,sans-serif;colo ...
#   </style>
#   <style type="text/css">
#    .ollehmap{cursor:default}.ollehmap-boxzoom{position:absolute;background-color:#fff;opacity:.5;border:2px dotted red;width:0;height:0}.ollehmap-transparent{background-color:#fff;opacity:0}.ollehmap-control-clickable{cursor:pointer}.ollehmap-info-close{position:absolute;width:14px;height:14px;overflow:hidden;right:18px;top:13px;z-index:10000;cursor:pointer}.ollehmap-info-close-img{position:absolute;-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;border:0;padding:0;margin:0;top:-346px;left:-51px}
#   </style>
#   <!--[if lte IE 8]><style type="text/css">.ollehmap-vml{behavior:url(#default#VML);position:absolute}.ollehmap-boxzoom{-ms-filter:"alpha(Opacity=50)";filter:alpha(opacity=50)}.ollehmap-transparent{-ms-filter:"alpha(Opacity=0)";filter:alpha(opacity=0)}.ollehmap-corner-area{margin:1px}.ollehmap-maptype-control-expandtype>form{height:100%;padding:0;margin:0}.ollehmap-measure-pointDetail{width:135px}.ollehmap-measure-areaInfo{width:120px}</style><![endif]-->
#   <script charset="utf-8" src="https://api.ollehmap.com:10083/v3/olleh/mapsSpatialAPI.js?key=YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=" type="text/javascript">
#   </script>
#   <!-- 2017.05.08 map src 변경 끝-->
#   <script type="text/javascript">
#    //20170926 보안조치
# var infow;
# var hsido = ['시/도','서울','부산','대구','인천','광주','대전','울산','세종','경기','충북','충남','전북','전남','경북','경남','제주','강원'];
# var OsMarker = new Array();
# var OsMarkerJsonArr = new Array();
# var mitersAll = "0";
# var pop = new Array();
# var pop2 = new Array();
# var pop3 = new Array();
# var pop4 = new Array();
# var listpop = new Array();
# //var clusterer = new olleh.maps.overlay.MarkerClusterer();
# 	$().ready(function(){
# 		document.oncontextmenu = new Function('return false');
# 		document.onselectstart = new Function('return false');
# 		var p_mnbSelectId = [0, 0]; //주유소/충전소 찾기 => 지역/위치별
# 		createMenu (_GnbData,p_mnbSelectId);
#
# 		fnSetOsLayer();
#
# 		$('#SIDO_NM0 option').each(function(e){
# 			$(this).text(hsido[e]);
# 		});
#
# 		$("#os_layer1").click(function() { //2019오피넷개선: 시군구가 전체이고 검색방법이 지역(addr), 상호(osNm), 주소(osAddr)인 경우 검색 후 목록의 첫 번째 주유소를 지도에 표시
# 			if('addr' == 'addr' || 'addr' == 'osNm'  || 'addr' == 'osAddr'){
# 		   		if("310169.34427" != "" && "541693.21359" != ""){
#    					map.setCenter(new olleh.maps.Katech("310169.34427", "541693.21359"));
# 		   		}
# 			}
# 		});
#
# 		$("#os_layer2").click(function() { //2019오피넷개선: 시군구가 전체이고 검색방법이 지역(addr), 상호(osNm), 주소(osAddr)인 경우 검색 후 목록의 첫 번째 주유소를 지도에 표시
# 			if('addr' == 'addr' || 'addr' == 'osNm'  || 'addr' == 'osAddr'){
# 		   		if("304179.85162" != "" && "542284.69116" != ""){
#    					map.setCenter(new olleh.maps.Katech("304179.85162", "542284.69116"));
# 		   		}
# 			}
# 		});
#
# 		$("#os_layer3").click(function() { //2019오피넷개선: 시군구가 전체이고 검색방법이 지역(addr), 상호(osNm), 주소(osAddr)인 경우 검색 후 목록의 첫 번째 주유소를 지도에 표시
# 			if('addr' == 'addr' || 'addr' == 'osNm'  || 'addr' == 'osAddr'){
# 		   		if("305616.56394" != "" && "542563.88518" != ""){
# 	   				map.setCenter(new olleh.maps.Katech("305616.56394", "542563.88518"));
# 		   		}
# 			}
# 		});
#
# 		$("#os_layer4").click(function() { //2019오피넷개선: 시군구가 전체이고 검색방법이 지역(addr), 상호(osNm), 주소(osAddr)인 경우 검색 후 목록의 첫 번째 주유소를 지도에 표시
# 			if('addr' == 'addr' || 'addr' == 'osNm'  || 'addr' == 'osAddr'){
# 		   		if("308420.93867" != "" && "542175.23155" != ""){
#    					map.setCenter(new olleh.maps.Katech("308420.93867", "542175.23155"));
# 		   		}
# 			}
# 		});
#
# 		$("#os_layer11").click(function() {
# 			$("#os_layer11").attr("class", "sel");
# 			$("#os_layer22").removeClass();
# 			$("#os_layer33").removeClass();
# 			$("#os_layer44").removeClass();
# 			$("#os_price22").show();
# 			$("#os_price11").hide();
# 			$("#os_price33").hide();
# 			$("#os_price44").hide();
# 			tabChgMarker("1");
# 		});
#
# 		$("#os_layer22").click(function() {
# 			$("#os_layer22").attr("class", "sel");
# 			$("#os_layer11").removeClass();
# 			$("#os_layer33").removeClass();
# 			$("#os_layer44").removeClass();
# 			$("#os_price11").show();
# 			$("#os_price22").hide();
# 			$("#os_price33").hide();
# 			$("#os_price44").hide();
# 			tabChgMarker("2");
# 		});
#
# 		$("#os_layer33").click(function() {
# 			$("#os_layer33").attr("class", "sel");
# 			$("#os_layer22").removeClass();
# 			$("#os_layer11").removeClass();
# 			$("#os_layer44").removeClass();
# 			$("#os_price33").show();
# 			$("#os_price22").hide();
# 			$("#os_price11").hide();
# 			$("#os_price44").hide();
# 			tabChgMarker("3");
# 		});
#
# 		$("#os_layer44").click(function() {
# 			$("#os_layer44").attr("class", "sel");
# 			$("#os_layer22").removeClass();
# 			$("#os_layer33").removeClass();
# 			$("#os_layer11").removeClass();
# 			$("#os_price44").show();
# 			$("#os_price22").hide();
# 			$("#os_price33").hide();
# 			$("#os_price11").hide();
# 			tabChgMarker("4");
# 		});
#
# 		$("#OS_BTN").click(function(){
# 			$("#BTN_DIV").val("os_btn");
# 			$("#BTN_DIV_STR").val("P_START");
# 			$('#LPG_YN').val('');
# 			$("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();
# 		});
#
# 		$("#LPG_BTN").click(function(){
# 			$("#BTN_DIV").val("lpg_btn");
# 			$("#BTN_DIV_STR").val("P_START");
# 			$('#LPG_YN').val('Y');
# 			$("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();
# 		});
#
# 		$("#NORM_YN").click(function() {
# 			if(!$("#NORM_YN").is(":checked")){
# 				if(!$("#KPETRO_DP_YN").is(":checked") && !$("#KPETRO_YN").is(":checked") && !$("#SELF_DIV_CD").is(":checked") && !$("#VLT_YN").is(":checked") ){
# 					alert("형태[일반/셀프/불법/인증/전산]를 한개이상을 선택해주세요!");
# 					$('input:checkbox[id="NORM_YN"]').attr("checked", true);
# 					return false;
# 				}
# 			}
# 		});
#
# 		$("#SELF_DIV_CD").click(function() {
# 			if(!$("#SELF_DIV_CD").is(":checked") && !$("#NORM_YN").is(":checked") && !$("#VLT_YN").is(":checked") && !$("#KPETRO_YN").is(":checked") && !$("#KPETRO_DP_YN").is(":checked")){
# 				alert("형태[일반/셀프/불법/인증/전산]를 한개이상을 선택해주세요!");
# 				$('input:checkbox [ id="SELF_DIV_CD"]').attr("checked", true);
# 				return false;
# 			}
# 		});
#
# 		$("#VLT_YN").click(function() {
# 			if(!$("#SELF_DIV_CD").is(":checked") && !$("#NORM_YN").is(":checked") && !$("#VLT_YN").is(":checked") && !$("#KPETRO_YN").is(":checked") && !$("#KPETRO_DP_YN").is(":checked")){
# 				alert("형태[일반/셀프/불법/인증/전산]를 한개이상을 선택해주세요!");
# 				$('input:checkbox [ id="VLT_YN"]').attr("checked", true);
# 				return false;
# 			}
# 		});
#
# 		$("#KPETRO_YN").click(function() {
# 			if(!$("#SELF_DIV_CD").is(":checked") && !$("#NORM_YN").is(":checked") && !$("#VLT_YN").is(":checked")  && !$("#KPETRO_YN").is(":checked") && !$("#KPETRO_DP_YN").is(":checked")){
# 				alert("형태[일반/셀프/불법/인증/전산]를 한개이상을 선택해주세요!");
# 				$('input:checkbox [ id="KPETRO_YN"]').attr("checked", true);
# 				return false;
# 			}
# 		});
#
# 		$("#KPETRO_DP_YN").click(function() {
# 			if(!$("#SELF_DIV_CD").is(":checked") && !$("#NORM_YN").is(":checked") && !$("#VLT_YN").is(":checked")  && !$("#KPETRO_YN").is(":checked") && !$("#KPETRO_DP_YN").is(":checked")){
# 				alert("형태[일반/셀프/불법/인증/전산]를 한개이상을 선택해주세요!");
# 				$('input:checkbox [ id="KPETRO_DP_YN"]').attr("checked", true);
# 				return false;
# 			}
# 		});
#
# 		$("#searRgSelect").click(function(){
#
# 			if($('#SEARCH_MOD3').is(":checked"))  {//위치 검색
# /* 				GetSearchBound();	//선택지역내의 지도좌표조회
#
# 				$('#OS_NM').val("");
#
# 				if(validate2()){
# 					$("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();
# 				} */
# 				alert("[위치검색]버튼을 클릭해주세요.");
# 				return false;
#
# 			}else if($('#SEARCH_MOD2').is(":checked"))  {//지도검색
# 				if(!GetSearchBound()){
# 					return false;
# 				}
# 				$('#MAP_CENTER_X').val(map.getCenter().x);
# 				$('#MAP_CENTER_Y').val(map.getCenter().y);
# 				$('#MAP_ZOOM').val(map.getZoom());
# 				$('#OS_NM').val("");
# 				if(validate2() == true){
# 					wrapMask();
# 					NetFunnel_Action({action_id:"B2"},function(ev,ret){
# 						$("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();	//지도좌표내의 주유소검색
# 					});
#
# 				}
# 			}else if($('#SEARCH_MOD5').is(":checked"))  {//반경검색
#
# 				 /*if(map.getZoom() < 8){
# 					 alert( "확대된 지도 레벨에서 검색이 가능합니다.\r\n우측 레벨바를 8레벨 이상으로 설정해 주십시요!" );
# 				        if (circle) {
# 				        	circle.setMap(null);
# 				            circle = null;
# 				        }
#
# 				        if (circleLine) {
# 				        	circleLine.setMap(null);
# 				        	circleLine = null;
# 				        	//circleLine.erase();
# 				        }
#
# 				       if (endPointMarker) {
# 				    	   endPointMarker.setMap(null);
# 				    	   endPointMarker = null;
# 				        }
#
# 					 return;
# 				 }*/
# 				if(mitersAll > 10000){
#  		    		alert("10km 이상은 조회가 불가능합니다.");
#  		    	 	SetCircleOnMap();
#  		    	 	return;
#  	 	     	}else if(mitersAll < 1){
#  	 	     		alert("반경을 선택해주세요.");
#  		    	 	SetCircleOnMap();
#  		    	 	return;
#  	 	     	}else{
#  	 	     		var elem = document.getElementById('map_div');
#  		            olleh.maps.util.dom.setStyle(elem, "cursor", "default");
#  		            olleh.maps.util.dom.setStyle(elem, "opacity", "");
#  		            olleh.maps.util.dom.setStyle(elem, "background", "");
#  	 	     	}
# 				GetCircleSearchBound();
# 				$('#POI_SEARCH').hide();
# 				$('#RACT_SEARCH').show();
#
# 				$('#templ_list0').hide();
# 				$('#templ_list1').show();
# 				$('#templ_list').hide();
# 				preDataDelete();
#
# 				//commonFormAjax('/searRgPlaceAjax.d', 'searrgVO', callbackPlaceFun);
# 				NetFunnel_Action({action_id:"B2"},function(ev,ret){
# 					$.ajax({
# 						type  : "POST",
# 						url   : "/searRgCircleAjax.do",
# 						data  : $("#searrgVO").serialize(),
# 						dataType : "json",
# 						//contentType: "application/json; charset=utf-8",
# 						success : function(data){
# 					    	callbackCircleFun(data);
# 					    	NetFunnel_Complete();
# 					    },
# 					    error: function(xhr, status, error) {
# 							alert(error);
# 						}
# 					});
# 				});
# 			}else {	//상호검색,지역내 검색,반경내 검색
# 				clearFormData();
# 				if($('#SEARCH_MOD4').is(":checked"))  {
# 					if($('#OS_NM').val() != ''){
# 						//$('#MAP_ZOOM').val(12); //줌 사용시 주석 해제 할것
# 					} else {
# 						alert("상호명을 입력 하십시오.");
# 						$('#OS_NM').focus();
# 						return;
# 					}
# 				}else if($('#SEARCH_MOD6').is(":checked"))  {
# 					if($('#OS_ADDR').val() != ''){
# 					} else {
# 						alert("주소를 입력 하십시오.");
# 						$('#OS_ADDR').focus();
# 						return;
# 					}
# 				}
# 				else{
# 					$('#OS_NM').val("");
# 					$('#OS_ADDR').val("");
# 				}
# 				if(validate()) {
# 					wrapMask();
# 					NetFunnel_Action({action_id:"B2"},function(ev,ret){
# 						$("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();
# 					});
# 				}
# 			}
# 		});
#
# 		$('#localSearch').click(function() {
# 			if($('#OS_NM').val() != "") {
# 				commonJsonSevletAjax("/GeocodeSelect.do", "type=poi&sidoNm="+$('#SIDO_NM0').val()+"&poiName="+$('#OS_NM').val(), poiSearchName1);
# 			} else {
# 				alert("검색어를 입력해주세요.");
# 				$('#OS_NM').focus();
# 			}
#
# 		});
#
# 		//지역 내
# 		$('#SEARCH_MOD1').click(function() {
# 			$('#POI_SEARCH').hide();
# 			$('#OS_ADDR_SEARCH').hide();
# 			$('#RACT_SEARCH').hide();
# 			$('#OS_NM').val("");
# 			$('#OS_ADDR').val("");
# 			$('.arrow_box').attr('tab','');
# 			$('.arrow_box2').attr('tab','');
# 		});
#
# 		//지도검색
# 		$('#SEARCH_MOD2').click(function() {
# 			//GetSearchBound();
# 			$('#POI_SEARCH').hide();
# 			$('#RACT_SEARCH').hide();
# 			$('#OS_ADDR_SEARCH').hide();
# 			$('#OS_NM').val("");
# 			$('#OS_ADDR').val("");
# 			$('.arrow_box').attr('tab','');
# 			$('.arrow_box2').attr('tab','');
# 		});
#
# 		//위치 검색 사용안함
# 		$('#SEARCH_MOD3').click(function() {
# 			$('#POI_SEARCH').show();
# // 			$('#localSearch').show();
# 			$('#localSearch').hide();	//2017.05.15 검색 버튼 사용 안함으로 변경
# 			$('#RACT_SEARCH').hide();
#
# 			$('#templ_list0').hide();
# 			$('#templ_list1').hide();
# 			$('#templ_list').show();
# 			$('#OS_NM').val("");
# 		});
# 		$('#typeRadio input[type="radio"]').change(function(){
# 			if(circle!=null) circle.setVisible(false);
# 			if(circleLine!=null) circleLine.setVisible(false);
# 			if(endPointMarker!=null) endPointMarker.setVisible(false);
# 		});
# 		//상호 검색
# 		$('#SEARCH_MOD4').click(function() {
# 			$('#POI_SEARCH').show();
# 			$('#OS_ADDR_SEARCH').hide();
# 			$('#RACT_SEARCH').hide();
# 			$('#localSearch').hide();
#
# 			$('#templ_list1').hide();
# 			$('#templ_list0').show();
# 			$('#templ_list').hide();
# 			$('#OS_ADDR').val("");
# 			$('.arrow_box').attr('tab','area2');
# 			$('.arrow_box2').attr('tab','area2');
# 		});
# 		//주소 검색
# 		$('#SEARCH_MOD6').click(function() {
# 			$('#OS_ADDR_SEARCH').show();
# 			$('#POI_SEARCH').hide();
# 			$('#RACT_SEARCH').hide();
# 			$('#localSearch').hide();
#
# 			$('#templ_list1').hide();
# 			$('#templ_list0').show();
# 			$('#templ_list').hide();
# 			$('#OS_NM').val("");
# 			$('.arrow_box').attr('tab','area2');
# 			$('.arrow_box2').attr('tab','area2');
# 		});
#
# 		//반경 선택
# 		$('#SEARCH_MOD5').click(function() {
# 			if(checkBrowser()){
# 				$('.gis_map').attr('style','width:100%; height:100%; left:0px;');
# 			}
#
# 			SetCircleOnMap();
# 			$('#POI_SEARCH').hide();
# 			$('#OS_ADDR_SEARCH').hide();
# 			$('#OS_NM').val("");
# 			$('#OS_ADDR').val("");
# 			$('.arrow_box').attr('tab','round');
# 			$('.arrow_box2').attr('tab','round');
# 		});
# 		$('#SEARCH_MOD5').change(function() {
# 			//preDataDelete();
# 		});
#
# 		//반경 재선택
# 		$('#BTN_CIRCLE_RESET').click(function() {
# 			SetCircleOnMap();
# 		});
#
#
# 		$('.POLL_DIV_CD').click(function() {
# 			var poll = document.getElementsByName("POLL_DIV_CD");
# 			var leng = poll.length;
# 			var check = 0;
# 			for(var i=0; i<leng; i++) {
# 				if(document.getElementsByName("POLL_DIV_CD")[i].checked) {
# 					check++;
# 				} else {
# 					check--;
# 					break;
# 				}
# 			}
# 			if(check == 6){
# 				document.getElementById("POLL_DIV_ALL").className = "btn_type2_sel";
# 				$('#POLL_ALL').val('ALL');
# 			}else{
# 				document.getElementById("POLL_DIV_ALL").className = "btn_type2";
# 				$('#POLL_ALL').val('');
# 			}
# 		});
#
#
# 		$("#SIDO_NM0").change(function() {
#
# 			$("#SIDO_NM").val($("#SIDO_NM0").val());
# 			sigunguGisAjax($("#SIDO_NM0").val(), sigunguGisResult0);
# 			$('#DONG_NM').val("");
#
# 			geocoder = new olleh.maps.Geocoder("YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=");
# 			geocoder.geocode({
# 				type:0,
# 				addr: $("#SIDO_NM0").val(),
# 				addrcdtype:1
# 			},
# 			"geocode_center"
# 			);
#
#
# 		});
#
#
# 		$("#SIGUNGU_NM0").change(function() {
# 			$('#DONG_NM').val("");
# 			$('#SEARCH_MOD1').attr("checked",true);
#
# 			//dongGisAjax($("#SIDO_NM0").text(), $("#SIGUNGU_NM0").val(), dongGisResult);
# 			$("#SIGUNGU_NM").val($("#SIGUNGU_NM0").val());
# 			//2019오피넷개선: 검색 후 목록의 첫 번째 주유소를 지도에 표시하므로 해당지역으로 지도화면 이동 불필요로 주석처리함.
# // 			geocoder = new olleh.maps.Geocoder("YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=");
# // 			geocoder.geocode({
# // 				type:0,
# // 				addr: $("#SIDO_NM0").val() +" "+ $("#SIGUNGU_NM0").val(),
# // 				addrcdtype: 1
# // 			},
# // 			"geocode_center"
# // 			);
#
#
# /* 			if($('#SEARCH_MOD3').is(":checked"))  { //위치 검색
# 				GetSearchBound();	//선택지역내의 지도좌표조회
# 				if(validate2())	$("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();	//지도 검색
# 			}else if($('#SEARCH_MOD2').is(":checked"))  {
# 				if(validate2() == true){
# 					$("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();	//지도좌표내의 주유소검색
# 				}
# 			} else {// 지역 내 	 상호 검색  반경 선택
# 				if(validate()) $("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();
# 			} */
#
# 			if(validate()){
# 				clearFormData();
# 				jQuery('input:radio[id="SEARCH_MOD1"]:input[value="addr"]').attr("checked", true);
# 				$("#searrgVO").attr({"action":"/searRgSelect.do", "target":"_self"}).submit();
# 			}
#
# 			//markerDraw();
#
# 		});
# 		//$('.gis_map').css({'width':'100%','height':'100%','left':'0'});
#
# 		//상호 검색 엔터키 20170817 ysj  추가
# 		$("#OS_NM, #OS_ADDR").keydown(function(key){
# 			if(key.keyCode == 13){
# 				$("#searRgSelect").trigger("click");
# 			}
# 		});
#
# 		$(".d_right .ico_kpos").hover(
# 			function(){
# 				$(".arrow_box").css("display","block");
# 			},function(){
# 				$(".arrow_box").css("display","none");
# 			}
# 		);
# 		$(".d_right .ico_kdp").hover(
# 			function(){
# 				$(".arrow_box2").css("display","block");
# 			},function(){
# 				$(".arrow_box2").css("display","none");
# 			}
# 		);
#
# 		var boxChk = 'addr';
# 		if(boxChk == 'osNm'){
# 			$('.arrow_box').attr('tab','area2');
# 			$('.arrow_box2').attr('tab','area2');
# 		}else if(boxChk == 'ract'){
# 			$('.arrow_box').attr('tab','round');
# 			$('.arrow_box2').attr('tab','round');
# 		}
#
# 	});
#
# 	// 엑셀다운로드
# 	function fn_excel_download(btn_div) {
# 		if(listpop.length > 2000){
# 			alert("2,000건 이상은 엑셀저장이 지원되지 않습니다.");
# 			return;
# 		}
#
# 		/*$("#BTN_DIV").val(btn_div);
# 		frm = document.form1;
# 		frm.action="/download_excel.do";
# 		frm.target = "_self";
# 		frm.method = "post";
# 		frm.submit();*/
#
# 		if($('#SEARCH_MOD3').is(":checked"))  {//위치 검색
# 			alert("[위치검색]버튼을 클릭해주세요.");
# 			return;
# 		}else if($('#SEARCH_MOD2').is(":checked"))  {//지도검색
# 			if(!GetSearchBound()){
# 				return;
# 			}
# 			$('#MAP_CENTER_X').val(map.getCenter().x);
# 			$('#MAP_CENTER_Y').val(map.getCenter().y);
# 			$('#MAP_ZOOM').val(map.getZoom());
# 			$('#OS_NM').val("");
# 			if(validate2() == true){
# 				wrapMask();
# 				intv = setInterval(progress, 1000);
# 				NetFunnel_Action({action_id:"B2"},function(ev,ret){
# 					$("#searrgVO").attr({"action":"/download_excel.do", "target":"_self"}).submit();	//지도좌표내의 주유소검색
# 				});
# 			}
# 		}else if($('#SEARCH_MOD5').is(":checked"))  {//반경검색
# 			if(mitersAll > 10000){
# 	    		alert("10km 이상은 조회가 불가능합니다.");
# 	    	 	SetCircleOnMap();
# 	    	 	return;
#  	     	}else if(mitersAll < 1){
#  	     		alert("반경을 선택해주세요.");
# 	    	 	SetCircleOnMap();
# 	    	 	return;
#  	     	}
# 			GetCircleSearchBound();
# 			wrapMask();
# 			intv = setInterval(progress, 1000);
# 			NetFunnel_Action({action_id:"B2"},function(ev,ret){
# 				$("#searrgVO").attr({"action":"/download_excel.do", "target":"_self"}).submit();	//지도좌표내의 주유소검색
# 			});
#
# 		}else {	//상호검색,지역내 검색,반경내 검색
# 			clearFormData();
# 			if($('#SEARCH_MOD4').is(":checked"))  {
# 				if($('#OS_NM').val() != ''){
# 					//$('#MAP_ZOOM').val(12); //줌 사용시 주석 해제 할것
# 				} else {
# 					alert("상호명을 입력 하십시오.");
# 					$('#OS_NM').focus();
# 					return;
# 				}
# 			}else if($('#SEARCH_MOD6').is(":checked"))  {
# 				if($('#OS_ADDR').val() != ''){
# 				} else {
# 					alert("주소를 입력 하십시오.");
# 					$('#OS_ADDR').focus();
# 					return;
# 				}
# 			}else{
# 				$('#OS_NM').val("");
# 				$('#OS_ADDR').val("");
# 			}
# 			if(validate()) {
# 				wrapMask();
# 				intv = setInterval(progress, 1000);
# 				NetFunnel_Action({action_id:"B2"},function(ev,ret){
# 					$("#searrgVO").attr({"action":"/download_excel.do", "target":"_self"}).submit();
# 				});
# 			}
# 		}
# 	}
#
# 	function labelImg(lid){
# 		$('#'+lid).click();
# 	}
#
# 	function checkBrowser() {
# 		var canUse = false;
# 		var browserName = "Unknown";
# 		var browserVer = "";
# 		var browserVerMain = "";
#
# 		if (/MSIE/.test(navigator.userAgent)) {
# 		  	browserName = "Internet Explorer";
# 		  	browserVer = /MSIE ([\d\.]+)\;/.exec(navigator.appVersion)[1];
# 		  	browserVerMain = /(\d+)\./.exec(browserVer)[1];
# 		 	if(browserVerMain == "8"||browserVerMain == "7"||browserVerMain == "6") {
# 		   		canUse = true;
# 		  	}
# 		}
# 		return canUse;
# 	}
#   </script>
#   <script>
#    function fnSetOsLayer(){
# 			if('' == 'main'){ //메인화면에서 올때
# 				if('' == '3'){ //경유일때
# 					$("#os_layer3").attr("class", "sel");
# 					$("#os_layer2").removeClass();
# 					$("#os_layer1").removeClass();
# 					$("#os_layer4").removeClass();
# 					$("#os_price3").show();
# 					$("#os_price3").focus();
# 					$("#os_price2").hide();
# 					$("#os_price1").hide();
# 					$("#os_price4").hide();
# 				}
# 			}
# 			$('#templ_list0').show();
# 			$('#templ_list1').hide();
# 			$('#templ_list').hide();
# 		}
#
#
# 		// GIS 시군구명 ajax callbank 함수
# 		function sigunguGisResult0(data){
# 			var html = '<option value="">시/군/구</option>';
#
# 			$.each(data, function(idx){
# 				html += '<option value="'+this.SIGUNGU_NM+'">'+this.SIGUNGU_NM+'</option>';
# 			});
#
# 			$("#SIGUNGU_NM0").html(html);
# 		}
#
# 		function clearFormData(){
# 			$('#MAP_CENTER_X').val("");
# 			$('#MAP_CENTER_Y').val("");
# 			$('#MAP_ZOOM').val("");
# 		}
#
# 		function fn_map0(dong, zoom) {
#
# 			var mapOpts = {
# 					center: new olleh.maps.LatLng(37.4852037,127.0344078),
# 					zoom: zoom,
# 					disableShadow: true,
# 					measureControl: false,
# 					//disableDraggingCursor :false,
# 					mapTypeId: 'ROADMAP'
# 				};
#
# 			map = new olleh.maps.Map(document.getElementById('map_div'), mapOpts);
# 		}
#
#    		function initialize() {
#    			var SEARCH_MOD_MAP 	= 'addr';
#    			//var SEARCH_MOD_MAP = $('#SEARCH_MOD').val();
#    			var MAP_CENTER_X 	= $('#MAP_CENTER_X').val();
#    			var MAP_CENTER_Y 	= $('#MAP_CENTER_Y').val();
#    			var MAP_ZOOM 		= '';
#    			if(MAP_ZOOM == ''){
#    				MAP_ZOOM = 8;
#    			}
#
#    			//alert("initialize:"+MAP_CENTER_X+"|"+MAP_CENTER_Y+"|"+SEARCH_MOD_MAP+"|"+MAP_ZOOM);
#    			fn_map0("", MAP_ZOOM);
#    		 	if(SEARCH_MOD_MAP == 'map'){
# 	   				geocoder = new olleh.maps.Geocoder("YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=");
#    	   				geocoder.geocode({
#    	   					type:1,
#    						x:MAP_CENTER_X,
#    						y:MAP_CENTER_Y
#    	   				},
#    	   				"geocode_center_map"
#    	   				);
#    			}else{
#    				if("" != ""){//메인화면에서 넘오올때
#
#    					geocoder = new olleh.maps.Geocoder("YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=");
#    	   				geocoder.geocode({
#    	   					type:1,
#    						x:$('#MAP_FIRST_X').val(),
#    						y:$('#MAP_FIRST_Y').val()
#    	   				},
#    	   				"geocode_center_main"
#    	   				);
#
#    				}else{
#    					//alert("selectVO.SIGUNGU_NM 없음" + "서울특별시 관악구 " );
#    	   	   			if("관악구" != "") {
#    	   	   				var sido_nm = "서울특별시";
#    	   	   				var sigungu_nm = "관악구";
#    	   	   				var sigun_idx = sigungu_nm.indexOf("시");
#    	   	   				if(sigun_idx>0){
#    	   	   					sigungu_nm = sigungu_nm.substring(0,sigun_idx+1)+" "+sigungu_nm.substring(sigun_idx+1,sigungu_nm.length);
#    	   	   				}
#
#    	   	   				/* var sigungu_nm_arr = sigungu_nm.split("시");
#    	   	   				if(sigungu_nm_arr != null && sigungu_nm_arr != undefined && sigungu_nm_arr.length > 1){
#    	   	   					if(sigungu_nm_arr.length > 3){
# 	   	   	   					sigungu_nm = sigungu_nm_arr[0] + "시 "+sigungu_nm_arr[1]  +" "+ sigungu_nm_arr[2];
#    	   	   					}else{
# 	   	   	   					sigungu_nm = sigungu_nm_arr[0] +"시 "+ sigungu_nm_arr[1];
#    	   	   					}
#    	   	   				} */
#    	   	   				var addrS = "";
#    	   	   				var dong_nm = "";
#    	   	   				if("" != ""){
#    	   	   					dong_nm = "";
#    	   	   				}
#
#    	   	   			//	alert(sido_nm);
#    	   	   				if(dong_nm==""){
#   	   	   	   				if(sigungu_nm == '청주시 상당구'){
# 		   						sigungu_nm += ' 성안동';
#  		   					}else if(sigungu_nm == '청주시 흥덕구'){
# 		   						sigungu_nm += ' 복대1동';
# 		   					}else if(sigungu_nm == '청주시 서원구'){
# 		   						sigungu_nm += ' 사직동';
# 		   					}else if(sigungu_nm == '청주시 청원구'){
# 		   						sigungu_nm += ' 우암동';
# 		   					}else if(sido_nm == '세종특별자치시'){
# 		   						sigungu_nm = '';
# 		   					//	sido_nm = '세종시';
# 		   						sido_nm = '세종특별자치시';
# 		   					}
#    	   	   				}
#    	   	   				if("304179.85162" != "" && "542284.69116" != ""){
#    	   	   					map.setCenter(new olleh.maps.Katech("304179.85162", "542284.69116"));
#    	   	   				} else{
#    	   	   					addrS = sido_nm +" "+ sigungu_nm + " " + dong_nm;
#    	   	   				//	alert(addrS);
#    	   	   					geocoder = new olleh.maps.Geocoder("YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=");
#    	   	   					geocoder.geocode({
#    	   	   						type:0,
#    	   							addr:addrS,
#    	   							addrcdtype:1
#    	   	   					},
#    	   	   					"geocode_center_nm"
#    	   	   					);
#    	   	   				}
#    	   	   			} else {
#
#    	   	   				geocoder = new olleh.maps.Geocoder("YjlmODYzMDE4N2ViNGU3OGEzMDE0MWRjZDcwNTdiZmI6NzViMmU2ZjFkYjVmYmMxY2Q1MWVlNjJhYjY0NDhkMWY=");
#    	   	   				geocoder.geocode({
#    	   	   					type:0,
#    	   	   					addr:"",
#    	   	   					addrcdtype:1
#    	   	   				},
#    	   	   				"geocode_center0"
#    	   	   				);
#    	   	   			}
#    				}
#
#    			}
#    		 	var listi = 0;
#
#    				var B027_P 			= "1729";
#    				var D047_P 			= "1649";
#    				var B034_P 			= "99999";
#    				var C004_P 			= "1499";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 10:56:28";
#    				var D047_DT 		= "2023-08-17 10:49:37";
#    				var B034_DT 		= " ";
#    				var C004_DT 		= "2023-08-16 15:03:43";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "304179.85162";
#    				var GIS_Y_COOR 		= "542284.69116";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "N";
#    				var SEL24_YN 		= "N";
#    				var POLL_DIV_CD 	= "HDO";
#    				var OS_NM 			= "HD현대오일뱅크㈜직영 문성골주유소";
#    				var DISC_IF_CONTS 		= "★현대오일뱅크제휴 신용카드할인 및 적립혜택&lt;br/&gt;  ☆주말 가격 대폭 할인";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= "★쿠폰 행사 사은품 지급";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= "☆최신식 세차기 운영&lt;br/&gt;★프리미엄 폼 세차 시행";
#    				var POLL_DIV_NM 		= "HD현대오일뱅크";
#    				var PHN_NO 			= "02-839-0081";
#    				var RD_ADDR 		= "서울 관악구 문성로 97 (신림동)";
#    				var CWSH_YN 		= "Y";
#    				var MAINT_YN 		= "N";
#    				var CVS_YN 			= "N";
#    				var UNI_ID    		= "A0000771";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "Y";
#    				var MARKER_ID       = "marker"+'1';
#    				var inx 			= '0';
#    				var BIZ_NO    		= "2838501654";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# 					, GIS_Y_COOR, VLT_YN, SELF_DIV_CD, SEL24_YN
# 					, POLL_DIV_CD, OS_NM
#
# 					, DISC_IF_CONTS
# 					, SAVE_EVENT_CONTS
# 					, REP_EVENT_CONTS
# 					, ON_EVENT_CONTS
# 					, ETC_BIZ_CONTS
#
# 					, POLL_DIV_NM, PHN_NO, RD_ADDR
# 					, CWSH_YN, MAINT_YN, CVS_YN, LPG_YN, UNI_ID, UNI_ID_VO
# 					, KPETRO_YN, BIZ_NO, CB_CD, CS_YN,KPETRO_DP_YN);
#
# 				listpop[listi] = {"B027_P":B027_P,"D047_P":D047_P,"B034_P":B034_P,"C004_P":C004_P,"K015_P":K015_P};
# 				listi+=1;
#
#    				var B027_P 			= "1739";
#    				var D047_P 			= "1639";
#    				var B034_P 			= "99999";
#    				var C004_P 			= "1500";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 10:59:08";
#    				var D047_DT 		= "2023-08-17 10:48:36";
#    				var B034_DT 		= " ";
#    				var C004_DT 		= "2023-08-12 09:51:05";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "305616.56394";
#    				var GIS_Y_COOR 		= "542563.88518";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "Y";
#    				var SEL24_YN 		= "N";
#    				var POLL_DIV_CD 	= "RTO";
#    				var OS_NM 			= "(주)연우에너지 신관주유소";
#    				var DISC_IF_CONTS 		= "";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= "";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= "버블폼 왁스코팅 고급세차합니다.    &lt;br/&gt; 세차후 차량광택을 직접 확인해보세요.";
#    				var POLL_DIV_NM 		= "알뜰주유소";
#    				var PHN_NO 			= "02-871-1356";
#    				var RD_ADDR 		= "서울 관악구 신림로 290 (신림동)";
#    				var CWSH_YN 		= "Y";
#    				var MAINT_YN 		= "N";
#    				var CVS_YN 			= "N";
#    				var UNI_ID    		= "A0009272";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "Y";
#    				var MARKER_ID       = "marker"+'2';
#    				var inx 			= '1';
#    				var BIZ_NO    		= "1418144346";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# 					, GIS_Y_COOR, VLT_YN, SELF_DIV_CD, SEL24_YN
# 					, POLL_DIV_CD, OS_NM
#
# 					, DISC_IF_CONTS
# 					, SAVE_EVENT_CONTS
# 					, REP_EVENT_CONTS
# 					, ON_EVENT_CONTS
# 					, ETC_BIZ_CONTS
#
# 					, POLL_DIV_NM, PHN_NO, RD_ADDR
# 					, CWSH_YN, MAINT_YN, CVS_YN, LPG_YN, UNI_ID, UNI_ID_VO
# 					, KPETRO_YN, BIZ_NO, CB_CD, CS_YN,KPETRO_DP_YN);
#
# 				listpop[listi] = {"B027_P":B027_P,"D047_P":D047_P,"B034_P":B034_P,"C004_P":C004_P,"K015_P":K015_P};
# 				listi+=1;
#
#    				var B027_P 			= "1739";
#    				var D047_P 			= "1654";
#    				var B034_P 			= "2079";
#    				var C004_P 			= "99999";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 10:58:55";
#    				var D047_DT 		= "2023-08-17 10:35:05";
#    				var B034_DT 		= "2023-08-17 10:40:03";
#    				var C004_DT 		= " ";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "304629.00295";
#    				var GIS_Y_COOR 		= "542795.99535";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "Y";
#    				var SEL24_YN 		= "N";
#    				var POLL_DIV_CD 	= "HDO";
#    				var OS_NM 			= "HD현대오일뱅크㈜직영 관악셀프주유소";
#    				var DISC_IF_CONTS 		= "현대오일뱅크 보너스 카드 적립&lt;br/&gt;제휴 신용카드 40~180원까지 할인/적립";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= "";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= "주유소 운영시간 05:30~23:00 연중무휴&lt;br/&gt;★초고급 휘발유 울트라카젠(옥탄가 102이상) 판매중★&lt;br/&gt;※울트라 카젠은 서울에서 6곳만 취급하는 옥탄가 102이상의 초고급 휘발유 입니다.※&lt;br/&gt;주유소 내부사정으로 인하여 일부 영업시간이 변동될 수 있습니다.";
#    				var POLL_DIV_NM 		= "HD현대오일뱅크";
#    				var PHN_NO 			= "02-867-1877";
#    				var RD_ADDR 		= "서울 관악구 남부순환로 1520 (신림동)";
#    				var CWSH_YN 		= "N";
#    				var MAINT_YN 		= "N";
#    				var CVS_YN 			= "N";
#    				var UNI_ID    		= "A0001129";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "Y";
#    				var MARKER_ID       = "marker"+'3';
#    				var inx 			= '2';
#    				var BIZ_NO    		= "8938501048";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# 					, GIS_Y_COOR, VLT_YN, SELF_DIV_CD, SEL24_YN
# 					, POLL_DIV_CD, OS_NM
#
# 					, DISC_IF_CONTS
# 					, SAVE_EVENT_CONTS
# 					, REP_EVENT_CONTS
# 					, ON_EVENT_CONTS
# 					, ETC_BIZ_CONTS
#
# 					, POLL_DIV_NM, PHN_NO, RD_ADDR
# 					, CWSH_YN, MAINT_YN, CVS_YN, LPG_YN, UNI_ID, UNI_ID_VO
# 					, KPETRO_YN, BIZ_NO, CB_CD, CS_YN,KPETRO_DP_YN);
#
# 				listpop[listi] = {"B027_P":B027_P,"D047_P":D047_P,"B034_P":B034_P,"C004_P":C004_P,"K015_P":K015_P};
# 				listi+=1;
#
#    				var B027_P 			= "1739";
#    				var D047_P 			= "1639";
#    				var B034_P 			= "99999";
#    				var C004_P 			= "99999";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 10:59:01";
#    				var D047_DT 		= "2023-08-17 10:53:03";
#    				var B034_DT 		= " ";
#    				var C004_DT 		= " ";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "305291.00000";
#    				var GIS_Y_COOR 		= "543996.00000";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "N";
#    				var SEL24_YN 		= "N";
#    				var POLL_DIV_CD 	= "HDO";
#    				var OS_NM 			= "(주)엠오티이엔지 직영 삼화주유소";
#    				var DISC_IF_CONTS 		= "";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= "";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= "영업시간AM 05:00~PM 12:00";
#    				var POLL_DIV_NM 		= "HD현대오일뱅크";
#    				var PHN_NO 			= "02-889-8929";
#    				var RD_ADDR 		= "서울 관악구 보라매로 41";
#    				var CWSH_YN 		= "N";
#    				var MAINT_YN 		= "N";
#    				var CVS_YN 			= "N";
#    				var UNI_ID    		= "A0009284";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "Y";
#    				var MARKER_ID       = "marker"+'4';
#    				var inx 			= '3';
#    				var BIZ_NO    		= "8788500827";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# 					, GIS_Y_COOR, VLT_YN, SELF_DIV_CD, SEL24_YN
# 					, POLL_DIV_CD, OS_NM
#
# 					, DISC_IF_CONTS
# 					, SAVE_EVENT_CONTS
# 					, REP_EVENT_CONTS
# 					, ON_EVENT_CONTS
# 					, ETC_BIZ_CONTS
#
# 					, POLL_DIV_NM, PHN_NO, RD_ADDR
# 					, CWSH_YN, MAINT_YN, CVS_YN, LPG_YN, UNI_ID, UNI_ID_VO
# 					, KPETRO_YN, BIZ_NO, CB_CD, CS_YN,KPETRO_DP_YN);
#
# 				listpop[listi] = {"B027_P":B027_P,"D047_P":D047_P,"B034_P":B034_P,"C004_P":C004_P,"K015_P":K015_P};
# 				listi+=1;
#
#    				var B027_P 			= "1746";
#    				var D047_P 			= "1646";
#    				var B034_P 			= "99999";
#    				var C004_P 			= "99999";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 10:44:06";
#    				var D047_DT 		= "2023-08-17 10:48:34";
#    				var B034_DT 		= " ";
#    				var C004_DT 		= " ";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "304626.76480";
#    				var GIS_Y_COOR 		= "540872.61710";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "N";
#    				var SEL24_YN 		= "N";
#    				var POLL_DIV_CD 	= "HDO";
#    				var OS_NM 			= "현대주유소";
#    				var DISC_IF_CONTS 		= "";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= "";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= "";
#    				var POLL_DIV_NM 		= "HD현대오일뱅크";
#    				var PHN_NO 			= "02-851-9200";
#    				var RD_ADDR 		= "서울 관악구 난곡로 108 (신림동)";
#    				var CWSH_YN 		= "N";
#    				var MAINT_YN 		= "N";
#    				var CVS_YN 			= "N";
#    				var UNI_ID    		= "A0001089";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "N";
#    				var MARKER_ID       = "marker"+'5';
#    				var inx 			= '4';
#    				var BIZ_NO    		= "1191198968";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# 					, GIS_Y_COOR, VLT_YN, SELF_DIV_CD, SEL24_YN
# 					, POLL_DIV_CD, OS_NM
#
# 					, DISC_IF_CONTS
# 					, SAVE_EVENT_CONTS
# 					, REP_EVENT_CONTS
# 					, ON_EVENT_CONTS
# 					, ETC_BIZ_CONTS
#
# 					, POLL_DIV_NM, PHN_NO, RD_ADDR
# 					, CWSH_YN, MAINT_YN, CVS_YN, LPG_YN, UNI_ID, UNI_ID_VO
# 					, KPETRO_YN, BIZ_NO, CB_CD, CS_YN,KPETRO_DP_YN);
#
# 				listpop[listi] = {"B027_P":B027_P,"D047_P":D047_P,"B034_P":B034_P,"C004_P":C004_P,"K015_P":K015_P};
# 				listi+=1;
#
#    				var B027_P 			= "1755";
#    				var D047_P 			= "1655";
#    				var B034_P 			= "2158";
#    				var C004_P 			= "99999";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 10:58:35";
#    				var D047_DT 		= "2023-08-17 10:57:09";
#    				var B034_DT 		= "2023-08-17 10:50:15";
#    				var C004_DT 		= " ";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "308132.00000";
#    				var GIS_Y_COOR 		= "542397.00000";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "Y";
#    				var SEL24_YN 		= "N";
#    				var POLL_DIV_CD 	= "SKE";
#    				var OS_NM 			= "(주)한유에너지행운셀프주유소";
#    				var DISC_IF_CONTS 		= "CLUB SK 하나카드 150원/ℓ 할인,&lt;br/&gt;THE YOU 신한카드 100원/ℓ 할인,&lt;br/&gt;드라이빙패스 롯데카드 100원/ℓ 할인,&lt;br/&gt;SK스마트 KB카드 최고 100원/ℓ 할인,.&lt;br/&gt;SK상품권/OK캐시백포인트/모바일쿠폰 사용가능,";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= "";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= "";
#    				var POLL_DIV_NM 		= "SK에너지";
#    				var PHN_NO 			= "02-871-5189";
#    				var RD_ADDR 		= "서울 관악구 남부순환로 1883 (봉천동)";
#    				var CWSH_YN 		= "Y";
#    				var MAINT_YN 		= "N";
#    				var CVS_YN 			= "N";
#    				var UNI_ID    		= "A0001149";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "Y";
#    				var MARKER_ID       = "marker"+'6';
#    				var inx 			= '5';
#    				var BIZ_NO    		= "1198522514";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# 					, GIS_Y_COOR, VLT_YN, SELF_DIV_CD, SEL24_YN
# 					, POLL_DIV_CD, OS_NM
#
# 					, DISC_IF_CONTS
# 					, SAVE_EVENT_CONTS
# 					, REP_EVENT_CONTS
# 					, ON_EVENT_CONTS
# 					, ETC_BIZ_CONTS
#
# 					, POLL_DIV_NM, PHN_NO, RD_ADDR
# 					, CWSH_YN, MAINT_YN, CVS_YN, LPG_YN, UNI_ID, UNI_ID_VO
# 					, KPETRO_YN, BIZ_NO, CB_CD, CS_YN,KPETRO_DP_YN);
#
# 				listpop[listi] = {"B027_P":B027_P,"D047_P":D047_P,"B034_P":B034_P,"C004_P":C004_P,"K015_P":K015_P};
# 				listi+=1;
#
#    				var B027_P 			= "1759";
#    				var D047_P 			= "1659";
#    				var B034_P 			= "99999";
#    				var C004_P 			= "99999";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 09:37:52";
#    				var D047_DT 		= "2023-08-17 09:37:52";
#    				var B034_DT 		= " ";
#    				var C004_DT 		= " ";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "305321.36850";
#    				var GIS_Y_COOR 		= "543824.24180";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "Y";
#    				var SEL24_YN 		= "N";
#    				var POLL_DIV_CD 	= "SKE";
#    				var OS_NM 			= "대양석유(주)직영 보라매주유소";
#    				var DISC_IF_CONTS 		= ".";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= ".";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= ".";
#    				var POLL_DIV_NM 		= "SK에너지";
#    				var PHN_NO 			= "02-882-5189";
#    				var RD_ADDR 		= "서울 관악구  보라매로 26 (봉천동)";
#    				var CWSH_YN 		= "Y";
#    				var MAINT_YN 		= "N";
#    				var CVS_YN 			= "N";
#    				var UNI_ID    		= "A0001145";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "Y";
#    				var MARKER_ID       = "marker"+'7';
#    				var inx 			= '6';
#    				var BIZ_NO    		= "2668500043";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# 					, GIS_Y_COOR, VLT_YN, SELF_DIV_CD, SEL24_YN
# 					, POLL_DIV_CD, OS_NM
#
# 					, DISC_IF_CONTS
# 					, SAVE_EVENT_CONTS
# 					, REP_EVENT_CONTS
# 					, ON_EVENT_CONTS
# 					, ETC_BIZ_CONTS
#
# 					, POLL_DIV_NM, PHN_NO, RD_ADDR
# 					, CWSH_YN, MAINT_YN, CVS_YN, LPG_YN, UNI_ID, UNI_ID_VO
# 					, KPETRO_YN, BIZ_NO, CB_CD, CS_YN,KPETRO_DP_YN);
#
# 				listpop[listi] = {"B027_P":B027_P,"D047_P":D047_P,"B034_P":B034_P,"C004_P":C004_P,"K015_P":K015_P};
# 				listi+=1;
#
#    				var B027_P 			= "1765";
#    				var D047_P 			= "1675";
#    				var B034_P 			= "1955";
#    				var C004_P 			= "1430";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 10:59:57";
#    				var D047_DT 		= "2023-08-17 10:46:26";
#    				var B034_DT 		= "2023-08-17 10:42:15";
#    				var C004_DT 		= "2023-08-16 11:00:38";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "308077.68423";
#    				var GIS_Y_COOR 		= "542361.34829";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "N";
#    				var SEL24_YN 		= "N";
#    				var POLL_DIV_CD 	= "SKE";
#    				var OS_NM 			= "SK에너지(주) 신봉천";
#    				var DISC_IF_CONTS 		= "* SK제휴 할인카드 40~120원/L 할인&lt;br/&gt;*  옥탄가 99이상 고급휘발유 판매";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= ".  @  SK주유 상품권 판매처  @";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= "* 세차영업시간 : 08:00 ~ 20:00시 세차기 가동 &lt;br/&gt;&lt;br/&gt;* 독일명품 소낙스(SONAX)세제 사용&lt;br/&gt;* 휠 세척 (휠 크리너)&lt;br/&gt;* 버블(거품) 세차&lt;br/&gt;* 코팅왁스 세차&lt;br/&gt;* 하부세차";
#    				var POLL_DIV_NM 		= "SK에너지";
#    				var PHN_NO 			= "02-885-5189";
#    				var RD_ADDR 		= "서울 관악구 남부순환로 1880 (봉천동)";
#    				var CWSH_YN 		= "Y";
#    				var MAINT_YN 		= "N";
#    				var CVS_YN 			= "Y";
#    				var UNI_ID    		= "A0001144";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "Y";
#    				var MARKER_ID       = "marker"+'8';
#    				var inx 			= '7';
#    				var BIZ_NO    		= "1198507866";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# 					, GIS_Y_COOR, VLT_YN, SELF_DIV_CD, SEL24_YN
# 					, POLL_DIV_CD, OS_NM
#
# 					, DISC_IF_CONTS
# 					, SAVE_EVENT_CONTS
# 					, REP_EVENT_CONTS
# 					, ON_EVENT_CONTS
# 					, ETC_BIZ_CONTS
#
# 					, POLL_DIV_NM, PHN_NO, RD_ADDR
# 					, CWSH_YN, MAINT_YN, CVS_YN, LPG_YN, UNI_ID, UNI_ID_VO
# 					, KPETRO_YN, BIZ_NO, CB_CD, CS_YN,KPETRO_DP_YN);
#
# 				listpop[listi] = {"B027_P":B027_P,"D047_P":D047_P,"B034_P":B034_P,"C004_P":C004_P,"K015_P":K015_P};
# 				listi+=1;
#
#    				var B027_P 			= "1765";
#    				var D047_P 			= "1665";
#    				var B034_P 			= "1975";
#    				var C004_P 			= "1420";
#    				var K015_P 			= "";
#    				var B027_DT 		= "2023-08-17 10:57:14";
#    				var D047_DT 		= "2023-08-17 10:51:26";
#    				var B034_DT 		= "2023-08-17 10:55:56";
#    				var C004_DT 		= "2023-08-16 16:35:25";
#    				var K015_DT 		= "";
#    				var GIS_X_COOR 		= "308420.93867";
#    				var GIS_Y_COOR 		= "542175.23155";
#    				var VLT_YN 			= " ";
#    				var SELF_DIV_CD 	= "Y";
#    				var SEL24_YN 		= "Y";
#    				var POLL_DIV_CD 	= "GSC";
#    				var OS_NM 			= "서일석유(주)락성주유소";
#    				var DISC_IF_CONTS 		= "*GS&amp;amp;POINT&lt;br/&gt;*제로페이,서울페이 사용가능&lt;br/&gt;&lt;br/&gt;*우수단골 고객 할인 제도: 월 주유량에따른 할인 적용 (직원문의)";
#    				var SAVE_EVENT_CONTS 	= "";
#    				var REP_EVENT_CONTS 	= "☆신형주유기 교체 완료!!☆&lt;br/&gt;※바로주유 서비스 이용가능!!&lt;br/&gt;(자세한 내용은 해당업장을 방문하여 확인하세요!)&lt;br/&gt;*세차영업시간 8:00~20:00 연중무휴&lt;br/&gt;독일제 명품 브러시 + 버블세차 + 최고급세제+신개념유리막코팅제+물기제거까지 완벽한세차!";
#    				var ON_EVENT_CONTS 		= "";
#    				var ETC_BIZ_CONTS 		= "* 주유소 운영시간&lt;br/&gt;평일, 토요일 : 23시간 영업(새벽 2시~3시까지 1시간 미영업)&lt;br/&gt;토요일,일요일 : 18시간 영업(00시부터 06시까지 6시간 미영업)&lt;br/&gt;&lt;br/&gt;*GS포인트 공식 사용처&lt;br/&gt;";
#    				var POLL_DIV_NM 		= "GS칼텍스";
#    				var PHN_NO 			= "02-877-0867";
#    				var RD_ADDR 		= "서울 관악구 남부순환로 1920 (봉천동)";
#    				var CWSH_YN 		= "Y";
#    				var MAINT_YN 		= "Y";
#    				var CVS_YN 			= "N";
#    				var UNI_ID    		= "A0001155";
#    				var LPG_YN 			= "";
#    				var UNI_ID_VO		= "";
#    				var KPETRO_YN 		= "N";
#    				var KPETRO_DP_YN 	= "Y";
#    				var MARKER_ID       = "marker"+'9';
#    				var inx 			= '8';
#    				var BIZ_NO    		= "1198540996";
#    				var CB_CD    		= "N";
#    				var CS_YN    		= "N";
#
# 				fn_marker0(inx,MARKER_ID, B027_P, D047_P, B034_P
# 					, C004_P, K015_P, B027_DT, D047_DT, B034_DT
# 					, C004_DT, K015_DT, GIS_X_COOR
# ...
#            </div>
#           </div>
#           <div style="position: absolute; transform: translate3d(705px, 492px, 0px); display: block; z-index: 845881;">
#            <div class="ollehmap-event" data-id="ollehmap1692246973442" style='position: absolute; background-color: transparent; background-repeat: no-repeat; cursor: pointer; width: 38px; height: 37px; margin-left: -19px; margin-top: -37px; background-image: url("/images/user/gis/3-01.png"); background-size: 100% 100%; transform-origin: 50% 100%; transform: rotate(0deg);'>
#            </div>
#           </div>
#           <div style="position: absolute; transform: translate3d(819px, 374px, 0px); display: block; z-index: 844942;">
#            <div class="ollehmap-event" data-id="ollehmap1692246973443" style='position: absolute; background-color: transparent; background-repeat: no-repeat; cursor: pointer; width: 38px; height: 37px; margin-left: -19px; margin-top: -37px; background-image: url("/images/user/gis/3-01.png"); background-size: 100% 100%; transform-origin: 50% 100%; transform: rotate(0deg);'>
#            </div>
#           </div>
#           <div style="position: absolute; transform: translate3d(530px, 363px, 0px); display: block; z-index: 844856;">
#            <div class="ollehmap-event" data-id="ollehmap1692246973444" style='position: absolute; background-color: transparent; background-repeat: no-repeat; cursor: pointer; width: 38px; height: 37px; margin-left: -19px; margin-top: -37px; background-image: url("/images/user/gis/marker_dp_gsc.png"); background-size: 100% 100%; transform-origin: 50% 100%; transform: rotate(0deg);'>
#            </div>
#           </div>
#           <div style="position: absolute; transform: translate3d(527px, 496px, 0px); display: block; z-index: 845918;">
#            <div class="ollehmap-event" data-id="ollehmap1692246973445" style='position: absolute; background-color: transparent; background-repeat: no-repeat; cursor: pointer; width: 38px; height: 37px; margin-left: -19px; margin-top: -37px; background-image: url("/images/user/gis/marker_dp_gsc.png"); background-size: 100% 100%; transform-origin: 50% 100%; transform: rotate(0deg);'>
#            </div>
#           </div>
#          </div>
#          <div style="position: absolute; z-index: 1003;">
#          </div>
#          <div style="position: absolute; z-index: 1004;">
#           <div class="ollehmap-info" style="margin-top: -568px; margin-left: -217px; transform: translate3d(480px, 435px, 0px); display: block; z-index: 845428; position: absolute; top: -21px;">
#            <div class="ollehmap-info-area" style="width:426px;height:500px;">
#             <div class="ollehmap-info-content" style="max-width:600px;">
#              <div class="ollehmap-info-content-overflow ollehmap-event" data-id="ollehmap1692246973446" style="padding:18px;width:390px;height:464px;">
#               <div class="ollehmap-info-defaultStyle">
#                <div class="gis_detail_info_box" id="os_dtail_info">
#                 <div class="inner">
#                  <div class="header">
#                   <img alt="sk에너지" class="mgr_5" id="os_title_icon" src="/images/user/com/icon_hy.gif"/>
#                   <label id="os_nm">
#                    HD현대오일뱅크㈜직영 문성골주유소
#                   </label>
#                   <span id="SPAN_SELF_VLT_YN_ID">
#                   </span>
#                  </div>
#                  <div class="overflow_gis_detail" style="height:455px;">
#                   <div class="gis_detail_info_bcon">
#                    <div class="desc_box mgb_0">
#                     <div class="d_left">
#                      <span class="gis_dpopup_tt">
#                       기본정보
#                       <span id="SPAN_KPETRO">
#                        <a href="#" onmouseout="hideDp();return false;" onmouseover="showDp();return false;">
#                         <img alt="전산보고주유소" class="bul" id="kdp_icon" src="/images/user/gis/k_petro_dp.jpg"/>
#                        </a>
#                       </span>
#                      </span>
#                     </div>
#                     <div class="d_right">
#                      <!--a class="btn_type2_gray va_top" href="#" title="주유소사진보기"><span>주유소사진보기</span></a-->
#                      <a class="btn_type2_green va_top" href="javascript:fnInsertMycareos('A0000771','2838501654');" title="관심주유소 등록">
#                       <span>
#                        관심주유소 등록
#                       </span>
#                      </a>
#                     </div>
#                    </div>
#                    <ul>
#                     <li>
#                      - 전화번호 :
#                      <label id="phn_no">
#                       02-839-0081
#                      </label>
#                     </li>
#                     <li>
#                      - 주소 :
#                      <label id="rd_addr">
#                       서울 관악구 문성로 97 (신림동)
#                      </label>
#                     </li>
#                     <li>
#                      - 상표 :
#                      <label id="poll_div_nm">
#                       HD현대오일뱅크
#                      </label>
#                     </li>
#                    </ul>
#                   </div>
#                   <div class="gis_detail_info_os" id="os_dtail_info_os">
#                    <div class="inner2">
#                     <div class="overflow_gis_detail2">
#                      <img alt="품질인증주유소" class="bul" id="kpos_icon" src="/images/user/gis/k_petro_ansim_pop.jpg"/>
#                      <br/>
#                      <br/>
#                      한국석유관리원에서 운영하는
#                      <br/>
#                      석유품질인증프로그램 협약 주유소입니다.
#                      <br/>
#                      자세한 내용은 한국석유관리원 홈페이지
#                      <br/>
#                      <span>
#                       (www.kpetro.or.kr)
#                      </span>
#                      를 참고하시기 바랍니다.
#                     </div>
#                    </div>
#                   </div>
#                   <div class="gis_detail_info_dp" id="os_dtail_info_dp">
#                    <div class="inner2">
#                     <div class="overflow_gis_detail2">
#                      <img alt="전산보고주유소" class="bul" id="kdp_icon" src="/images/user/gis/k_petro_dp_pop.jpg"/>
#                      <br/>
#                      <br/>
#                      석유제품의 실거래 물량정보를 자동으로 집계하여 유통량을
#                      <br/>
#                      정확하고 투명하게 보고하는 전산보고 주유소입니다.
#                      <br/>
#                      자세한 내용은 한국석유관리원 홈페이지
#                      <br/>
#                      <span>
#                       (www.kpetro.or.kr)
#                      </span>
#                      를 참고하시기 바랍니다.
#                     </div>
#                    </div>
#                   </div>
#                   <div class="gis_detail_info_bcon mgt_15">
#                    <div class="desc_box">
#                     <div class="d_left">
#                      <span class="gis_dpopup_tt">
#                       유가정보
#                      </span>
#                     </div>
#                    </div>
#                    <div>
#                     <table class="tbl_type10" summary="유종, 가격, 업데이트일시별로 확인할 수 있습니다.">
#                      <caption>
#                       유가정보 안내
#                      </caption>
#                      <colgroup>
#                       <col style="width:80px;"/>
#                       <col style="width:70px;"/>
#                       <col style="width:auto;"/>
#                      </colgroup>
#                      <thead>
#                       <tr>
#                        <th class="nobd_l" scope="col">
#                         유종
#                        </th>
#                        <th scope="col">
#                         가격
#                        </th>
#                        <th scope="col">
#                         업데이트 일시
#                        </th>
#                       </tr>
#                      </thead>
#                      <tbody id="infoTbody">
#                       <tr id="b034Div" style="display: none;">
#                        <td class="nobd_l" scope="col">
#                         고급휘발유
#                        </td>
#                        <td>
#                         <label id="b034_p">
#                         </label>
#                         원
#                        </td>
#                        <td>
#                         <label id="cha_aft_fin_dt1">
#                         </label>
#                        </td>
#                       </tr>
#                       <tr id="b027Div">
#                        <td class="nobd_l" scope="col">
#                         보통휘발유
#                        </td>
#                        <td>
#                         <label id="b027_p">
#                          1,729
#                         </label>
#                         원
#                        </td>
#                        <td>
#                         <label id="cha_aft_fin_dt2">
#                          2023-08-17　　10:56:28
#                         </label>
#                        </td>
#                       </tr>
#                       <tr id="d047Div">
#                        <td class="nobd_l" scope="col">
#                         경유
#                        </td>
#                        <td>
#                         <label id="d047_p">
#                          1,649
#                         </label>
#                         원
#                        </td>
#                        <td>
#                         <label id="cha_aft_fin_dt3">
#                          2023-08-17　　10:49:37
#                         </label>
#                        </td>
#                       </tr>
#                       <tr id="c004Div">
#                        <td class="nobd_l" scope="col">
#                         실내등유
#                        </td>
#                        <td>
#                         <label id="c004_p">
#                          1,499
#                         </label>
#                         원
#                        </td>
#                        <td>
#                         <label id="cha_aft_fin_dt4">
#                          2023-08-16　　15:03:43
#                         </label>
#                        </td>
#                       </tr>
#                       <tr id="k015Div" style="display: none;">
#                        <td class="nobd_l" scope="col">
#                         자동차부탄
#                        </td>
#                        <td>
#                         <label id="k015_p">
#                         </label>
#                         원
#                        </td>
#                        <td>
#                         <label id="cha_aft_fin_dt5">
#                         </label>
#                        </td>
#                       </tr>
#                      </tbody>
#                      <tbody id="infoTbodyNon" style="display: none;">
#                       <tr>
#                        <td class="nobd_l" colspan="3" scope="col">
#                         가격보고 자료가 없습니다.
#                        </td>
#                       </tr>
#                      </tbody>
#                      <tbody id="infoTbodyNonT" style="display: none;">
#                       <tr>
#                        <td class="nobd_l" colspan="3" id="infoTbodyNonTTD" scope="col">
#                        </td>
#                       </tr>
#                      </tbody>
#                     </table>
#                    </div>
#                    <span class="ts_11 tc_666">
#                     * 상기 가격정보는 특정시점에 조사되어 실제와 다를 수 있습니다.
#                    </span>
#                   </div>
#                   <div class="gis_detail_info_bcon mgt_20">
#                    <div class="desc_box">
#                     <div class="d_left">
#                      <span class="gis_dpopup_tt">
#                       부가정보
#                      </span>
#                     </div>
#                    </div>
#                    <div class="service">
#                     <img alt="세차장" id="cwsh_yn" src="/images/user/gis/oil_station_service1_01.gif"/>
#                     <img alt="충전소" id="lpg_yn" src="/images/user/gis/oil_station_service1_02_01_off.gif"/>
#                     <img alt="경정비" id="maint_yn" src="/images/user/gis/oil_station_service1_03_off.gif"/>
#                     <img alt="편의점" id="cvs_yn" src="/images/user/gis/oil_station_service1_04_off.gif"/>
#                     <img alt="24시영업" id="sel24_yn" src="/images/user/gis/oil_station_service1_05_off.gif"/>
#                    </div>
#                   </div>
#                   <div class="gis_detail_info_bcon mgt_15">
#                    <div class="desc_box">
#                     <div class="d_left">
#                      <span class="gis_dpopup_tt">
#                       행사정보
#                      </span>
#                     </div>
#                    </div>
#                    <div class="t_left">
#                     <table class="tbl_type20">
#                      <colgroup>
#                       <col style="width:120px;"/>
#                       <col/>
#                      </colgroup>
#                      <tbody>
#                       <tr>
#                        <th class="nobd_l fir t_center">
#                         할인/적립내용
#                        </th>
#                        <td class="fir">
#                         <label id="conts1">
#                          ★현대오일뱅크제휴 신용카드할인 및 적립혜택
#                          <br/>
#                          ☆주말 가격 대폭 할인
#                         </label>
#                        </td>
#                       </tr>
#                       <tr>
#                        <th class="nobd_l t_center">
#                         사은/오픈행사 내용
#                        </th>
#                        <td>
#                         <label id="conts2">
#                          ★쿠폰 행사 사은품 지급
#                         </label>
#                        </td>
#                       </tr>
#                       <tr>
#                        <th class="nobd_l t_center">
#                         기타 내용
#                        </th>
#                        <td>
#                         <label id="conts3">
#                          ☆최신식 세차기 운영
#                          <br/>
#                          ★프리미엄 폼 세차 시행
#                         </label>
#                        </td>
#                       </tr>
#                      </tbody>
#                     </table>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <div class="b_arr">
#                  <img alt="" src="/images/user/gis/gis_info_detail_arr.png"/>
#                 </div>
#                 <div class="btn_close">
#                  <a href="#">
#                   <img alt="닫기" onclick="javascript:fn_osBox_close();" src="/images/user/com/btn_layer_dclose_gray.gif"/>
#                  </a>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="ollehmap-info-tip" style="top:502px;left:215px;">
#             <img class="ollehmap-info-tip-img" src="https://api.ktgis.com:443/ollehmap/resource/v3/img/infowins.png"/>
#            </div>
#           </div>
#          </div>
#          <div style="position: absolute; z-index: 999; visibility: visible;">
#          </div>
#          <div class="ollehmap-noevent" style="position: absolute; display: none; z-index: 1;">
#           <div class="ollehmap-noevent" style="position: absolute;">
#           </div>
#          </div>
#          <div class="ollehmap-noevent" style="position: absolute; display: none; z-index: 0;">
#           <div class="ollehmap-noevent" style="position: absolute;">
#           </div>
#          </div>
#         </div>
#         <div class="ollehmap-transparent" id="transparent_pane" style="position: absolute; z-index: 99999; width: 100%; height: 100%; display: none;">
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- 지도 끝-->
#     </div>
#     <!-- //content -->
#    </div>
#    <!-- //container -->
#    <div id="mask">
#    </div>
#    <div id="modalwindow">
#     <img alt="로딩중" src="/images/user/gis/02_loading_map.gif"/>
#    </div>
#   </div>
#  </body>
# </html>

# %%
os_info = soup.find_all(id= "SIGUNGU_NM0")
os_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os_info = soup.find_all(id= "SIGUNGU_NM0")
#       2 os_info
#
# NameError: name 'soup' is not defined

# %%
os_info[0].find(id = "os_nm").text
# Out:
# '오천만주유소'

# %%
price_info = soup.find_all( id = "infoTbody")
price_info[0].find(id = "b027_p").text
# Out:
# '1,737'

# %%
disel_info = soup.find_all(id = "infoTbody")
disel_info[0].find(id = "d047_p").text
# Out:
# '1,577'

# %%
add_info = soup.find_all(class_ = "service")
src_text = add_info[0].find("img")["src"]
print(add_info[0].find("img")["alt"])
# if not "off" in src_text:
#     print(1)
# Out:
# 세차장

# %%
add_info[0].find_all("img")[1]["alt"]
# Out:
# '충전소'

# %%
soup.find_all(id = "poll_div_nm")[0].text
# Out:
# 'S-OIL'

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 driver.close()
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:456, in WebDriver.close(self)
#     448 def close(self) -> None:
#     449     """Closes the current window.
#     450
#     451     :Usage:
#    (...)
#     454             driver.close()
#     455     """
# --> 456     self.execute(Command.CLOSE)
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=116.0.5845.96)
# Stacktrace:
# #0 0x55f7c525ee23 <unknown>
# #1 0x55f7c4f877a7 <unknown>
# #2 0x55f7c4f6c340 <unknown>
# #3 0x55f7c4f6d84f <unknown>
# #4 0x55f7c4f6d7a4 <unknown>
# #5 0x55f7c4f5def1 <unknown>
# #6 0x55f7c4f5ecc0 <unknown>
# #7 0x55f7c4ff1c42 <unknown>
# #8 0x55f7c4fe6fd8 <unknown>
# #9 0x55f7c4fbaa7b <unknown>
# #10 0x55f7c4fbb81e <unknown>
# #11 0x55f7c5220638 <unknown>
# #12 0x55f7c5224507 <unknown>
# #13 0x55f7c522ec4c <unknown>
# #14 0x55f7c5225136 <unknown>
# #15 0x55f7c51f39cf <unknown>
# #16 0x55f7c5248b98 <unknown>
# #17 0x55f7c5248d68 <unknown>
# #18 0x55f7c5257cb3 <unknown>
# #19 0x7fb674494b43 <unknown>

# %%
from tqdm.notebook import tqdm
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd


def get_oil_info(soup):

    os_info ={}

    ## 주유소 이름
    os_name = soup.find_all(class_="header")
    os_info["이름"] = os_info[0].find(id = "os_nm").text

    ## 주유소 상표
    os_property = soup.find_all(id = "poll_div_nm")
    os_info["상표"] = os_property[0].text

    ## 휘발유 가격
    gasoline_price = soup.find_all( id = "infoTbody")
    os_info["휘발유 가격"] = gasoline_price[0].find(id = "b027_p").text

    ## 경유 가격
    disel_price = soup.find_all(id = "infoTbody")
    os_info["경유 가격"] = disel_price[0].find(id = "d047_p").text

    ## 부가 기능
    add_info = soup.find_all(class_ = "service")
    for info in add_info[0].find_all("img"):
        if not "off" in info["src"]:
            os_info["부가기능"] = {info["alt"] : "o" }
        else:
            os_info["부가기능"] = {info["alt"] : "x" }    

    return os_info


def make_df(os_data):
    
    os_df = pd.DataFrame(os_data)
    print(os_df)
    


if __name__ == "__main__":

    options = webdriver.ChromeOptions()

    prefs = {'download.default_directory':'../../data/html/',
            'download.prompt_for_download' : False}
    options.add_experimental_option('prefs', prefs)

    url = "https://www.opinet.co.kr/searRgSelect.do"
    driver = webdriver.Chrome(service=Service("../../driver/chromedriver-linux64/chromedriver"))


    sigungu = driver.find_element(By.ID, "SIGUNGU_NM0")
    sigungu_list = sigungu.find_elements(By.TAG_NAME, "option")

    sigungu_nm_list = []
    for idx, sigungu_name in enumerate(sigungu_list):
        sigungu_nm_list.append(sigungu_name.get_attribute("value"))


    os_data = []
    for sigungu_name in tqdm(sigungu_nm_list):
        sigungu = driver.find_element(By.ID, "SIGUNGU_NM0")
        sigungu.send_keys(sigungu_name)

        gasoline = driver.find_element(By.XPATH, '''//*[@id="os_layer2"]/p/a''')
        gasoline.click()
        oilstation = driver.find_element(By.XPATH, '''//*[@id="body1"]/tr[1]/td[1]/a''')
        oilstation.click()

        page = driver.page_source
        soup = BeautifulSoup(page, "html.parser")

        os_data.append(get_oil_info(soup))
        
        time.sleep(3)

    make_df(os_data)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[82], line 60
#      56 url = "https://www.opinet.co.kr/searRgSelect.do"
#      57 driver = webdriver.Chrome(service=Service("../../driver/chromedriver-linux64/chromedriver"))
# ---> 60 sigungu = driver.find_element(By.ID, "SIGUNGU_NM0")
#      61 sigungu_list = sigungu.find_elements(By.TAG_NAME, "option")
#      63 sigungu_nm_list = []
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:739, in WebDriver.find_element(self, by, value)
#     736     by = By.CSS_SELECTOR
#     737     value = f'[name="{value}"]'
# --> 739 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="SIGUNGU_NM0"]"}
#   (Session info: chrome=116.0.5845.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x55f7c525ee23 <unknown>
# #1 0x55f7c4f877a7 <unknown>
# #2 0x55f7c4fc61d3 <unknown>
# #3 0x55f7c4fc62c1 <unknown>
# #4 0x55f7c5001a04 <unknown>
# #5 0x55f7c4fe703d <unknown>
# #6 0x55f7c4fff369 <unknown>
# #7 0x55f7c4fe6de3 <unknown>
# #8 0x55f7c4fbaa7b <unknown>
# #9 0x55f7c4fbb81e <unknown>
# #10 0x55f7c5220638 <unknown>
# #11 0x55f7c5224507 <unknown>
# #12 0x55f7c522ec4c <unknown>
# #13 0x55f7c5225136 <unknown>
# #14 0x55f7c51f39cf <unknown>
# #15 0x55f7c5248b98 <unknown>
# #16 0x55f7c5248d68 <unknown>
# #17 0x55f7c5257cb3 <unknown>
# #18 0x7fb674494b43 <unknown>
